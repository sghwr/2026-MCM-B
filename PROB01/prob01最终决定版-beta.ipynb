# %%
from deap import base, creator, tools
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# ==============================
# 问题参数
# ==============================
TMAX = 200          # 为演示缩短长度，实际可设1000
K = 10
P = 3

D_total = 1e8
Cap_rocket = 150        
Cap_lift = 179000       
L_max = 800

Cost_rocket = 500000
Cost_lift = 100000

# ==============================
# DEAP 初始化
# ==============================
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()

# 火箭发射次数 (整数)
toolbox.register("attr_R", lambda: random.randint(0, L_max))
# 电梯运输量 (连续)
toolbox.register("attr_E", lambda: random.uniform(0, Cap_lift))

def init_individual():
    """保证初始化总运输量大约 D_total / TMAX"""
    ind = []
    avg_rocket_per_year = D_total / TMAX / 2 / Cap_rocket / K
    avg_lift_per_year = D_total / TMAX / 2 / P

    for _ in range(K*TMAX):
        val = max(1, int(random.gauss(avg_rocket_per_year, avg_rocket_per_year*0.5)))
        ind.append(min(val, L_max))

    for _ in range(P*TMAX):
        val = random.gauss(avg_lift_per_year, avg_lift_per_year*0.5)
        val = max(0, min(val, Cap_lift))
        ind.append(val)

    return creator.Individual(ind)

toolbox.register("individual", init_individual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# ==============================
# Fitness 分配
# ==============================
def assign_fitness(pop, w1=0.5, w2=0.5):
    ZC_list = []
    ZT_list = []

    for ind in pop:
        R = np.array(ind[:K*TMAX]).reshape(K, TMAX)
        E = np.array(ind[K*TMAX:]).reshape(P, TMAX)

        # 总成本
        rocket_tons = np.sum(R) * Cap_rocket
        lift_tons = np.sum(E)
        ZC = Cost_rocket * rocket_tons + Cost_lift * lift_tons

        # 总工期
        transported = 0
        ZT = TMAX
        for t in range(TMAX):
            R_t = np.sum(R[:, t]) * Cap_rocket
            E_t = np.sum(E[:, t])
            transported += R_t + E_t
            if transported >= D_total:
                ZT = t + 1
                break

        # 罚函数: 总运输量不足时增加 fitness
        
        penalty = max(0, (D_total - transported)/D_total) * 1e6

        ind.ZC = ZC
        ind.ZT = ZT
        ind.penalty = penalty

        ZC_list.append(ZC)
        ZT_list.append(ZT)

    # 种群内标准化
    std_C = np.std(ZC_list) + 1e-6
    std_T = np.std(ZT_list) + 1e-6

    for ind in pop:
        fitness_val = w1 * ind.ZC / std_C + w2 * ind.ZT / std_T + ind.penalty
        ind.fitness.values = (fitness_val,)

# ==============================
# 遗传算子
# ==============================
toolbox.register("mate", tools.cxTwoPoint)

def mutate_bound(ind, mu_R=0, sigma_R=100, mu_E=0, sigma_E=5e4, indpb=0.1):
    for i in range(len(ind)):
        if random.random() < indpb:
            if i < K*TMAX:
                ind[i] += int(round(random.gauss(mu_R, sigma_R)))
                ind[i] = max(0, min(L_max, ind[i]))
            else:
                ind[i] += random.gauss(mu_E, sigma_E)
                ind[i] = max(0, min(Cap_lift, ind[i]))
    return ind,

toolbox.register("mutate", mutate_bound)
toolbox.register("select", tools.selTournament, tournsize=3)

# %%
# ==============================
# 修改后的主程序 - 添加数据收集功能
# ==============================
def main_with_history():
    pop = toolbox.population(n=100)
    NGEN = 700
    CXPB = 0.7
    MUTPB = 0.2
    
    # 用于存储历史数据的列表
    history = {
        'gen': [],           # 代数
        'best_fitness': [],  # 最佳适应度
        'best_ZC': [],       # 最佳成本
        'best_ZT': [],       # 最佳工期
        'avg_ZC': [],        # 平均成本
        'avg_ZT': [],        # 平均工期
        'pop_ZC': [],        # 每代所有个体的成本（用于帕累托图）
        'pop_ZT': []         # 每代所有个体的工期（用于帕累托图）
    }
    
    assign_fitness(pop)
    
    for gen in range(NGEN):
        offspring = toolbox.select(pop, len(pop))
        offspring = list(map(toolbox.clone, offspring))
        
        # 交叉
        for c1, c2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < CXPB:
                toolbox.mate(c1, c2)
                del c1.fitness.values, c2.fitness.values
        
        # 变异
        for ind in offspring:
            if random.random() < MUTPB:
                toolbox.mutate(ind)
                del ind.fitness.values
        
        assign_fitness(offspring)
        pop[:] = offspring
        
        best = tools.selBest(pop, 1)[0]
        total_transported = np.sum(best[:K*TMAX])*Cap_rocket + np.sum(best[K*TMAX:])
        
        # 收集当前代的数据
        ZC_list = [ind.ZC for ind in pop]
        ZT_list = [ind.ZT for ind in pop]
        
        history['gen'].append(gen)
        history['best_fitness'].append(best.fitness.values[0])
        history['best_ZC'].append(best.ZC)
        history['best_ZT'].append(best.ZT)
        history['avg_ZC'].append(np.mean(ZC_list))
        history['avg_ZT'].append(np.mean(ZT_list))
        history['pop_ZC'].append(ZC_list)  # 保存整个种群的成本
        history['pop_ZT'].append(ZT_list)  # 保存整个种群的工期
        
        print(f"Gen {gen}: Z={best.fitness.values[0]:.3e}, "
              f"ZC={best.ZC:.3e}, ZT={best.ZT}, TotalTransport={total_transported:.1e}")
    
    return tools.selBest(pop, 1)[0], history

# %%
# ==============================
# 运行 GA
# ==============================
best_ind, history = main_with_history()

R = np.array(best_ind[:K*TMAX]).reshape(K, TMAX)
E = np.array(best_ind[K*TMAX:]).reshape(P, TMAX)

ROCKET = pd.DataFrame(R)
ELEVATOR = pd.DataFrame(E)
ROCKET.to_excel((r"D:\USELESS\数据分析学习\数学建模学习\2026美赛\B\PROB01\ROCKET1.xlsx"))
ELEVATOR.to_excel((r"D:\USELESS\数据分析学习\数学建模学习\2026美赛\B\PROB01\ELEVATOR1.xlsx"))
print("最终总运输量 =", np.sum(R)*Cap_rocket + np.sum(E))
print('火箭运输量 = ', np.sum(R)*Cap_rocket)
print('太空电梯运输量 = ', np.sum(E))



K, TMAX = R.shape
P = E.shape[0]

# 计算每年总运输量
yearly_transport = np.array([R[:, t].sum()*Cap_rocket + E[:, t].sum() for t in range(TMAX)])

# 按年份运输量从大到小排序
sorted_idx = np.argsort(-yearly_transport)

# 初始化新的矩阵
R_new = np.zeros_like(R)
E_new = np.zeros_like(E)

transported = 0
ZT_new = 0

for t_new, t_old in enumerate(sorted_idx):
    # 尽量保持原有分配比例，但不超过上限
    R_year = np.minimum(R[:, t_old], L_max)
    E_year = np.minimum(E[:, t_old], Cap_lift)

    # 计算这一年的运输量
    transported += R_year.sum()*Cap_rocket + E_year.sum()
    
    # 如果运输量超过 D_total，则按比例缩减这一年的运输量
    if transported > D_total:
        excess = transported - D_total
        # 按比例缩减火箭和电梯
        total_year = R_year.sum()*Cap_rocket + E_year.sum()
        if total_year > 0:
            ratio = (total_year - excess) / total_year
            R_year = np.floor(R_year * ratio)  # 保留整数
            E_year = E_year * ratio
        transported = D_total
        ZT_new = t_new + 1
        R_new[:, t_new] = R_year
        E_new[:, t_new] = E_year
        break
    
    R_new[:, t_new] = R_year
    E_new[:, t_new] = E_year
    ZT_new = t_new + 1

print(f"压缩后最早完成 D_total 的年份 ZT_new = {ZT_new}")
print(f"压缩后总运输量 = {transported}")

# 修正：正确的压缩后总成本计算
rocket_tons_new = np.sum(R_new[:, :ZT_new]) * Cap_rocket
lift_tons_new = np.sum(E_new[:, :ZT_new])
ZC_new = Cost_rocket * rocket_tons_new + Cost_lift * lift_tons_new

print(f"压缩后总成本 = {ZC_new:.3e}")
print(f"火箭总运输量 = {R_new.sum()*Cap_rocket}")
print(f"电梯总运输量 = {E_new.sum()}")


R = np.array(best_ind[:K*TMAX]).reshape(K, TMAX)
E = np.array(best_ind[K*TMAX:]).reshape(P, TMAX)

ROCKET = pd.DataFrame(R)
ELEVATOR = pd.DataFrame(E)

ROCKET.to_excel((r"D:\USELESS\数据分析学习\数学建模学习\2026美赛\B\PROB01\ROCKET_final.xlsx"))
ELEVATOR.to_excel((r"D:\USELESS\数据分析学习\数学建模学习\2026美赛\B\PROB01\_final.xlsx"))
# Out:
# Gen 0: Z=1.235e+02, ZC=3.010e+13, ZT=196, TotalTransport=1.0e+08
# Gen 1: Z=1.156e+02, ZC=3.022e+13, ZT=195, TotalTransport=1.0e+08
# Gen 2: Z=1.247e+02, ZC=3.005e+13, ZT=195, TotalTransport=1.0e+08
# Gen 3: Z=1.081e+02, ZC=3.013e+13, ZT=194, TotalTransport=1.0e+08
# Gen 4: Z=1.138e+02, ZC=3.018e+13, ZT=192, TotalTransport=1.0e+08
# Gen 5: Z=1.095e+02, ZC=2.992e+13, ZT=194, TotalTransport=1.0e+08
# Gen 6: Z=9.616e+01, ZC=3.017e+13, ZT=192, TotalTransport=1.0e+08
# Gen 7: Z=1.024e+02, ZC=3.017e+13, ZT=191, TotalTransport=1.0e+08
# Gen 8: Z=1.004e+02, ZC=2.957e+13, ZT=194, TotalTransport=1.0e+08
# Gen 9: Z=9.934e+01, ZC=2.990e+13, ZT=192, TotalTransport=1.0e+08
# Gen 10: Z=1.158e+02, ZC=2.969e+13, ZT=193, TotalTransport=1.0e+08
# Gen 11: Z=1.278e+02, ZC=2.975e+13, ZT=192, TotalTransport=1.0e+08
# Gen 12: Z=1.309e+02, ZC=2.975e+13, ZT=192, TotalTransport=1.0e+08
# Gen 13: Z=1.336e+02, ZC=2.980e+13, ZT=191, TotalTransport=1.0e+08
# Gen 14: Z=1.315e+02, ZC=2.965e+13, ZT=191, TotalTransport=1.0e+08
# Gen 15: Z=1.580e+02, ZC=2.965e+13, ZT=191, TotalTransport=1.0e+08
# Gen 16: Z=1.484e+02, ZC=2.952e+13, ZT=191, TotalTransport=1.0e+08
# Gen 17: Z=1.658e+02, ZC=2.953e+13, ZT=191, TotalTransport=1.0e+08
# Gen 18: Z=1.761e+02, ZC=2.927e+13, ZT=192, TotalTransport=1.0e+08
# Gen 19: Z=1.596e+02, ZC=2.937e+13, ZT=191, TotalTransport=1.0e+08
# Gen 20: Z=1.422e+02, ZC=2.960e+13, ZT=189, TotalTransport=1.1e+08
# Gen 21: Z=1.411e+02, ZC=2.962e+13, ZT=189, TotalTransport=1.1e+08
# Gen 22: Z=1.441e+02, ZC=2.925e+13, ZT=190, TotalTransport=1.0e+08
# Gen 23: Z=1.532e+02, ZC=2.954e+13, ZT=188, TotalTransport=1.1e+08
# Gen 24: Z=1.662e+02, ZC=2.958e+13, ZT=188, TotalTransport=1.1e+08
# Gen 25: Z=1.543e+02, ZC=2.950e+13, ZT=188, TotalTransport=1.1e+08
# Gen 26: Z=1.492e+02, ZC=2.965e+13, ZT=187, TotalTransport=1.1e+08
# Gen 27: Z=1.626e+02, ZC=2.958e+13, ZT=187, TotalTransport=1.1e+08
# Gen 28: Z=1.842e+02, ZC=2.932e+13, ZT=188, TotalTransport=1.1e+08
# Gen 29: Z=1.948e+02, ZC=2.924e+13, ZT=188, TotalTransport=1.1e+08
# Gen 30: Z=1.761e+02, ZC=2.928e+13, ZT=188, TotalTransport=1.1e+08
# Gen 31: Z=1.854e+02, ZC=2.935e+13, ZT=187, TotalTransport=1.1e+08
# Gen 32: Z=2.310e+02, ZC=2.931e+13, ZT=187, TotalTransport=1.1e+08
# Gen 33: Z=2.514e+02, ZC=2.906e+13, ZT=188, TotalTransport=1.1e+08
# Gen 34: Z=2.566e+02, ZC=2.920e+13, ZT=187, TotalTransport=1.1e+08
# Gen 35: Z=2.178e+02, ZC=2.925e+13, ZT=187, TotalTransport=1.1e+08
# Gen 36: Z=1.918e+02, ZC=2.914e+13, ZT=187, TotalTransport=1.1e+08
# Gen 37: Z=1.902e+02, ZC=2.950e+13, ZT=185, TotalTransport=1.1e+08
# Gen 38: Z=1.864e+02, ZC=2.896e+13, ZT=188, TotalTransport=1.1e+08
# Gen 39: Z=1.886e+02, ZC=2.915e+13, ZT=186, TotalTransport=1.1e+08
# Gen 40: Z=1.881e+02, ZC=2.921e+13, ZT=186, TotalTransport=1.1e+08
# Gen 41: Z=2.021e+02, ZC=2.916e+13, ZT=186, TotalTransport=1.1e+08
# Gen 42: Z=2.117e+02, ZC=2.904e+13, ZT=186, TotalTransport=1.1e+08
# Gen 43: Z=2.077e+02, ZC=2.902e+13, ZT=186, TotalTransport=1.1e+08
# Gen 44: Z=2.023e+02, ZC=2.917e+13, ZT=185, TotalTransport=1.1e+08
# Gen 45: Z=2.059e+02, ZC=2.915e+13, ZT=185, TotalTransport=1.1e+08
# Gen 46: Z=1.937e+02, ZC=2.899e+13, ZT=185, TotalTransport=1.1e+08
# Gen 47: Z=2.249e+02, ZC=2.895e+13, ZT=185, TotalTransport=1.1e+08
# Gen 48: Z=1.991e+02, ZC=2.895e+13, ZT=185, TotalTransport=1.1e+08
# Gen 49: Z=2.149e+02, ZC=2.892e+13, ZT=185, TotalTransport=1.1e+08
# Gen 50: Z=2.150e+02, ZC=2.895e+13, ZT=185, TotalTransport=1.1e+08
# Gen 51: Z=2.133e+02, ZC=2.904e+13, ZT=184, TotalTransport=1.1e+08
# Gen 52: Z=2.113e+02, ZC=2.902e+13, ZT=184, TotalTransport=1.1e+08
# Gen 53: Z=2.223e+02, ZC=2.898e+13, ZT=184, TotalTransport=1.1e+08
# Gen 54: Z=2.163e+02, ZC=2.884e+13, ZT=184, TotalTransport=1.1e+08
# Gen 55: Z=2.160e+02, ZC=2.883e+13, ZT=184, TotalTransport=1.1e+08
# Gen 56: Z=2.122e+02, ZC=2.893e+13, ZT=183, TotalTransport=1.1e+08
# Gen 57: Z=2.451e+02, ZC=2.893e+13, ZT=183, TotalTransport=1.1e+08
# Gen 58: Z=2.783e+02, ZC=2.888e+13, ZT=183, TotalTransport=1.1e+08
# Gen 59: Z=2.595e+02, ZC=2.875e+13, ZT=184, TotalTransport=1.1e+08
# Gen 60: Z=2.674e+02, ZC=2.908e+13, ZT=182, TotalTransport=1.1e+08
# Gen 61: Z=2.402e+02, ZC=2.907e+13, ZT=182, TotalTransport=1.1e+08
# Gen 62: Z=2.397e+02, ZC=2.878e+13, ZT=183, TotalTransport=1.1e+08
# Gen 63: Z=2.189e+02, ZC=2.876e+13, ZT=183, TotalTransport=1.1e+08
# Gen 64: Z=2.266e+02, ZC=2.893e+13, ZT=182, TotalTransport=1.1e+08
# Gen 65: Z=2.565e+02, ZC=2.885e+13, ZT=182, TotalTransport=1.1e+08
# Gen 66: Z=2.723e+02, ZC=2.876e+13, ZT=182, TotalTransport=1.1e+08
# Gen 67: Z=2.868e+02, ZC=2.891e+13, ZT=182, TotalTransport=1.1e+08
# Gen 68: Z=2.774e+02, ZC=2.878e+13, ZT=182, TotalTransport=1.1e+08
# Gen 69: Z=2.761e+02, ZC=2.874e+13, ZT=182, TotalTransport=1.1e+08
# Gen 70: Z=2.747e+02, ZC=2.888e+13, ZT=181, TotalTransport=1.1e+08
# Gen 71: Z=2.866e+02, ZC=2.864e+13, ZT=182, TotalTransport=1.1e+08
# Gen 72: Z=2.807e+02, ZC=2.860e+13, ZT=182, TotalTransport=1.1e+08
# Gen 73: Z=2.498e+02, ZC=2.880e+13, ZT=181, TotalTransport=1.1e+08
# Gen 74: Z=2.253e+02, ZC=2.879e+13, ZT=181, TotalTransport=1.1e+08
# Gen 75: Z=2.440e+02, ZC=2.878e+13, ZT=181, TotalTransport=1.1e+08
# Gen 76: Z=2.400e+02, ZC=2.891e+13, ZT=180, TotalTransport=1.1e+08
# Gen 77: Z=2.246e+02, ZC=2.895e+13, ZT=179, TotalTransport=1.1e+08
# Gen 78: Z=2.024e+02, ZC=2.896e+13, ZT=179, TotalTransport=1.1e+08
# Gen 79: Z=1.721e+02, ZC=2.871e+13, ZT=180, TotalTransport=1.1e+08
# Gen 80: Z=1.764e+02, ZC=2.863e+13, ZT=180, TotalTransport=1.1e+08
# Gen 81: Z=1.649e+02, ZC=2.863e+13, ZT=180, TotalTransport=1.1e+08
# Gen 82: Z=1.924e+02, ZC=2.863e+13, ZT=180, TotalTransport=1.1e+08
# Gen 83: Z=2.192e+02, ZC=2.863e+13, ZT=180, TotalTransport=1.1e+08
# Gen 84: Z=2.452e+02, ZC=2.861e+13, ZT=180, TotalTransport=1.1e+08
# Gen 85: Z=2.719e+02, ZC=2.861e+13, ZT=180, TotalTransport=1.1e+08
# Gen 86: Z=2.972e+02, ZC=2.858e+13, ZT=180, TotalTransport=1.1e+08
# Gen 87: Z=2.880e+02, ZC=2.874e+13, ZT=179, TotalTransport=1.1e+08
# Gen 88: Z=2.664e+02, ZC=2.872e+13, ZT=179, TotalTransport=1.1e+08
# Gen 89: Z=2.593e+02, ZC=2.865e+13, ZT=179, TotalTransport=1.1e+08
# Gen 90: Z=2.401e+02, ZC=2.865e+13, ZT=179, TotalTransport=1.1e+08
# Gen 91: Z=2.790e+02, ZC=2.868e+13, ZT=179, TotalTransport=1.1e+08
# Gen 92: Z=2.523e+02, ZC=2.867e+13, ZT=179, TotalTransport=1.1e+08
# Gen 93: Z=2.595e+02, ZC=2.865e+13, ZT=179, TotalTransport=1.1e+08
# Gen 94: Z=3.008e+02, ZC=2.875e+13, ZT=178, TotalTransport=1.1e+08
# Gen 95: Z=2.833e+02, ZC=2.879e+13, ZT=178, TotalTransport=1.1e+08
# Gen 96: Z=2.977e+02, ZC=2.874e+13, ZT=178, TotalTransport=1.1e+08
# Gen 97: Z=2.716e+02, ZC=2.874e+13, ZT=178, TotalTransport=1.1e+08
# Gen 98: Z=2.847e+02, ZC=2.874e+13, ZT=178, TotalTransport=1.1e+08
# Gen 99: Z=2.529e+02, ZC=2.874e+13, ZT=178, TotalTransport=1.1e+08
# Gen 100: Z=2.764e+02, ZC=2.873e+13, ZT=178, TotalTransport=1.1e+08
# Gen 101: Z=2.920e+02, ZC=2.873e+13, ZT=178, TotalTransport=1.1e+08
# Gen 102: Z=3.215e+02, ZC=2.872e+13, ZT=178, TotalTransport=1.1e+08
# Gen 103: Z=3.383e+02, ZC=2.852e+13, ZT=179, TotalTransport=1.1e+08
# Gen 104: Z=2.724e+02, ZC=2.871e+13, ZT=178, TotalTransport=1.1e+08
# Gen 105: Z=2.939e+02, ZC=2.870e+13, ZT=178, TotalTransport=1.1e+08
# Gen 106: Z=2.862e+02, ZC=2.870e+13, ZT=178, TotalTransport=1.1e+08
# Gen 107: Z=3.098e+02, ZC=2.870e+13, ZT=178, TotalTransport=1.1e+08
# Gen 108: Z=2.981e+02, ZC=2.866e+13, ZT=178, TotalTransport=1.1e+08
# Gen 109: Z=3.030e+02, ZC=2.847e+13, ZT=179, TotalTransport=1.1e+08
# Gen 110: Z=2.612e+02, ZC=2.866e+13, ZT=178, TotalTransport=1.1e+08
# Gen 111: Z=2.941e+02, ZC=2.864e+13, ZT=178, TotalTransport=1.1e+08
# Gen 112: Z=2.815e+02, ZC=2.857e+13, ZT=178, TotalTransport=1.1e+08
# Gen 113: Z=2.841e+02, ZC=2.856e+13, ZT=178, TotalTransport=1.1e+08
# Gen 114: Z=2.929e+02, ZC=2.878e+13, ZT=177, TotalTransport=1.1e+08
# Gen 115: Z=2.838e+02, ZC=2.860e+13, ZT=178, TotalTransport=1.1e+08
# Gen 116: Z=3.651e+02, ZC=2.857e+13, ZT=178, TotalTransport=1.1e+08
# Gen 117: Z=3.398e+02, ZC=2.867e+13, ZT=177, TotalTransport=1.1e+08
# Gen 118: Z=2.994e+02, ZC=2.862e+13, ZT=177, TotalTransport=1.1e+08
# Gen 119: Z=2.894e+02, ZC=2.862e+13, ZT=177, TotalTransport=1.1e+08
# Gen 120: Z=2.924e+02, ZC=2.861e+13, ZT=177, TotalTransport=1.1e+08
# Gen 121: Z=3.192e+02, ZC=2.861e+13, ZT=177, TotalTransport=1.1e+08
# Gen 122: Z=3.142e+02, ZC=2.852e+13, ZT=177, TotalTransport=1.1e+08
# Gen 123: Z=2.904e+02, ZC=2.852e+13, ZT=177, TotalTransport=1.1e+08
# Gen 124: Z=2.897e+02, ZC=2.871e+13, ZT=176, TotalTransport=1.1e+08
# Gen 125: Z=2.909e+02, ZC=2.873e+13, ZT=176, TotalTransport=1.1e+08
# Gen 126: Z=3.648e+02, ZC=2.858e+13, ZT=176, TotalTransport=1.1e+08
# Gen 127: Z=3.223e+02, ZC=2.858e+13, ZT=176, TotalTransport=1.1e+08
# Gen 128: Z=3.246e+02, ZC=2.866e+13, ZT=176, TotalTransport=1.1e+08
# Gen 129: Z=3.069e+02, ZC=2.860e+13, ZT=176, TotalTransport=1.1e+08
# Gen 130: Z=3.462e+02, ZC=2.858e+13, ZT=176, TotalTransport=1.1e+08
# Gen 131: Z=2.584e+02, ZC=2.853e+13, ZT=176, TotalTransport=1.1e+08
# Gen 132: Z=2.359e+02, ZC=2.851e+13, ZT=176, TotalTransport=1.1e+08
# Gen 133: Z=2.294e+02, ZC=2.851e+13, ZT=176, TotalTransport=1.1e+08
# Gen 134: Z=2.264e+02, ZC=2.853e+13, ZT=176, TotalTransport=1.1e+08
# Gen 135: Z=2.866e+02, ZC=2.864e+13, ZT=175, TotalTransport=1.1e+08
# Gen 136: Z=2.957e+02, ZC=2.864e+13, ZT=175, TotalTransport=1.1e+08
# Gen 137: Z=2.885e+02, ZC=2.846e+13, ZT=176, TotalTransport=1.1e+08
# Gen 138: Z=3.174e+02, ZC=2.858e+13, ZT=175, TotalTransport=1.1e+08
# Gen 139: Z=2.639e+02, ZC=2.858e+13, ZT=175, TotalTransport=1.1e+08
# Gen 140: Z=2.702e+02, ZC=2.857e+13, ZT=175, TotalTransport=1.1e+08
# Gen 141: Z=2.607e+02, ZC=2.859e+13, ZT=174, TotalTransport=1.1e+08
# Gen 142: Z=2.243e+02, ZC=2.852e+13, ZT=174, TotalTransport=1.1e+08
# Gen 143: Z=2.224e+02, ZC=2.850e+13, ZT=174, TotalTransport=1.1e+08
# Gen 144: Z=2.112e+02, ZC=2.850e+13, ZT=174, TotalTransport=1.1e+08
# Gen 145: Z=1.951e+02, ZC=2.850e+13, ZT=174, TotalTransport=1.1e+08
# Gen 146: Z=1.942e+02, ZC=2.864e+13, ZT=173, TotalTransport=1.1e+08
# Gen 147: Z=1.958e+02, ZC=2.856e+13, ZT=173, TotalTransport=1.1e+08
# Gen 148: Z=2.064e+02, ZC=2.843e+13, ZT=174, TotalTransport=1.1e+08
# Gen 149: Z=2.107e+02, ZC=2.855e+13, ZT=173, TotalTransport=1.1e+08
# Gen 150: Z=2.007e+02, ZC=2.855e+13, ZT=173, TotalTransport=1.1e+08
# Gen 151: Z=2.078e+02, ZC=2.853e+13, ZT=173, TotalTransport=1.1e+08
# Gen 152: Z=1.828e+02, ZC=2.846e+13, ZT=173, TotalTransport=1.1e+08
# Gen 153: Z=2.214e+02, ZC=2.848e+13, ZT=173, TotalTransport=1.1e+08
# Gen 154: Z=2.445e+02, ZC=2.843e+13, ZT=173, TotalTransport=1.1e+08
# Gen 155: Z=2.306e+02, ZC=2.857e+13, ZT=172, TotalTransport=1.1e+08
# Gen 156: Z=2.109e+02, ZC=2.835e+13, ZT=173, TotalTransport=1.1e+08
# Gen 157: Z=2.146e+02, ZC=2.835e+13, ZT=173, TotalTransport=1.1e+08
# Gen 158: Z=2.206e+02, ZC=2.851e+13, ZT=172, TotalTransport=1.1e+08
# Gen 159: Z=2.207e+02, ZC=2.851e+13, ZT=172, TotalTransport=1.1e+08
# Gen 160: Z=2.366e+02, ZC=2.847e+13, ZT=172, TotalTransport=1.1e+08
# Gen 161: Z=2.474e+02, ZC=2.847e+13, ZT=172, TotalTransport=1.1e+08
# Gen 162: Z=2.670e+02, ZC=2.846e+13, ZT=172, TotalTransport=1.1e+08
# Gen 163: Z=2.683e+02, ZC=2.845e+13, ZT=172, TotalTransport=1.1e+08
# Gen 164: Z=3.120e+02, ZC=2.845e+13, ZT=172, TotalTransport=1.1e+08
# Gen 165: Z=2.781e+02, ZC=2.843e+13, ZT=172, TotalTransport=1.1e+08
# Gen 166: Z=3.193e+02, ZC=2.839e+13, ZT=172, TotalTransport=1.1e+08
# Gen 167: Z=2.811e+02, ZC=2.839e+13, ZT=172, TotalTransport=1.1e+08
# Gen 168: Z=2.759e+02, ZC=2.837e+13, ZT=172, TotalTransport=1.1e+08
# Gen 169: Z=3.060e+02, ZC=2.837e+13, ZT=172, TotalTransport=1.1e+08
# Gen 170: Z=3.007e+02, ZC=2.832e+13, ZT=172, TotalTransport=1.1e+08
# Gen 171: Z=3.650e+02, ZC=2.847e+13, ZT=171, TotalTransport=1.1e+08
# Gen 172: Z=3.158e+02, ZC=2.832e+13, ZT=172, TotalTransport=1.1e+08
# Gen 173: Z=3.514e+02, ZC=2.829e+13, ZT=172, TotalTransport=1.1e+08
# Gen 174: Z=2.675e+02, ZC=2.826e+13, ZT=172, TotalTransport=1.1e+08
# Gen 175: Z=2.941e+02, ZC=2.826e+13, ZT=172, TotalTransport=1.1e+08
# Gen 176: Z=3.508e+02, ZC=2.826e+13, ZT=172, TotalTransport=1.1e+08
# Gen 177: Z=3.649e+02, ZC=2.838e+13, ZT=171, TotalTransport=1.1e+08
# Gen 178: Z=3.363e+02, ZC=2.838e+13, ZT=171, TotalTransport=1.1e+08
# Gen 179: Z=2.664e+02, ZC=2.838e+13, ZT=171, TotalTransport=1.1e+08
# Gen 180: Z=3.174e+02, ZC=2.838e+13, ZT=171, TotalTransport=1.1e+08
# Gen 181: Z=3.158e+02, ZC=2.836e+13, ZT=171, TotalTransport=1.1e+08
# Gen 182: Z=3.289e+02, ZC=2.837e+13, ZT=171, TotalTransport=1.1e+08
# Gen 183: Z=3.296e+02, ZC=2.837e+13, ZT=171, TotalTransport=1.1e+08
# Gen 184: Z=3.363e+02, ZC=2.837e+13, ZT=171, TotalTransport=1.1e+08
# Gen 185: Z=3.822e+02, ZC=2.836e+13, ZT=171, TotalTransport=1.1e+08
# Gen 186: Z=3.674e+02, ZC=2.836e+13, ZT=171, TotalTransport=1.1e+08
# Gen 187: Z=4.919e+02, ZC=2.836e+13, ZT=171, TotalTransport=1.1e+08
# Gen 188: Z=4.396e+02, ZC=2.856e+13, ZT=170, TotalTransport=1.1e+08
# Gen 189: Z=4.509e+02, ZC=2.836e+13, ZT=171, TotalTransport=1.1e+08
# Gen 190: Z=4.051e+02, ZC=2.834e+13, ZT=171, TotalTransport=1.1e+08
# Gen 191: Z=4.446e+02, ZC=2.834e+13, ZT=171, TotalTransport=1.1e+08
# Gen 192: Z=3.495e+02, ZC=2.832e+13, ZT=171, TotalTransport=1.1e+08
# Gen 193: Z=3.959e+02, ZC=2.834e+13, ZT=171, TotalTransport=1.1e+08
# Gen 194: Z=3.887e+02, ZC=2.834e+13, ZT=171, TotalTransport=1.1e+08
# Gen 195: Z=3.953e+02, ZC=2.833e+13, ZT=171, TotalTransport=1.1e+08
# Gen 196: Z=3.725e+02, ZC=2.854e+13, ZT=170, TotalTransport=1.1e+08
# Gen 197: Z=3.312e+02, ZC=2.830e+13, ZT=171, TotalTransport=1.1e+08
# Gen 198: Z=3.984e+02, ZC=2.851e+13, ZT=170, TotalTransport=1.1e+08
# Gen 199: Z=3.911e+02, ZC=2.831e+13, ZT=171, TotalTransport=1.1e+08
# Gen 200: Z=4.115e+02, ZC=2.830e+13, ZT=171, TotalTransport=1.1e+08
# Gen 201: Z=3.673e+02, ZC=2.828e+13, ZT=171, TotalTransport=1.1e+08
# Gen 202: Z=3.504e+02, ZC=2.828e+13, ZT=171, TotalTransport=1.1e+08
# Gen 203: Z=3.595e+02, ZC=2.850e+13, ZT=170, TotalTransport=1.1e+08
# Gen 204: Z=3.384e+02, ZC=2.848e+13, ZT=170, TotalTransport=1.1e+08
# Gen 205: Z=3.278e+02, ZC=2.842e+13, ZT=170, TotalTransport=1.1e+08
# Gen 206: Z=3.432e+02, ZC=2.828e+13, ZT=171, TotalTransport=1.1e+08
# Gen 207: Z=3.278e+02, ZC=2.828e+13, ZT=171, TotalTransport=1.1e+08
# Gen 208: Z=3.525e+02, ZC=2.826e+13, ZT=171, TotalTransport=1.1e+08
# Gen 209: Z=4.407e+02, ZC=2.847e+13, ZT=170, TotalTransport=1.1e+08
# Gen 210: Z=3.679e+02, ZC=2.824e+13, ZT=171, TotalTransport=1.1e+08
# Gen 211: Z=4.083e+02, ZC=2.823e+13, ZT=171, TotalTransport=1.1e+08
# Gen 212: Z=3.479e+02, ZC=2.834e+13, ZT=170, TotalTransport=1.1e+08
# Gen 213: Z=3.434e+02, ZC=2.830e+13, ZT=170, TotalTransport=1.1e+08
# Gen 214: Z=3.190e+02, ZC=2.826e+13, ZT=170, TotalTransport=1.1e+08
# Gen 215: Z=2.790e+02, ZC=2.828e+13, ZT=170, TotalTransport=1.1e+08
# Gen 216: Z=2.511e+02, ZC=2.826e+13, ZT=170, TotalTransport=1.1e+08
# Gen 217: Z=3.281e+02, ZC=2.821e+13, ZT=170, TotalTransport=1.1e+08
# Gen 218: Z=3.573e+02, ZC=2.821e+13, ZT=170, TotalTransport=1.1e+08
# Gen 219: Z=4.810e+02, ZC=2.819e+13, ZT=170, TotalTransport=1.1e+08
# Gen 220: Z=3.707e+02, ZC=2.819e+13, ZT=170, TotalTransport=1.1e+08
# Gen 221: Z=3.148e+02, ZC=2.819e+13, ZT=170, TotalTransport=1.1e+08
# Gen 222: Z=3.377e+02, ZC=2.819e+13, ZT=170, TotalTransport=1.1e+08
# Gen 223: Z=4.038e+02, ZC=2.819e+13, ZT=170, TotalTransport=1.1e+08
# Gen 224: Z=3.534e+02, ZC=2.818e+13, ZT=170, TotalTransport=1.1e+08
# Gen 225: Z=3.444e+02, ZC=2.818e+13, ZT=170, TotalTransport=1.1e+08
# Gen 226: Z=4.245e+02, ZC=2.817e+13, ZT=170, TotalTransport=1.1e+08
# Gen 227: Z=4.097e+02, ZC=2.812e+13, ZT=170, TotalTransport=1.1e+08
# Gen 228: Z=4.455e+02, ZC=2.815e+13, ZT=170, TotalTransport=1.1e+08
# Gen 229: Z=4.278e+02, ZC=2.815e+13, ZT=170, TotalTransport=1.1e+08
# Gen 230: Z=4.353e+02, ZC=2.828e+13, ZT=169, TotalTransport=1.1e+08
# Gen 231: Z=3.833e+02, ZC=2.812e+13, ZT=170, TotalTransport=1.1e+08
# Gen 232: Z=3.454e+02, ZC=2.812e+13, ZT=170, TotalTransport=1.1e+08
# Gen 233: Z=4.599e+02, ZC=2.812e+13, ZT=170, TotalTransport=1.1e+08
# Gen 234: Z=3.998e+02, ZC=2.812e+13, ZT=170, TotalTransport=1.1e+08
# Gen 235: Z=3.755e+02, ZC=2.822e+13, ZT=169, TotalTransport=1.1e+08
# Gen 236: Z=4.665e+02, ZC=2.822e+13, ZT=169, TotalTransport=1.1e+08
# Gen 237: Z=3.860e+02, ZC=2.822e+13, ZT=169, TotalTransport=1.1e+08
# Gen 238: Z=4.209e+02, ZC=2.822e+13, ZT=169, TotalTransport=1.1e+08
# Gen 239: Z=4.006e+02, ZC=2.817e+13, ZT=169, TotalTransport=1.1e+08
# Gen 240: Z=3.088e+02, ZC=2.815e+13, ZT=169, TotalTransport=1.1e+08
# Gen 241: Z=3.157e+02, ZC=2.815e+13, ZT=169, TotalTransport=1.1e+08
# Gen 242: Z=3.068e+02, ZC=2.815e+13, ZT=169, TotalTransport=1.1e+08
# Gen 243: Z=2.946e+02, ZC=2.815e+13, ZT=169, TotalTransport=1.1e+08
# Gen 244: Z=3.165e+02, ZC=2.815e+13, ZT=169, TotalTransport=1.1e+08
# Gen 245: Z=4.073e+02, ZC=2.815e+13, ZT=169, TotalTransport=1.1e+08
# Gen 246: Z=3.698e+02, ZC=2.814e+13, ZT=169, TotalTransport=1.1e+08
# Gen 247: Z=4.627e+02, ZC=2.814e+13, ZT=169, TotalTransport=1.1e+08
# Gen 248: Z=4.564e+02, ZC=2.814e+13, ZT=169, TotalTransport=1.1e+08
# Gen 249: Z=3.546e+02, ZC=2.814e+13, ZT=169, TotalTransport=1.1e+08
# Gen 250: Z=3.163e+02, ZC=2.814e+13, ZT=169, TotalTransport=1.1e+08
# Gen 251: Z=3.495e+02, ZC=2.814e+13, ZT=169, TotalTransport=1.1e+08
# Gen 252: Z=3.980e+02, ZC=2.834e+13, ZT=168, TotalTransport=1.1e+08
# Gen 253: Z=3.371e+02, ZC=2.834e+13, ZT=168, TotalTransport=1.1e+08
# Gen 254: Z=4.023e+02, ZC=2.812e+13, ZT=169, TotalTransport=1.1e+08
# Gen 255: Z=3.660e+02, ZC=2.834e+13, ZT=168, TotalTransport=1.1e+08
# Gen 256: Z=3.332e+02, ZC=2.812e+13, ZT=169, TotalTransport=1.1e+08
# Gen 257: Z=3.586e+02, ZC=2.812e+13, ZT=169, TotalTransport=1.1e+08
# Gen 258: Z=3.890e+02, ZC=2.812e+13, ZT=169, TotalTransport=1.1e+08
# Gen 259: Z=3.581e+02, ZC=2.809e+13, ZT=169, TotalTransport=1.1e+08
# Gen 260: Z=4.194e+02, ZC=2.809e+13, ZT=169, TotalTransport=1.1e+08
# Gen 261: Z=4.039e+02, ZC=2.809e+13, ZT=169, TotalTransport=1.1e+08
# Gen 262: Z=3.943e+02, ZC=2.809e+13, ZT=169, TotalTransport=1.1e+08
# Gen 263: Z=3.349e+02, ZC=2.809e+13, ZT=169, TotalTransport=1.1e+08
# Gen 264: Z=4.037e+02, ZC=2.809e+13, ZT=169, TotalTransport=1.1e+08
# Gen 265: Z=3.962e+02, ZC=2.808e+13, ZT=169, TotalTransport=1.1e+08
# Gen 266: Z=3.986e+02, ZC=2.809e+13, ZT=169, TotalTransport=1.1e+08
# Gen 267: Z=4.529e+02, ZC=2.809e+13, ZT=169, TotalTransport=1.1e+08
# Gen 268: Z=5.939e+02, ZC=2.806e+13, ZT=169, TotalTransport=1.1e+08
# Gen 269: Z=3.659e+02, ZC=2.805e+13, ZT=169, TotalTransport=1.1e+08
# Gen 270: Z=4.305e+02, ZC=2.802e+13, ZT=169, TotalTransport=1.1e+08
# Gen 271: Z=3.938e+02, ZC=2.802e+13, ZT=169, TotalTransport=1.1e+08
# Gen 272: Z=3.668e+02, ZC=2.801e+13, ZT=169, TotalTransport=1.1e+08
# Gen 273: Z=4.144e+02, ZC=2.801e+13, ZT=169, TotalTransport=1.1e+08
# Gen 274: Z=3.621e+02, ZC=2.800e+13, ZT=169, TotalTransport=1.1e+08
# Gen 275: Z=3.577e+02, ZC=2.799e+13, ZT=169, TotalTransport=1.1e+08
# Gen 276: Z=4.246e+02, ZC=2.799e+13, ZT=169, TotalTransport=1.1e+08
# Gen 277: Z=3.884e+02, ZC=2.798e+13, ZT=169, TotalTransport=1.1e+08
# Gen 278: Z=4.035e+02, ZC=2.798e+13, ZT=169, TotalTransport=1.1e+08
# Gen 279: Z=3.964e+02, ZC=2.798e+13, ZT=169, TotalTransport=1.1e+08
# Gen 280: Z=3.921e+02, ZC=2.797e+13, ZT=169, TotalTransport=1.1e+08
# Gen 281: Z=3.750e+02, ZC=2.795e+13, ZT=169, TotalTransport=1.1e+08
# Gen 282: Z=3.876e+02, ZC=2.795e+13, ZT=169, TotalTransport=1.1e+08
# Gen 283: Z=4.066e+02, ZC=2.795e+13, ZT=169, TotalTransport=1.1e+08
# Gen 284: Z=4.933e+02, ZC=2.795e+13, ZT=169, TotalTransport=1.1e+08
# Gen 285: Z=3.652e+02, ZC=2.795e+13, ZT=169, TotalTransport=1.1e+08
# Gen 286: Z=3.545e+02, ZC=2.795e+13, ZT=169, TotalTransport=1.1e+08
# Gen 287: Z=4.212e+02, ZC=2.795e+13, ZT=169, TotalTransport=1.1e+08
# Gen 288: Z=4.616e+02, ZC=2.794e+13, ZT=169, TotalTransport=1.1e+08
# Gen 289: Z=4.254e+02, ZC=2.793e+13, ZT=169, TotalTransport=1.1e+08
# Gen 290: Z=3.974e+02, ZC=2.793e+13, ZT=169, TotalTransport=1.1e+08
# Gen 291: Z=4.214e+02, ZC=2.793e+13, ZT=169, TotalTransport=1.1e+08
# Gen 292: Z=4.520e+02, ZC=2.792e+13, ZT=169, TotalTransport=1.1e+08
# Gen 293: Z=5.440e+02, ZC=2.792e+13, ZT=169, TotalTransport=1.1e+08
# Gen 294: Z=4.195e+02, ZC=2.792e+13, ZT=169, TotalTransport=1.1e+08
# Gen 295: Z=4.378e+02, ZC=2.792e+13, ZT=169, TotalTransport=1.1e+08
# Gen 296: Z=4.729e+02, ZC=2.791e+13, ZT=169, TotalTransport=1.1e+08
# Gen 297: Z=4.552e+02, ZC=2.791e+13, ZT=169, TotalTransport=1.1e+08
# Gen 298: Z=3.781e+02, ZC=2.791e+13, ZT=169, TotalTransport=1.1e+08
# Gen 299: Z=5.027e+02, ZC=2.790e+13, ZT=169, TotalTransport=1.1e+08
# Gen 300: Z=4.685e+02, ZC=2.790e+13, ZT=169, TotalTransport=1.1e+08
# Gen 301: Z=3.741e+02, ZC=2.808e+13, ZT=168, TotalTransport=1.1e+08
# Gen 302: Z=4.078e+02, ZC=2.808e+13, ZT=168, TotalTransport=1.1e+08
# Gen 303: Z=3.837e+02, ZC=2.808e+13, ZT=168, TotalTransport=1.1e+08
# Gen 304: Z=3.758e+02, ZC=2.808e+13, ZT=168, TotalTransport=1.1e+08
# Gen 305: Z=3.429e+02, ZC=2.807e+13, ZT=168, TotalTransport=1.1e+08
# Gen 306: Z=3.192e+02, ZC=2.803e+13, ZT=168, TotalTransport=1.1e+08
# Gen 307: Z=3.407e+02, ZC=2.802e+13, ZT=168, TotalTransport=1.1e+08
# Gen 308: Z=3.368e+02, ZC=2.802e+13, ZT=168, TotalTransport=1.1e+08
# Gen 309: Z=3.180e+02, ZC=2.801e+13, ZT=168, TotalTransport=1.1e+08
# Gen 310: Z=2.900e+02, ZC=2.800e+13, ZT=168, TotalTransport=1.1e+08
# Gen 311: Z=2.488e+02, ZC=2.800e+13, ZT=168, TotalTransport=1.1e+08
# Gen 312: Z=2.994e+02, ZC=2.800e+13, ZT=168, TotalTransport=1.1e+08
# Gen 313: Z=2.729e+02, ZC=2.799e+13, ZT=168, TotalTransport=1.1e+08
# Gen 314: Z=3.446e+02, ZC=2.798e+13, ZT=168, TotalTransport=1.1e+08
# Gen 315: Z=2.995e+02, ZC=2.798e+13, ZT=168, TotalTransport=1.1e+08
# Gen 316: Z=3.504e+02, ZC=2.798e+13, ZT=168, TotalTransport=1.1e+08
# Gen 317: Z=3.861e+02, ZC=2.798e+13, ZT=168, TotalTransport=1.1e+08
# Gen 318: Z=4.177e+02, ZC=2.798e+13, ZT=168, TotalTransport=1.1e+08
# Gen 319: Z=3.859e+02, ZC=2.798e+13, ZT=168, TotalTransport=1.1e+08
# Gen 320: Z=4.669e+02, ZC=2.797e+13, ZT=168, TotalTransport=1.1e+08
# Gen 321: Z=4.894e+02, ZC=2.797e+13, ZT=168, TotalTransport=1.1e+08
# Gen 322: Z=3.895e+02, ZC=2.797e+13, ZT=168, TotalTransport=1.1e+08
# Gen 323: Z=3.122e+02, ZC=2.797e+13, ZT=168, TotalTransport=1.1e+08
# Gen 324: Z=3.982e+02, ZC=2.797e+13, ZT=168, TotalTransport=1.1e+08
# Gen 325: Z=4.081e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 326: Z=3.273e+02, ZC=2.796e+13, ZT=168, TotalTransport=1.1e+08
# Gen 327: Z=3.764e+02, ZC=2.796e+13, ZT=168, TotalTransport=1.1e+08
# Gen 328: Z=3.759e+02, ZC=2.796e+13, ZT=168, TotalTransport=1.1e+08
# Gen 329: Z=3.389e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 330: Z=4.031e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 331: Z=3.712e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 332: Z=4.138e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 333: Z=3.933e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 334: Z=3.665e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 335: Z=3.535e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 336: Z=4.307e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 337: Z=3.329e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 338: Z=3.758e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 339: Z=3.494e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 340: Z=5.512e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 341: Z=4.552e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 342: Z=4.414e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 343: Z=3.638e+02, ZC=2.815e+13, ZT=167, TotalTransport=1.1e+08
# Gen 344: Z=4.527e+02, ZC=2.815e+13, ZT=167, TotalTransport=1.1e+08
# Gen 345: Z=4.668e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 346: Z=4.749e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 347: Z=5.166e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 348: Z=4.306e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 349: Z=4.331e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 350: Z=3.582e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 351: Z=4.055e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 352: Z=4.035e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 353: Z=4.956e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 354: Z=4.011e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 355: Z=4.750e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 356: Z=4.550e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 357: Z=4.842e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 358: Z=3.938e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 359: Z=4.882e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 360: Z=4.337e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 361: Z=3.658e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 362: Z=5.091e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 363: Z=4.338e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 364: Z=3.750e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 365: Z=3.854e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 366: Z=4.929e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 367: Z=5.371e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 368: Z=4.086e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 369: Z=4.229e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 370: Z=3.664e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 371: Z=3.472e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 372: Z=4.238e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 373: Z=4.710e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 374: Z=4.082e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 375: Z=4.062e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 376: Z=3.551e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 377: Z=3.667e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 378: Z=3.511e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 379: Z=3.861e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 380: Z=5.556e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 381: Z=4.897e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 382: Z=4.049e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 383: Z=5.756e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 384: Z=5.507e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 385: Z=4.830e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 386: Z=5.968e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 387: Z=3.805e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 388: Z=4.212e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 389: Z=4.202e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 390: Z=3.606e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 391: Z=4.373e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 392: Z=4.303e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 393: Z=4.129e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 394: Z=4.589e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 395: Z=4.636e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 396: Z=3.567e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 397: Z=4.558e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 398: Z=3.855e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 399: Z=4.100e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 400: Z=4.129e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 401: Z=4.310e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 402: Z=4.625e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 403: Z=5.048e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 404: Z=4.922e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 405: Z=4.352e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 406: Z=4.182e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 407: Z=3.955e+02, ZC=2.795e+13, ZT=168, TotalTransport=1.1e+08
# Gen 408: Z=3.716e+02, ZC=2.793e+13, ZT=168, TotalTransport=1.1e+08
# Gen 409: Z=4.038e+02, ZC=2.794e+13, ZT=168, TotalTransport=1.1e+08
# Gen 410: Z=4.424e+02, ZC=2.794e+13, ZT=168, TotalTransport=1.1e+08
# Gen 411: Z=3.966e+02, ZC=2.808e+13, ZT=167, TotalTransport=1.1e+08
# Gen 412: Z=3.769e+02, ZC=2.793e+13, ZT=168, TotalTransport=1.1e+08
# Gen 413: Z=3.713e+02, ZC=2.793e+13, ZT=168, TotalTransport=1.1e+08
# Gen 414: Z=3.595e+02, ZC=2.790e+13, ZT=168, TotalTransport=1.1e+08
# Gen 415: Z=3.496e+02, ZC=2.790e+13, ZT=168, TotalTransport=1.1e+08
# Gen 416: Z=3.511e+02, ZC=2.789e+13, ZT=168, TotalTransport=1.1e+08
# Gen 417: Z=3.579e+02, ZC=2.788e+13, ZT=168, TotalTransport=1.1e+08
# Gen 418: Z=3.852e+02, ZC=2.788e+13, ZT=168, TotalTransport=1.1e+08
# Gen 419: Z=3.456e+02, ZC=2.787e+13, ZT=168, TotalTransport=1.1e+08
# Gen 420: Z=3.397e+02, ZC=2.787e+13, ZT=168, TotalTransport=1.1e+08
# Gen 421: Z=4.379e+02, ZC=2.786e+13, ZT=168, TotalTransport=1.1e+08
# Gen 422: Z=3.545e+02, ZC=2.786e+13, ZT=168, TotalTransport=1.1e+08
# Gen 423: Z=3.945e+02, ZC=2.785e+13, ZT=168, TotalTransport=1.1e+08
# Gen 424: Z=4.370e+02, ZC=2.785e+13, ZT=168, TotalTransport=1.1e+08
# Gen 425: Z=3.483e+02, ZC=2.783e+13, ZT=168, TotalTransport=1.1e+08
# Gen 426: Z=3.547e+02, ZC=2.783e+13, ZT=168, TotalTransport=1.1e+08
# Gen 427: Z=4.690e+02, ZC=2.783e+13, ZT=168, TotalTransport=1.1e+08
# Gen 428: Z=4.513e+02, ZC=2.783e+13, ZT=168, TotalTransport=1.1e+08
# Gen 429: Z=4.003e+02, ZC=2.783e+13, ZT=168, TotalTransport=1.1e+08
# Gen 430: Z=4.143e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 431: Z=3.790e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 432: Z=3.364e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 433: Z=3.449e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 434: Z=3.312e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 435: Z=3.541e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 436: Z=3.622e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 437: Z=3.583e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 438: Z=3.378e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 439: Z=4.758e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 440: Z=3.801e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 441: Z=3.616e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 442: Z=3.925e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 443: Z=3.775e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 444: Z=3.786e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 445: Z=4.115e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 446: Z=4.479e+02, ZC=2.782e+13, ZT=168, TotalTransport=1.1e+08
# Gen 447: Z=3.924e+02, ZC=2.778e+13, ZT=168, TotalTransport=1.1e+08
# Gen 448: Z=3.563e+02, ZC=2.778e+13, ZT=168, TotalTransport=1.1e+08
# Gen 449: Z=3.708e+02, ZC=2.776e+13, ZT=168, TotalTransport=1.1e+08
# Gen 450: Z=3.525e+02, ZC=2.776e+13, ZT=168, TotalTransport=1.1e+08
# Gen 451: Z=3.917e+02, ZC=2.776e+13, ZT=168, TotalTransport=1.1e+08
# Gen 452: Z=3.644e+02, ZC=2.776e+13, ZT=168, TotalTransport=1.1e+08
# Gen 453: Z=3.850e+02, ZC=2.776e+13, ZT=168, TotalTransport=1.1e+08
# Gen 454: Z=4.250e+02, ZC=2.774e+13, ZT=168, TotalTransport=1.1e+08
# Gen 455: Z=4.263e+02, ZC=2.773e+13, ZT=168, TotalTransport=1.1e+08
# Gen 456: Z=3.994e+02, ZC=2.773e+13, ZT=168, TotalTransport=1.1e+08
# Gen 457: Z=3.531e+02, ZC=2.773e+13, ZT=168, TotalTransport=1.1e+08
# Gen 458: Z=3.389e+02, ZC=2.772e+13, ZT=168, TotalTransport=1.1e+08
# Gen 459: Z=3.101e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 460: Z=3.532e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 461: Z=2.965e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 462: Z=3.901e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 463: Z=4.011e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 464: Z=3.860e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 465: Z=3.557e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 466: Z=4.001e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 467: Z=3.651e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 468: Z=4.188e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 469: Z=3.104e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 470: Z=3.250e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 471: Z=3.888e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 472: Z=3.466e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 473: Z=4.097e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 474: Z=4.535e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 475: Z=4.386e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 476: Z=4.265e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 477: Z=4.016e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 478: Z=3.792e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 479: Z=3.212e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 480: Z=3.968e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 481: Z=3.890e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 482: Z=3.678e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 483: Z=4.115e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 484: Z=4.081e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 485: Z=3.253e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 486: Z=3.843e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 487: Z=3.647e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 488: Z=4.960e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 489: Z=3.790e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 490: Z=3.428e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 491: Z=4.686e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 492: Z=4.060e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 493: Z=3.339e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 494: Z=3.613e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 495: Z=3.951e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 496: Z=3.815e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 497: Z=3.643e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 498: Z=4.473e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 499: Z=3.743e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 500: Z=5.250e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 501: Z=4.700e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 502: Z=5.746e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 503: Z=3.534e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 504: Z=4.027e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 505: Z=3.895e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 506: Z=5.097e+02, ZC=2.797e+13, ZT=167, TotalTransport=1.1e+08
# Gen 507: Z=3.653e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 508: Z=4.330e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 509: Z=4.532e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 510: Z=3.883e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 511: Z=3.880e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 512: Z=3.833e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 513: Z=4.298e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 514: Z=3.572e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 515: Z=3.612e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 516: Z=4.029e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 517: Z=3.255e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 518: Z=4.180e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 519: Z=3.593e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 520: Z=3.684e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 521: Z=4.111e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 522: Z=4.027e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 523: Z=3.747e+02, ZC=2.771e+13, ZT=168, TotalTransport=1.1e+08
# Gen 524: Z=3.807e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 525: Z=4.505e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 526: Z=4.119e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 527: Z=3.773e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 528: Z=3.803e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 529: Z=4.965e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 530: Z=3.924e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 531: Z=3.640e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 532: Z=4.240e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 533: Z=4.671e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 534: Z=3.915e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 535: Z=3.335e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 536: Z=3.596e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 537: Z=3.672e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 538: Z=4.491e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 539: Z=4.446e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 540: Z=3.528e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 541: Z=3.734e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 542: Z=4.172e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 543: Z=3.694e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 544: Z=4.076e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 545: Z=4.505e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 546: Z=4.125e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 547: Z=3.685e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 548: Z=3.996e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 549: Z=3.939e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 550: Z=5.476e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 551: Z=4.189e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 552: Z=3.953e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 553: Z=4.577e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 554: Z=3.654e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 555: Z=4.076e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 556: Z=4.237e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 557: Z=4.485e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 558: Z=3.847e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 559: Z=3.788e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 560: Z=5.760e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 561: Z=3.520e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 562: Z=4.268e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 563: Z=4.347e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 564: Z=4.252e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 565: Z=5.208e+02, ZC=2.804e+13, ZT=167, TotalTransport=1.1e+08
# Gen 566: Z=4.237e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 567: Z=3.650e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 568: Z=4.181e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 569: Z=3.416e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 570: Z=3.385e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 571: Z=4.389e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 572: Z=4.354e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 573: Z=4.367e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 574: Z=3.805e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 575: Z=3.316e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 576: Z=3.683e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 577: Z=4.325e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 578: Z=3.421e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 579: Z=4.163e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 580: Z=3.842e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 581: Z=3.979e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 582: Z=4.580e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 583: Z=4.373e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 584: Z=3.946e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 585: Z=3.953e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 586: Z=4.599e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 587: Z=4.153e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 588: Z=3.949e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 589: Z=4.309e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 590: Z=3.196e+02, ZC=2.770e+13, ZT=168, TotalTransport=1.1e+08
# Gen 591: Z=4.050e+02, ZC=2.792e+13, ZT=167, TotalTransport=1.1e+08
# Gen 592: Z=3.261e+02, ZC=2.787e+13, ZT=167, TotalTransport=1.1e+08
# Gen 593: Z=3.641e+02, ZC=2.786e+13, ZT=167, TotalTransport=1.1e+08
# Gen 594: Z=3.763e+02, ZC=2.785e+13, ZT=167, TotalTransport=1.1e+08
# Gen 595: Z=4.218e+02, ZC=2.785e+13, ZT=167, TotalTransport=1.1e+08
# Gen 596: Z=3.727e+02, ZC=2.769e+13, ZT=168, TotalTransport=1.1e+08
# Gen 597: Z=4.545e+02, ZC=2.769e+13, ZT=168, TotalTransport=1.1e+08
# Gen 598: Z=3.713e+02, ZC=2.769e+13, ZT=168, TotalTransport=1.1e+08
# Gen 599: Z=4.117e+02, ZC=2.769e+13, ZT=168, TotalTransport=1.1e+08
# Gen 600: Z=5.103e+02, ZC=2.769e+13, ZT=168, TotalTransport=1.1e+08
# Gen 601: Z=5.392e+02, ZC=2.769e+13, ZT=168, TotalTransport=1.1e+08
# Gen 602: Z=3.424e+02, ZC=2.769e+13, ZT=168, TotalTransport=1.1e+08
# Gen 603: Z=4.076e+02, ZC=2.769e+13, ZT=168, TotalTransport=1.1e+08
# Gen 604: Z=4.102e+02, ZC=2.769e+13, ZT=168, TotalTransport=1.1e+08
# Gen 605: Z=5.390e+02, ZC=2.768e+13, ZT=168, TotalTransport=1.1e+08
# Gen 606: Z=4.263e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 607: Z=3.838e+02, ZC=2.768e+13, ZT=168, TotalTransport=1.1e+08
# Gen 608: Z=4.639e+02, ZC=2.768e+13, ZT=168, TotalTransport=1.1e+08
# Gen 609: Z=3.906e+02, ZC=2.767e+13, ZT=168, TotalTransport=1.1e+08
# Gen 610: Z=3.572e+02, ZC=2.767e+13, ZT=168, TotalTransport=1.1e+08
# Gen 611: Z=3.587e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 612: Z=4.024e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 613: Z=3.961e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 614: Z=3.999e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 615: Z=3.714e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 616: Z=3.653e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 617: Z=3.435e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 618: Z=4.666e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 619: Z=3.845e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 620: Z=4.395e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 621: Z=3.682e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 622: Z=4.063e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 623: Z=3.612e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 624: Z=3.595e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 625: Z=3.728e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 626: Z=4.009e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 627: Z=3.587e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 628: Z=3.449e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 629: Z=3.489e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 630: Z=3.815e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 631: Z=4.735e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 632: Z=4.738e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 633: Z=3.882e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 634: Z=3.767e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 635: Z=4.356e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 636: Z=3.539e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 637: Z=4.240e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 638: Z=3.632e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 639: Z=3.565e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 640: Z=4.194e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 641: Z=4.170e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 642: Z=3.640e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 643: Z=4.279e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 644: Z=4.400e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 645: Z=4.707e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 646: Z=4.399e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 647: Z=4.735e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 648: Z=4.591e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 649: Z=4.721e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 650: Z=4.753e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 651: Z=3.320e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 652: Z=3.578e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 653: Z=4.206e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 654: Z=4.148e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 655: Z=3.580e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 656: Z=3.492e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 657: Z=4.172e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 658: Z=4.914e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 659: Z=4.636e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 660: Z=4.321e+02, ZC=2.766e+13, ZT=168, TotalTransport=1.1e+08
# Gen 661: Z=3.777e+02, ZC=2.765e+13, ZT=168, TotalTransport=1.1e+08
# Gen 662: Z=4.808e+02, ZC=2.765e+13, ZT=168, TotalTransport=1.1e+08
# Gen 663: Z=3.975e+02, ZC=2.764e+13, ZT=168, TotalTransport=1.1e+08
# Gen 664: Z=3.437e+02, ZC=2.764e+13, ZT=168, TotalTransport=1.1e+08
# Gen 665: Z=3.504e+02, ZC=2.764e+13, ZT=168, TotalTransport=1.1e+08
# Gen 666: Z=4.117e+02, ZC=2.764e+13, ZT=168, TotalTransport=1.1e+08
# Gen 667: Z=3.984e+02, ZC=2.763e+13, ZT=168, TotalTransport=1.1e+08
# Gen 668: Z=4.680e+02, ZC=2.763e+13, ZT=168, TotalTransport=1.1e+08
# Gen 669: Z=4.065e+02, ZC=2.763e+13, ZT=168, TotalTransport=1.1e+08
# Gen 670: Z=3.972e+02, ZC=2.762e+13, ZT=168, TotalTransport=1.1e+08
# Gen 671: Z=5.077e+02, ZC=2.762e+13, ZT=168, TotalTransport=1.1e+08
# Gen 672: Z=5.344e+02, ZC=2.761e+13, ZT=168, TotalTransport=1.1e+08
# Gen 673: Z=5.003e+02, ZC=2.760e+13, ZT=168, TotalTransport=1.1e+08
# Gen 674: Z=3.728e+02, ZC=2.757e+13, ZT=168, TotalTransport=1.1e+08
# Gen 675: Z=3.271e+02, ZC=2.757e+13, ZT=168, TotalTransport=1.1e+08
# Gen 676: Z=4.031e+02, ZC=2.757e+13, ZT=168, TotalTransport=1.1e+08
# Gen 677: Z=4.043e+02, ZC=2.757e+13, ZT=168, TotalTransport=1.1e+08
# Gen 678: Z=4.514e+02, ZC=2.756e+13, ZT=168, TotalTransport=1.1e+08
# Gen 679: Z=3.793e+02, ZC=2.756e+13, ZT=168, TotalTransport=1.1e+08
# Gen 680: Z=3.136e+02, ZC=2.755e+13, ZT=168, TotalTransport=1.1e+08
# Gen 681: Z=3.917e+02, ZC=2.755e+13, ZT=168, TotalTransport=1.1e+08
# Gen 682: Z=3.870e+02, ZC=2.755e+13, ZT=168, TotalTransport=1.1e+08
# Gen 683: Z=3.670e+02, ZC=2.754e+13, ZT=168, TotalTransport=1.1e+08
# Gen 684: Z=3.458e+02, ZC=2.754e+13, ZT=168, TotalTransport=1.1e+08
# Gen 685: Z=4.525e+02, ZC=2.754e+13, ZT=168, TotalTransport=1.1e+08
# Gen 686: Z=4.468e+02, ZC=2.754e+13, ZT=168, TotalTransport=1.1e+08
# Gen 687: Z=3.727e+02, ZC=2.753e+13, ZT=168, TotalTransport=1.1e+08
# Gen 688: Z=3.701e+02, ZC=2.753e+13, ZT=168, TotalTransport=1.1e+08
# Gen 689: Z=3.318e+02, ZC=2.753e+13, ZT=168, TotalTransport=1.1e+08
# Gen 690: Z=3.296e+02, ZC=2.753e+13, ZT=168, TotalTransport=1.1e+08
# Gen 691: Z=3.550e+02, ZC=2.753e+13, ZT=168, TotalTransport=1.1e+08
# Gen 692: Z=3.209e+02, ZC=2.753e+13, ZT=168, TotalTransport=1.1e+08
# Gen 693: Z=3.207e+02, ZC=2.752e+13, ZT=168, TotalTransport=1.1e+08
# Gen 694: Z=3.863e+02, ZC=2.752e+13, ZT=168, TotalTransport=1.1e+08
# Gen 695: Z=3.446e+02, ZC=2.752e+13, ZT=168, TotalTransport=1.1e+08
# Gen 696: Z=4.037e+02, ZC=2.752e+13, ZT=168, TotalTransport=1.1e+08
# Gen 697: Z=4.151e+02, ZC=2.752e+13, ZT=168, TotalTransport=1.1e+08
# Gen 698: Z=3.897e+02, ZC=2.752e+13, ZT=168, TotalTransport=1.1e+08
# Gen 699: Z=4.356e+02, ZC=2.752e+13, ZT=168, TotalTransport=1.1e+08
# 最终总运输量 = 112727449.60469484
# 火箭运输量 =  40620000
# 太空电梯运输量 =  72107449.60469484
# 压缩后最早完成 D_total 的年份 ZT_new = 164
# 压缩后总运输量 = 100000000.0
# 压缩后总成本 = 2.381e+13
# 火箭总运输量 = 34521300
# 电梯总运输量 = 65478279.4212801

# %%
# ==============================
# 可视化模块
# ==============================

# 1. 种群演化三维图（成本-工期-代数）
fig = plt.figure(figsize=(18, 6))

# 三维图 - 最佳个体演化
ax1 = fig.add_subplot(131, projection='3d')
gen_array = np.array(history['gen'])
best_ZC_array = np.array(history['best_ZC'])
best_ZT_array = np.array(history['best_ZT'])

# 将成本标准化以便更好地显示
best_ZC_norm = (best_ZC_array - np.min(best_ZC_array)) / (np.max(best_ZC_array) - np.min(best_ZC_array) + 1e-10)

# 绘制三维线图
ax1.plot(gen_array, best_ZC_array, best_ZT_array, 'b-', linewidth=2, alpha=0.7, label='Best Individual')
# 绘制三维散点图
scatter1 = ax1.scatter(gen_array, best_ZC_array, best_ZT_array, 
                      c=best_ZT_array, cmap='viridis', s=50, alpha=0.8)

ax1.set_xlabel('Generation', fontsize=10)
ax1.set_ylabel('Total Cost', fontsize=10)
ax1.set_zlabel('Total Time', fontsize=1)

ax1.set_title('Evolution of Best Individual', fontsize=14)
ax1.grid(True, alpha=0.3)
cbar1 = fig.colorbar(scatter1, ax=ax1, shrink=0.5, aspect=10)
cbar1.set_label('ZT Value', fontsize=10)

# 2. 二维演化图 - 成本
ax2 = fig.add_subplot(132)
ax2.plot(history['gen'], history['best_ZC'], 'b-', linewidth=2, label='Best ZC')
ax2.plot(history['gen'], history['avg_ZC'], 'r-', linewidth=2, alpha=0.7, label='Average ZC')
ax2.fill_between(history['gen'], 
                 np.array(history['avg_ZC']) - np.array([np.std(zc) for zc in history['pop_ZC']]),
                 np.array(history['avg_ZC']) + np.array([np.std(zc) for zc in history['pop_ZC']]),
                 alpha=0.2, color='red')
ax2.set_xlabel('Generation', fontsize=12)
ax2.set_ylabel('Total Cost (ZC)', fontsize=12)
ax2.set_title('Cost Evolution Over Generations', fontsize=14)
ax2.legend()
ax2.grid(True, alpha=0.3)

# 3. 二维演化图 - 工期
ax3 = fig.add_subplot(133)
ax3.plot(history['gen'], history['best_ZT'], 'g-', linewidth=2, label='Best ZT')
ax3.plot(history['gen'], history['avg_ZT'], 'orange', linewidth=2, alpha=0.7, label='Average ZT')
ax3.fill_between(history['gen'], 
                 np.array(history['avg_ZT']) - np.array([np.std(zt) for zt in history['pop_ZT']]),
                 np.array(history['avg_ZT']) + np.array([np.std(zt) for zt in history['pop_ZT']]),
                 alpha=0.2, color='orange')
ax3.set_xlabel('Generation', fontsize=12)
ax3.set_ylabel('Total Time (ZT)', fontsize=12)
ax3.set_title('Time Evolution Over Generations', fontsize=14)
ax3.legend()
ax3.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# 4. 帕累托前沿图（多代对比）
fig2 = plt.figure(figsize=(15, 10))

# 选择几个关键代进行显示
key_generations = [0, 100, 250, 500, 750, 999]
colors = ['lightgray', 'lightblue', 'blue', 'green', 'orange', 'red']
markers = ['o', 's', '^', 'v', 'D', 'X']

for i, gen in enumerate(key_generations):
    if gen < len(history['gen']):
        # 获取该代的所有个体
        ZC_values = history['pop_ZC'][gen]
        ZT_values = history['pop_ZT'][gen]
        
        # 绘制散点
        plt.scatter(ZC_values, ZT_values, 
                   c=colors[i], marker=markers[i], s=50, 
                   alpha=0.6, label=f'Gen {gen}')
        
        # 标记最佳个体
        best_idx = np.argmin([history['best_fitness'][gen]])
        plt.scatter(history['best_ZC'][gen], history['best_ZT'][gen], 
                   c='black', marker='*', s=200, edgecolors='yellow', 
                   linewidth=2, zorder=5)


plt.xlabel('Total Cost', fontsize=14)
plt.ylabel('Total Time', fontsize=14)
plt.title('Pareto Front Evolution Across Generations', fontsize=16)
plt.legend()
plt.grid(True, alpha=0.3)

# 添加箭头表示演化方向
if len(key_generations) > 1:
    for i in range(len(key_generations)-1):
        gen1 = key_generations[i]
        gen2 = key_generations[i+1]
        if gen1 < len(history['gen']) and gen2 < len(history['gen']):
            plt.annotate('', 
                        xy=(history['best_ZC'][gen2], history['best_ZT'][gen2]),
                        xytext=(history['best_ZC'][gen1], history['best_ZT'][gen1]),
                        arrowprops=dict(arrowstyle='->', color='purple', lw=2, alpha=0.7))

plt.tight_layout()
plt.show()

# 5. 最终代的帕累托前沿详细图
final_gen = len(history['gen']) - 1
fig3, (ax4, ax5) = plt.subplots(1, 2, figsize=(16, 6))

# 左图：最终代所有个体
final_ZC = history['pop_ZC'][final_gen]
final_ZT = history['pop_ZT'][final_gen]

scatter_final = ax4.scatter(final_ZC, final_ZT, c=final_ZT, cmap='viridis', 
                           s=60, alpha=0.8, edgecolors='k', linewidth=0.5)

# 标记最佳个体
best_final_idx = np.argmin(history['best_fitness'])
ax4.scatter(history['best_ZC'][final_gen], history['best_ZT'][final_gen], 
           c='red', marker='*', s=300, edgecolors='gold', linewidth=2, 
           label=f'Best: ZC={history["best_ZC"][final_gen]:.2e}, ZT={history["best_ZT"][final_gen]}')

ax4.set_xlabel('Total Cost', fontsize=12)
ax4.set_ylabel('Total Time', fontsize=12)
ax4.set_title(f'Final Generation Population', fontsize=14)
ax4.legend()
ax4.grid(True, alpha=0.3)
cbar_final = fig3.colorbar(scatter_final, ax=ax4, shrink=0.8)
cbar_final.set_label('ZT Value', fontsize=10)

# 右图：适应度演化
ax5.plot(history['gen'], history['best_fitness'], 'purple', linewidth=2, label='Best Fitness')
ax5.fill_between(history['gen'], 
                 np.array(history['best_fitness']) - 0.1*np.array(history['best_fitness']),
                 np.array(history['best_fitness']) + 0.1*np.array(history['best_fitness']),
                 alpha=0.2, color='purple')
ax5.set_xlabel('Generation', fontsize=12)
ax5.set_ylabel('Fitness Value', fontsize=12)
ax5.set_title('Fitness Evolution', fontsize=14)
ax5.set_yscale('log')
ax5.legend()
ax5.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# 打印最终结果摘要
print("="*60)
print("GENETIC ALGORITHM OPTIMIZATION RESULTS")
print("="*60)
print(f"Total Generations: {len(history['gen'])}")
print(f"Best Individual Found:")
print(f"  - Total Cost (ZC): {history['best_ZC'][-1]:.3e}")
print(f"  - Total Time (ZT): {history['best_ZT'][-1]} years")
print(f"  - Fitness Value: {history['best_fitness'][-1]:.3e}")
print(f"\nImprovement Over Generations:")
print(f"  - Cost Reduction: {((history['best_ZC'][0] - history['best_ZC'][-1])/history['best_ZC'][0]*100):.2f}%")
print(f"  - Time Reduction: {((history['best_ZT'][0] - history['best_ZT'][-1])/history['best_ZT'][0]*100):.2f}%")
print("="*60)
# Out:
# ============================================================
# GENETIC ALGORITHM OPTIMIZATION RESULTS
# ============================================================
# Total Generations: 700
# Best Individual Found:
#   - Total Cost (ZC): 2.752e+13
#   - Total Time (ZT): 168 years
#   - Fitness Value: 4.356e+02
#
# Improvement Over Generations:
#   - Cost Reduction: 8.57%
#   - Time Reduction: 14.29%
# ============================================================
