# %%
from deap import base, creator, tools
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 全局参数

# %%
TMAX = 500          # 为演示缩短长度，实际可设1000
K = 10
P = 3

D_total = 1e8
Cap_rocket = 150
Cap_lift = 179000
L_max = 800

Cost_rocket = 500000
Cost_lift = 100000

# %% [markdown]
# 初始化DEAP

# %%
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()

# 火箭发射次数 (整数)
toolbox.register("attr_R", lambda: random.randint(0, L_max))
# 电梯运输量 (连续)
toolbox.register("attr_E", lambda: random.uniform(0, Cap_lift))

def init_individual():
    """保证初始化总运输量大约 D_total / TMAX"""
    ind = []
    avg_rocket_per_year = D_total / TMAX / 2 / Cap_rocket / K
    avg_lift_per_year = D_total / TMAX / 2 / P

    for _ in range(K*TMAX):
        val = max(1, int(random.gauss(avg_rocket_per_year, avg_rocket_per_year*0.5)))
        ind.append(min(val, L_max))

    for _ in range(P*TMAX):
        val = random.gauss(avg_lift_per_year, avg_lift_per_year*0.5)
        val = max(0, min(val, Cap_lift))
        ind.append(val)

    return creator.Individual(ind)

toolbox.register("individual", init_individual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %% [markdown]
# fitness分配

# %%
def assign_fitness(pop, w1=0.5, w2=0.5):
    ZC_list = []
    ZT_list = []

    for ind in pop:
        R = np.array(ind[:K*TMAX]).reshape(K, TMAX)
        E = np.array(ind[K*TMAX:]).reshape(P, TMAX)

        # 总成本
        ZC = Cost_rocket * np.sum(R) + Cost_lift * np.sum(E)

        # 总工期
        transported = 0
        ZT = TMAX
        for t in range(TMAX):
            R_t = np.sum(R[:, t]) * Cap_rocket
            E_t = np.sum(E[:, t])
            transported += R_t + E_t
            if transported >= D_total:
                ZT = t + 1
                break

        # 罚函数: 总运输量不足时增加 fitness
        penalty = max(0, D_total - transported) * 1e-3  # 连续罚函数

        ind.ZC = ZC
        ind.ZT = ZT
        ind.penalty = penalty

        ZC_list.append(ZC)
        ZT_list.append(ZT)

    # 种群内标准化
    std_C = np.std(ZC_list) + 1e-6
    std_T = np.std(ZT_list) + 1e-6

    for ind in pop:
        fitness_val = w1 * ind.ZC / std_C + w2 * ind.ZT / std_T + ind.penalty
        ind.fitness.values = (fitness_val,)

# %% [markdown]
# 遗传算子

# %%
toolbox.register("mate", tools.cxTwoPoint)

def mutate_bound(ind, mu_R=0, sigma_R=100, mu_E=0, sigma_E=5e4, indpb=0.1):
    for i in range(len(ind)):
        if random.random() < indpb:
            if i < K*TMAX:
                ind[i] += int(round(random.gauss(mu_R, sigma_R)))
                ind[i] = max(0, min(L_max, ind[i]))
            else:
                ind[i] += random.gauss(mu_E, sigma_E)
                ind[i] = max(0, min(Cap_lift, ind[i]))
    return ind,

toolbox.register("mutate", mutate_bound)
toolbox.register("select", tools.selTournament, tournsize=3)

# %% [markdown]
# main函数入口

# %%
def main():
    pop = toolbox.population(n=50)
    NGEN = 500
    CXPB = 0.7
    MUTPB = 0.2

    assign_fitness(pop)

    for gen in range(NGEN):
        offspring = toolbox.select(pop, len(pop))
        offspring = list(map(toolbox.clone, offspring))

        # 交叉
        for c1, c2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < CXPB:
                toolbox.mate(c1, c2)
                del c1.fitness.values, c2.fitness.values

        # 变异
        for ind in offspring:
            if random.random() < MUTPB:
                toolbox.mutate(ind)
                del ind.fitness.values

        assign_fitness(offspring)
        pop[:] = offspring

        best = tools.selBest(pop, 1)[0]
        total_transported = np.sum(best[:K*TMAX])*Cap_rocket + np.sum(best[K*TMAX:])
        print(f"Gen {gen}: Z={best.fitness.values[0]:.3e}, "
              f"ZC={best.ZC:.3e}, ZT={best.ZT}, TotalTransport={total_transported:.1e}")

    return tools.selBest(pop, 1)[0]

# %% [markdown]
# 运行GA

# %%
best_ind = main()

R = np.array(best_ind[:K*TMAX]).reshape(K, TMAX)
E = np.array(best_ind[K*TMAX:]).reshape(P, TMAX)

ROCKET = pd.DataFrame(R)
ELEVATOR = pd.DataFrame(E)
ROCKET.to_excel((r"D:\USELESS\数据分析学习\数学建模学习\2026美赛\B\ROCKET1.xlsx"))
ELEVATOR.to_excel((r"D:\USELESS\数据分析学习\数学建模学习\2026美赛\B\ELEVATOR1.xlsx"))
print("最终总运输量 =", np.sum(R)*Cap_rocket + np.sum(E))
print('火箭运输量 = ', np.sum(R)*Cap_rocket)
print('太空电梯运输量 = ', np.sum(E))
# Out:
# Gen 0: Z=8.333e+01, ZC=5.324e+12, ZT=485, TotalTransport=1.0e+08
# Gen 1: Z=6.861e+01, ZC=5.248e+12, ZT=487, TotalTransport=1.0e+08
# Gen 2: Z=6.572e+01, ZC=5.211e+12, ZT=489, TotalTransport=1.0e+08
# Gen 3: Z=5.834e+01, ZC=5.210e+12, ZT=485, TotalTransport=1.0e+08
# Gen 4: Z=5.392e+01, ZC=5.460e+12, ZT=463, TotalTransport=1.1e+08
# Gen 5: Z=4.685e+01, ZC=5.174e+12, ZT=476, TotalTransport=1.0e+08
# Gen 6: Z=4.515e+01, ZC=5.242e+12, ZT=469, TotalTransport=1.1e+08
# Gen 7: Z=4.800e+01, ZC=5.243e+12, ZT=469, TotalTransport=1.1e+08
# Gen 8: Z=4.194e+01, ZC=5.369e+12, ZT=458, TotalTransport=1.1e+08
# Gen 9: Z=4.055e+01, ZC=5.424e+12, ZT=449, TotalTransport=1.1e+08
# Gen 10: Z=4.084e+01, ZC=5.586e+12, ZT=438, TotalTransport=1.1e+08
# Gen 11: Z=4.062e+01, ZC=5.633e+12, ZT=432, TotalTransport=1.2e+08
# Gen 12: Z=4.574e+01, ZC=5.438e+12, ZT=442, TotalTransport=1.1e+08
# Gen 13: Z=5.542e+01, ZC=5.316e+12, ZT=447, TotalTransport=1.1e+08
# Gen 14: Z=5.691e+01, ZC=5.447e+12, ZT=437, TotalTransport=1.1e+08
# Gen 15: Z=6.043e+01, ZC=5.318e+12, ZT=445, TotalTransport=1.1e+08
# Gen 16: Z=6.969e+01, ZC=5.375e+12, ZT=439, TotalTransport=1.1e+08
# Gen 17: Z=6.560e+01, ZC=5.381e+12, ZT=437, TotalTransport=1.1e+08
# Gen 18: Z=5.852e+01, ZC=5.383e+12, ZT=434, TotalTransport=1.1e+08
# Gen 19: Z=5.693e+01, ZC=5.482e+12, ZT=423, TotalTransport=1.2e+08
# Gen 20: Z=6.096e+01, ZC=5.483e+12, ZT=421, TotalTransport=1.2e+08
# Gen 21: Z=6.155e+01, ZC=5.423e+12, ZT=423, TotalTransport=1.2e+08
# Gen 22: Z=5.382e+01, ZC=5.423e+12, ZT=423, TotalTransport=1.2e+08
# Gen 23: Z=4.789e+01, ZC=5.523e+12, ZT=408, TotalTransport=1.2e+08
# Gen 24: Z=5.026e+01, ZC=5.608e+12, ZT=401, TotalTransport=1.2e+08
# Gen 25: Z=5.106e+01, ZC=5.608e+12, ZT=398, TotalTransport=1.2e+08
# Gen 26: Z=5.371e+01, ZC=5.536e+12, ZT=402, TotalTransport=1.2e+08
# Gen 27: Z=4.937e+01, ZC=5.549e+12, ZT=398, TotalTransport=1.3e+08
# Gen 28: Z=5.752e+01, ZC=5.539e+12, ZT=397, TotalTransport=1.3e+08
# Gen 29: Z=6.006e+01, ZC=5.423e+12, ZT=402, TotalTransport=1.2e+08
# Gen 30: Z=5.990e+01, ZC=5.421e+12, ZT=401, TotalTransport=1.2e+08
# Gen 31: Z=5.537e+01, ZC=5.483e+12, ZT=391, TotalTransport=1.3e+08
# Gen 32: Z=5.324e+01, ZC=5.618e+12, ZT=386, TotalTransport=1.3e+08
# Gen 33: Z=5.169e+01, ZC=5.728e+12, ZT=379, TotalTransport=1.3e+08
# Gen 34: Z=4.687e+01, ZC=5.680e+12, ZT=377, TotalTransport=1.3e+08
# Gen 35: Z=3.739e+01, ZC=5.721e+12, ZT=372, TotalTransport=1.3e+08
# Gen 36: Z=3.723e+01, ZC=5.721e+12, ZT=372, TotalTransport=1.3e+08
# Gen 37: Z=5.258e+01, ZC=5.515e+12, ZT=380, TotalTransport=1.3e+08
# Gen 38: Z=4.361e+01, ZC=5.765e+12, ZT=366, TotalTransport=1.3e+08
# Gen 39: Z=4.149e+01, ZC=5.850e+12, ZT=359, TotalTransport=1.4e+08
# Gen 40: Z=4.051e+01, ZC=5.540e+12, ZT=371, TotalTransport=1.3e+08
# Gen 41: Z=3.638e+01, ZC=5.675e+12, ZT=361, TotalTransport=1.4e+08
# Gen 42: Z=3.625e+01, ZC=5.635e+12, ZT=359, TotalTransport=1.4e+08
# Gen 43: Z=4.541e+01, ZC=5.707e+12, ZT=355, TotalTransport=1.4e+08
# Gen 44: Z=5.544e+01, ZC=5.707e+12, ZT=355, TotalTransport=1.4e+08
# Gen 45: Z=5.711e+01, ZC=5.862e+12, ZT=347, TotalTransport=1.4e+08
# Gen 46: Z=4.660e+01, ZC=5.835e+12, ZT=346, TotalTransport=1.4e+08
# Gen 47: Z=4.954e+01, ZC=5.836e+12, ZT=345, TotalTransport=1.4e+08
# Gen 48: Z=4.990e+01, ZC=5.818e+12, ZT=344, TotalTransport=1.4e+08
# Gen 49: Z=5.528e+01, ZC=5.820e+12, ZT=343, TotalTransport=1.4e+08
# Gen 50: Z=5.191e+01, ZC=5.867e+12, ZT=340, TotalTransport=1.4e+08
# Gen 51: Z=5.386e+01, ZC=5.823e+12, ZT=340, TotalTransport=1.4e+08
# Gen 52: Z=6.770e+01, ZC=5.765e+12, ZT=340, TotalTransport=1.4e+08
# Gen 53: Z=6.168e+01, ZC=5.765e+12, ZT=340, TotalTransport=1.4e+08
# Gen 54: Z=6.200e+01, ZC=5.902e+12, ZT=333, TotalTransport=1.5e+08
# Gen 55: Z=5.327e+01, ZC=5.958e+12, ZT=330, TotalTransport=1.5e+08
# Gen 56: Z=6.266e+01, ZC=5.804e+12, ZT=334, TotalTransport=1.4e+08
# Gen 57: Z=5.179e+01, ZC=5.873e+12, ZT=329, TotalTransport=1.5e+08
# Gen 58: Z=5.475e+01, ZC=5.861e+12, ZT=329, TotalTransport=1.5e+08
# Gen 59: Z=6.743e+01, ZC=5.883e+12, ZT=326, TotalTransport=1.5e+08
# Gen 60: Z=6.930e+01, ZC=5.931e+12, ZT=324, TotalTransport=1.5e+08
# Gen 61: Z=6.030e+01, ZC=6.155e+12, ZT=314, TotalTransport=1.5e+08
# Gen 62: Z=5.502e+01, ZC=5.933e+12, ZT=321, TotalTransport=1.5e+08
# Gen 63: Z=4.815e+01, ZC=5.971e+12, ZT=319, TotalTransport=1.5e+08
# Gen 64: Z=5.309e+01, ZC=5.897e+12, ZT=320, TotalTransport=1.5e+08
# Gen 65: Z=5.699e+01, ZC=5.910e+12, ZT=319, TotalTransport=1.5e+08
# Gen 66: Z=5.737e+01, ZC=5.987e+12, ZT=313, TotalTransport=1.5e+08
# Gen 67: Z=7.214e+01, ZC=6.161e+12, ZT=307, TotalTransport=1.5e+08
# Gen 68: Z=6.540e+01, ZC=6.255e+12, ZT=304, TotalTransport=1.6e+08
# Gen 69: Z=6.226e+01, ZC=6.162e+12, ZT=306, TotalTransport=1.5e+08
# Gen 70: Z=6.244e+01, ZC=5.817e+12, ZT=315, TotalTransport=1.5e+08
# Gen 71: Z=5.139e+01, ZC=6.140e+12, ZT=304, TotalTransport=1.6e+08
# Gen 72: Z=6.073e+01, ZC=6.405e+12, ZT=295, TotalTransport=1.6e+08
# Gen 73: Z=4.998e+01, ZC=5.965e+12, ZT=308, TotalTransport=1.5e+08
# Gen 74: Z=5.346e+01, ZC=6.314e+12, ZT=295, TotalTransport=1.6e+08
# Gen 75: Z=5.107e+01, ZC=6.313e+12, ZT=295, TotalTransport=1.6e+08
# Gen 76: Z=4.788e+01, ZC=6.079e+12, ZT=300, TotalTransport=1.6e+08
# Gen 77: Z=4.616e+01, ZC=6.311e+12, ZT=291, TotalTransport=1.6e+08
# Gen 78: Z=4.779e+01, ZC=6.083e+12, ZT=297, TotalTransport=1.6e+08
# Gen 79: Z=5.083e+01, ZC=5.942e+12, ZT=302, TotalTransport=1.6e+08
# Gen 80: Z=6.270e+01, ZC=5.944e+12, ZT=301, TotalTransport=1.6e+08
# Gen 81: Z=4.938e+01, ZC=6.068e+12, ZT=295, TotalTransport=1.6e+08
# Gen 82: Z=6.271e+01, ZC=6.069e+12, ZT=294, TotalTransport=1.6e+08
# Gen 83: Z=7.505e+01, ZC=6.141e+12, ZT=291, TotalTransport=1.6e+08
# Gen 84: Z=7.427e+01, ZC=6.231e+12, ZT=288, TotalTransport=1.6e+08
# Gen 85: Z=8.751e+01, ZC=6.076e+12, ZT=291, TotalTransport=1.6e+08
# Gen 86: Z=9.638e+01, ZC=6.142e+12, ZT=289, TotalTransport=1.6e+08
# Gen 87: Z=7.998e+01, ZC=6.078e+12, ZT=290, TotalTransport=1.6e+08
# Gen 88: Z=6.523e+01, ZC=6.203e+12, ZT=286, TotalTransport=1.6e+08
# Gen 89: Z=6.368e+01, ZC=6.163e+12, ZT=286, TotalTransport=1.6e+08
# Gen 90: Z=7.029e+01, ZC=6.219e+12, ZT=282, TotalTransport=1.7e+08
# Gen 91: Z=5.406e+01, ZC=6.340e+12, ZT=278, TotalTransport=1.7e+08
# Gen 92: Z=5.980e+01, ZC=6.121e+12, ZT=284, TotalTransport=1.6e+08
# Gen 93: Z=5.442e+01, ZC=6.280e+12, ZT=279, TotalTransport=1.7e+08
# Gen 94: Z=5.640e+01, ZC=6.161e+12, ZT=280, TotalTransport=1.7e+08
# Gen 95: Z=5.174e+01, ZC=6.127e+12, ZT=280, TotalTransport=1.7e+08
# Gen 96: Z=4.725e+01, ZC=6.579e+12, ZT=268, TotalTransport=1.7e+08
# Gen 97: Z=4.409e+01, ZC=6.544e+12, ZT=268, TotalTransport=1.7e+08
# Gen 98: Z=4.557e+01, ZC=6.591e+12, ZT=264, TotalTransport=1.7e+08
# Gen 99: Z=4.033e+01, ZC=6.677e+12, ZT=260, TotalTransport=1.7e+08
# Gen 100: Z=3.865e+01, ZC=6.135e+12, ZT=276, TotalTransport=1.7e+08
# Gen 101: Z=3.468e+01, ZC=6.737e+12, ZT=258, TotalTransport=1.8e+08
# Gen 102: Z=3.528e+01, ZC=6.259e+12, ZT=270, TotalTransport=1.7e+08
# Gen 103: Z=3.371e+01, ZC=6.722e+12, ZT=256, TotalTransport=1.8e+08
# Gen 104: Z=4.064e+01, ZC=6.343e+12, ZT=265, TotalTransport=1.7e+08
# Gen 105: Z=4.336e+01, ZC=6.344e+12, ZT=264, TotalTransport=1.7e+08
# Gen 106: Z=4.169e+01, ZC=6.654e+12, ZT=254, TotalTransport=1.8e+08
# Gen 107: Z=3.919e+01, ZC=6.654e+12, ZT=253, TotalTransport=1.8e+08
# Gen 108: Z=4.728e+01, ZC=6.654e+12, ZT=253, TotalTransport=1.8e+08
# Gen 109: Z=5.107e+01, ZC=6.702e+12, ZT=250, TotalTransport=1.8e+08
# Gen 110: Z=5.846e+01, ZC=6.702e+12, ZT=250, TotalTransport=1.8e+08
# Gen 111: Z=5.184e+01, ZC=6.583e+12, ZT=253, TotalTransport=1.8e+08
# Gen 112: Z=4.903e+01, ZC=6.743e+12, ZT=248, TotalTransport=1.8e+08
# Gen 113: Z=4.844e+01, ZC=6.747e+12, ZT=247, TotalTransport=1.8e+08
# Gen 114: Z=5.216e+01, ZC=6.718e+12, ZT=247, TotalTransport=1.8e+08
# Gen 115: Z=6.099e+01, ZC=6.625e+12, ZT=249, TotalTransport=1.8e+08
# Gen 116: Z=5.709e+01, ZC=6.571e+12, ZT=249, TotalTransport=1.8e+08
# Gen 117: Z=7.462e+01, ZC=6.824e+12, ZT=243, TotalTransport=1.8e+08
# Gen 118: Z=8.068e+01, ZC=6.823e+12, ZT=243, TotalTransport=1.8e+08
# Gen 119: Z=7.462e+01, ZC=6.685e+12, ZT=245, TotalTransport=1.8e+08
# Gen 120: Z=8.779e+01, ZC=6.816e+12, ZT=241, TotalTransport=1.9e+08
# Gen 121: Z=1.113e+02, ZC=7.012e+12, ZT=238, TotalTransport=1.9e+08
# Gen 122: Z=1.002e+02, ZC=6.756e+12, ZT=242, TotalTransport=1.8e+08
# Gen 123: Z=7.922e+01, ZC=6.690e+12, ZT=243, TotalTransport=1.8e+08
# Gen 124: Z=8.671e+01, ZC=6.793e+12, ZT=241, TotalTransport=1.9e+08
# Gen 125: Z=7.510e+01, ZC=7.014e+12, ZT=236, TotalTransport=1.9e+08
# Gen 126: Z=7.147e+01, ZC=6.808e+12, ZT=239, TotalTransport=1.9e+08
# Gen 127: Z=7.843e+01, ZC=6.700e+12, ZT=240, TotalTransport=1.9e+08
# Gen 128: Z=6.873e+01, ZC=6.701e+12, ZT=240, TotalTransport=1.9e+08
# Gen 129: Z=7.365e+01, ZC=6.701e+12, ZT=240, TotalTransport=1.9e+08
# Gen 130: Z=8.821e+01, ZC=6.705e+12, ZT=239, TotalTransport=1.9e+08
# Gen 131: Z=1.019e+02, ZC=6.871e+12, ZT=235, TotalTransport=1.9e+08
# Gen 132: Z=9.554e+01, ZC=6.891e+12, ZT=233, TotalTransport=1.9e+08
# Gen 133: Z=9.303e+01, ZC=6.891e+12, ZT=233, TotalTransport=1.9e+08
# Gen 134: Z=8.286e+01, ZC=6.724e+12, ZT=236, TotalTransport=1.9e+08
# Gen 135: Z=9.685e+01, ZC=7.099e+12, ZT=229, TotalTransport=1.9e+08
# Gen 136: Z=8.970e+01, ZC=7.099e+12, ZT=229, TotalTransport=1.9e+08
# Gen 137: Z=8.978e+01, ZC=6.839e+12, ZT=233, TotalTransport=1.9e+08
# Gen 138: Z=8.541e+01, ZC=6.816e+12, ZT=232, TotalTransport=1.9e+08
# Gen 139: Z=9.238e+01, ZC=6.917e+12, ZT=229, TotalTransport=1.9e+08
# Gen 140: Z=1.034e+02, ZC=6.900e+12, ZT=229, TotalTransport=1.9e+08
# Gen 141: Z=1.087e+02, ZC=6.900e+12, ZT=229, TotalTransport=1.9e+08
# Gen 142: Z=1.089e+02, ZC=6.996e+12, ZT=226, TotalTransport=1.9e+08
# Gen 143: Z=1.110e+02, ZC=6.996e+12, ZT=226, TotalTransport=1.9e+08
# Gen 144: Z=1.364e+02, ZC=6.866e+12, ZT=228, TotalTransport=1.9e+08
# Gen 145: Z=1.265e+02, ZC=6.986e+12, ZT=225, TotalTransport=2.0e+08
# Gen 146: Z=9.276e+01, ZC=6.958e+12, ZT=225, TotalTransport=1.9e+08
# Gen 147: Z=1.135e+02, ZC=6.904e+12, ZT=225, TotalTransport=1.9e+08
# Gen 148: Z=1.075e+02, ZC=6.877e+12, ZT=225, TotalTransport=1.9e+08
# Gen 149: Z=1.018e+02, ZC=7.117e+12, ZT=221, TotalTransport=2.0e+08
# Gen 150: Z=8.043e+01, ZC=7.195e+12, ZT=218, TotalTransport=2.0e+08
# Gen 151: Z=7.554e+01, ZC=7.195e+12, ZT=218, TotalTransport=2.0e+08
# Gen 152: Z=6.890e+01, ZC=6.962e+12, ZT=222, TotalTransport=2.0e+08
# Gen 153: Z=8.525e+01, ZC=7.160e+12, ZT=218, TotalTransport=2.0e+08
# Gen 154: Z=9.508e+01, ZC=7.093e+12, ZT=219, TotalTransport=2.0e+08
# Gen 155: Z=1.382e+02, ZC=7.105e+12, ZT=218, TotalTransport=2.0e+08
# Gen 156: Z=1.440e+02, ZC=7.293e+12, ZT=215, TotalTransport=2.0e+08
# Gen 157: Z=1.428e+02, ZC=7.322e+12, ZT=214, TotalTransport=2.0e+08
# Gen 158: Z=1.329e+02, ZC=7.322e+12, ZT=214, TotalTransport=2.0e+08
# Gen 159: Z=9.535e+01, ZC=7.188e+12, ZT=214, TotalTransport=2.0e+08
# Gen 160: Z=9.277e+01, ZC=7.233e+12, ZT=213, TotalTransport=2.0e+08
# Gen 161: Z=8.650e+01, ZC=7.438e+12, ZT=208, TotalTransport=2.1e+08
# Gen 162: Z=9.280e+01, ZC=7.269e+12, ZT=211, TotalTransport=2.0e+08
# Gen 163: Z=9.849e+01, ZC=7.271e+12, ZT=210, TotalTransport=2.0e+08
# Gen 164: Z=8.629e+01, ZC=7.271e+12, ZT=210, TotalTransport=2.0e+08
# Gen 165: Z=8.660e+01, ZC=7.203e+12, ZT=211, TotalTransport=2.0e+08
# Gen 166: Z=9.610e+01, ZC=7.151e+12, ZT=211, TotalTransport=2.0e+08
# Gen 167: Z=9.678e+01, ZC=7.261e+12, ZT=209, TotalTransport=2.1e+08
# Gen 168: Z=1.104e+02, ZC=7.261e+12, ZT=208, TotalTransport=2.1e+08
# Gen 169: Z=1.463e+02, ZC=7.262e+12, ZT=208, TotalTransport=2.1e+08
# Gen 170: Z=1.786e+02, ZC=7.258e+12, ZT=208, TotalTransport=2.1e+08
# Gen 171: Z=1.592e+02, ZC=7.463e+12, ZT=205, TotalTransport=2.1e+08
# Gen 172: Z=1.398e+02, ZC=7.261e+12, ZT=207, TotalTransport=2.1e+08
# Gen 173: Z=1.549e+02, ZC=7.261e+12, ZT=207, TotalTransport=2.1e+08
# Gen 174: Z=1.259e+02, ZC=7.320e+12, ZT=206, TotalTransport=2.1e+08
# Gen 175: Z=1.422e+02, ZC=7.322e+12, ZT=206, TotalTransport=2.1e+08
# Gen 176: Z=1.398e+02, ZC=7.264e+12, ZT=206, TotalTransport=2.1e+08
# Gen 177: Z=1.467e+02, ZC=7.264e+12, ZT=206, TotalTransport=2.1e+08
# Gen 178: Z=1.644e+02, ZC=7.400e+12, ZT=204, TotalTransport=2.1e+08
# Gen 179: Z=1.367e+02, ZC=7.451e+12, ZT=203, TotalTransport=2.1e+08
# Gen 180: Z=1.128e+02, ZC=7.572e+12, ZT=200, TotalTransport=2.1e+08
# Gen 181: Z=1.163e+02, ZC=7.572e+12, ZT=200, TotalTransport=2.1e+08
# Gen 182: Z=9.650e+01, ZC=7.301e+12, ZT=204, TotalTransport=2.1e+08
# Gen 183: Z=1.019e+02, ZC=7.329e+12, ZT=203, TotalTransport=2.1e+08
# Gen 184: Z=9.484e+01, ZC=7.402e+12, ZT=201, TotalTransport=2.1e+08
# Gen 185: Z=1.000e+02, ZC=7.287e+12, ZT=203, TotalTransport=2.1e+08
# Gen 186: Z=1.143e+02, ZC=7.337e+12, ZT=201, TotalTransport=2.1e+08
# Gen 187: Z=9.378e+01, ZC=7.337e+12, ZT=201, TotalTransport=2.1e+08
# Gen 188: Z=9.117e+01, ZC=7.327e+12, ZT=201, TotalTransport=2.1e+08
# Gen 189: Z=1.072e+02, ZC=7.297e+12, ZT=201, TotalTransport=2.1e+08
# Gen 190: Z=1.167e+02, ZC=7.337e+12, ZT=200, TotalTransport=2.1e+08
# Gen 191: Z=1.145e+02, ZC=7.336e+12, ZT=199, TotalTransport=2.2e+08
# Gen 192: Z=1.100e+02, ZC=7.336e+12, ZT=199, TotalTransport=2.2e+08
# Gen 193: Z=1.092e+02, ZC=7.336e+12, ZT=198, TotalTransport=2.2e+08
# Gen 194: Z=1.365e+02, ZC=7.499e+12, ZT=196, TotalTransport=2.2e+08
# Gen 195: Z=1.331e+02, ZC=7.468e+12, ZT=196, TotalTransport=2.2e+08
# Gen 196: Z=1.300e+02, ZC=7.355e+12, ZT=197, TotalTransport=2.2e+08
# Gen 197: Z=1.251e+02, ZC=7.401e+12, ZT=196, TotalTransport=2.2e+08
# Gen 198: Z=1.178e+02, ZC=7.450e+12, ZT=195, TotalTransport=2.2e+08
# Gen 199: Z=1.392e+02, ZC=7.509e+12, ZT=194, TotalTransport=2.2e+08
# Gen 200: Z=1.249e+02, ZC=7.509e+12, ZT=194, TotalTransport=2.2e+08
# Gen 201: Z=1.345e+02, ZC=7.498e+12, ZT=194, TotalTransport=2.2e+08
# Gen 202: Z=1.546e+02, ZC=7.498e+12, ZT=194, TotalTransport=2.2e+08
# Gen 203: Z=1.470e+02, ZC=7.608e+12, ZT=192, TotalTransport=2.2e+08
# Gen 204: Z=1.426e+02, ZC=7.641e+12, ZT=191, TotalTransport=2.2e+08
# Gen 205: Z=1.222e+02, ZC=7.641e+12, ZT=191, TotalTransport=2.2e+08
# Gen 206: Z=1.231e+02, ZC=7.494e+12, ZT=192, TotalTransport=2.2e+08
# Gen 207: Z=1.254e+02, ZC=7.493e+12, ZT=192, TotalTransport=2.2e+08
# Gen 208: Z=1.135e+02, ZC=7.493e+12, ZT=192, TotalTransport=2.2e+08
# Gen 209: Z=1.292e+02, ZC=7.546e+12, ZT=191, TotalTransport=2.2e+08
# Gen 210: Z=1.315e+02, ZC=7.497e+12, ZT=191, TotalTransport=2.2e+08
# Gen 211: Z=1.584e+02, ZC=7.497e+12, ZT=191, TotalTransport=2.2e+08
# Gen 212: Z=1.473e+02, ZC=7.441e+12, ZT=191, TotalTransport=2.2e+08
# Gen 213: Z=1.842e+02, ZC=7.502e+12, ZT=190, TotalTransport=2.2e+08
# Gen 214: Z=1.619e+02, ZC=7.501e+12, ZT=190, TotalTransport=2.2e+08
# Gen 215: Z=1.972e+02, ZC=7.501e+12, ZT=190, TotalTransport=2.2e+08
# Gen 216: Z=1.612e+02, ZC=7.608e+12, ZT=188, TotalTransport=2.2e+08
# Gen 217: Z=1.484e+02, ZC=7.515e+12, ZT=189, TotalTransport=2.2e+08
# Gen 218: Z=1.437e+02, ZC=7.589e+12, ZT=187, TotalTransport=2.2e+08
# Gen 219: Z=1.248e+02, ZC=7.589e+12, ZT=187, TotalTransport=2.2e+08
# Gen 220: Z=1.222e+02, ZC=7.589e+12, ZT=187, TotalTransport=2.2e+08
# Gen 221: Z=1.316e+02, ZC=7.588e+12, ZT=187, TotalTransport=2.2e+08
# Gen 222: Z=1.313e+02, ZC=7.596e+12, ZT=185, TotalTransport=2.3e+08
# Gen 223: Z=1.461e+02, ZC=7.594e+12, ZT=186, TotalTransport=2.3e+08
# Gen 224: Z=1.270e+02, ZC=7.774e+12, ZT=183, TotalTransport=2.3e+08
# Gen 225: Z=1.268e+02, ZC=7.624e+12, ZT=185, TotalTransport=2.3e+08
# Gen 226: Z=1.202e+02, ZC=7.775e+12, ZT=183, TotalTransport=2.3e+08
# Gen 227: Z=1.277e+02, ZC=7.723e+12, ZT=183, TotalTransport=2.3e+08
# Gen 228: Z=1.243e+02, ZC=7.715e+12, ZT=183, TotalTransport=2.3e+08
# Gen 229: Z=1.167e+02, ZC=7.701e+12, ZT=182, TotalTransport=2.3e+08
# Gen 230: Z=1.325e+02, ZC=7.699e+12, ZT=182, TotalTransport=2.3e+08
# Gen 231: Z=1.449e+02, ZC=7.700e+12, ZT=182, TotalTransport=2.3e+08
# Gen 232: Z=1.677e+02, ZC=7.700e+12, ZT=182, TotalTransport=2.3e+08
# Gen 233: Z=1.766e+02, ZC=7.695e+12, ZT=182, TotalTransport=2.3e+08
# Gen 234: Z=2.016e+02, ZC=7.794e+12, ZT=181, TotalTransport=2.3e+08
# Gen 235: Z=2.006e+02, ZC=7.794e+12, ZT=181, TotalTransport=2.3e+08
# Gen 236: Z=1.967e+02, ZC=7.991e+12, ZT=179, TotalTransport=2.3e+08
# Gen 237: Z=1.468e+02, ZC=7.749e+12, ZT=181, TotalTransport=2.3e+08
# Gen 238: Z=1.453e+02, ZC=7.812e+12, ZT=180, TotalTransport=2.3e+08
# Gen 239: Z=1.501e+02, ZC=7.814e+12, ZT=180, TotalTransport=2.3e+08
# Gen 240: Z=1.207e+02, ZC=8.055e+12, ZT=177, TotalTransport=2.4e+08
# Gen 241: Z=9.637e+01, ZC=7.988e+12, ZT=177, TotalTransport=2.4e+08
# Gen 242: Z=7.988e+01, ZC=7.872e+12, ZT=178, TotalTransport=2.3e+08
# Gen 243: Z=9.048e+01, ZC=7.734e+12, ZT=179, TotalTransport=2.3e+08
# Gen 244: Z=9.451e+01, ZC=7.734e+12, ZT=179, TotalTransport=2.3e+08
# Gen 245: Z=9.472e+01, ZC=7.878e+12, ZT=177, TotalTransport=2.4e+08
# Gen 246: Z=9.311e+01, ZC=7.749e+12, ZT=178, TotalTransport=2.3e+08
# Gen 247: Z=1.049e+02, ZC=7.792e+12, ZT=177, TotalTransport=2.4e+08
# Gen 248: Z=9.129e+01, ZC=7.785e+12, ZT=177, TotalTransport=2.4e+08
# Gen 249: Z=1.189e+02, ZC=7.878e+12, ZT=176, TotalTransport=2.4e+08
# Gen 250: Z=1.136e+02, ZC=7.906e+12, ZT=175, TotalTransport=2.4e+08
# Gen 251: Z=1.406e+02, ZC=7.707e+12, ZT=177, TotalTransport=2.4e+08
# Gen 252: Z=1.107e+02, ZC=7.860e+12, ZT=175, TotalTransport=2.4e+08
# Gen 253: Z=1.093e+02, ZC=7.802e+12, ZT=175, TotalTransport=2.4e+08
# Gen 254: Z=1.335e+02, ZC=7.914e+12, ZT=174, TotalTransport=2.4e+08
# Gen 255: Z=1.414e+02, ZC=7.878e+12, ZT=174, TotalTransport=2.4e+08
# Gen 256: Z=1.504e+02, ZC=7.979e+12, ZT=173, TotalTransport=2.4e+08
# Gen 257: Z=1.559e+02, ZC=7.929e+12, ZT=173, TotalTransport=2.4e+08
# Gen 258: Z=1.556e+02, ZC=7.823e+12, ZT=174, TotalTransport=2.4e+08
# Gen 259: Z=1.375e+02, ZC=7.868e+12, ZT=173, TotalTransport=2.4e+08
# Gen 260: Z=1.328e+02, ZC=7.879e+12, ZT=173, TotalTransport=2.4e+08
# Gen 261: Z=1.235e+02, ZC=7.840e+12, ZT=173, TotalTransport=2.4e+08
# Gen 262: Z=1.344e+02, ZC=7.881e+12, ZT=172, TotalTransport=2.4e+08
# Gen 263: Z=1.391e+02, ZC=7.964e+12, ZT=171, TotalTransport=2.4e+08
# Gen 264: Z=1.581e+02, ZC=7.882e+12, ZT=171, TotalTransport=2.4e+08
# Gen 265: Z=1.386e+02, ZC=7.981e+12, ZT=170, TotalTransport=2.4e+08
# Gen 266: Z=1.206e+02, ZC=7.953e+12, ZT=170, TotalTransport=2.4e+08
# Gen 267: Z=1.190e+02, ZC=7.882e+12, ZT=171, TotalTransport=2.4e+08
# Gen 268: Z=1.066e+02, ZC=7.945e+12, ZT=170, TotalTransport=2.4e+08
# Gen 269: Z=1.305e+02, ZC=7.949e+12, ZT=170, TotalTransport=2.4e+08
# Gen 270: Z=1.351e+02, ZC=7.882e+12, ZT=170, TotalTransport=2.4e+08
# Gen 271: Z=1.205e+02, ZC=8.080e+12, ZT=168, TotalTransport=2.4e+08
# Gen 272: Z=1.213e+02, ZC=8.079e+12, ZT=168, TotalTransport=2.4e+08
# Gen 273: Z=1.324e+02, ZC=8.080e+12, ZT=168, TotalTransport=2.4e+08
# Gen 274: Z=1.237e+02, ZC=8.079e+12, ZT=168, TotalTransport=2.4e+08
# Gen 275: Z=1.294e+02, ZC=8.074e+12, ZT=168, TotalTransport=2.4e+08
# Gen 276: Z=1.189e+02, ZC=7.890e+12, ZT=169, TotalTransport=2.4e+08
# Gen 277: Z=1.187e+02, ZC=7.994e+12, ZT=168, TotalTransport=2.4e+08
# Gen 278: Z=1.173e+02, ZC=7.994e+12, ZT=168, TotalTransport=2.4e+08
# Gen 279: Z=1.317e+02, ZC=7.994e+12, ZT=168, TotalTransport=2.4e+08
# Gen 280: Z=1.415e+02, ZC=8.001e+12, ZT=167, TotalTransport=2.4e+08
# Gen 281: Z=2.270e+02, ZC=8.185e+12, ZT=166, TotalTransport=2.5e+08
# Gen 282: Z=1.855e+02, ZC=8.185e+12, ZT=166, TotalTransport=2.5e+08
# Gen 283: Z=1.707e+02, ZC=8.021e+12, ZT=167, TotalTransport=2.4e+08
# Gen 284: Z=1.339e+02, ZC=7.971e+12, ZT=167, TotalTransport=2.5e+08
# Gen 285: Z=1.067e+02, ZC=8.026e+12, ZT=166, TotalTransport=2.5e+08
# Gen 286: Z=1.139e+02, ZC=8.026e+12, ZT=166, TotalTransport=2.5e+08
# Gen 287: Z=1.191e+02, ZC=8.080e+12, ZT=165, TotalTransport=2.5e+08
# Gen 288: Z=1.136e+02, ZC=8.163e+12, ZT=164, TotalTransport=2.5e+08
# Gen 289: Z=1.180e+02, ZC=8.137e+12, ZT=164, TotalTransport=2.5e+08
# Gen 290: Z=1.281e+02, ZC=8.116e+12, ZT=164, TotalTransport=2.5e+08
# Gen 291: Z=1.259e+02, ZC=8.101e+12, ZT=164, TotalTransport=2.5e+08
# Gen 292: Z=1.436e+02, ZC=8.101e+12, ZT=164, TotalTransport=2.5e+08
# Gen 293: Z=1.585e+02, ZC=8.056e+12, ZT=164, TotalTransport=2.5e+08
# Gen 294: Z=1.748e+02, ZC=8.056e+12, ZT=164, TotalTransport=2.5e+08
# Gen 295: Z=1.367e+02, ZC=8.076e+12, ZT=163, TotalTransport=2.5e+08
# Gen 296: Z=1.622e+02, ZC=8.076e+12, ZT=163, TotalTransport=2.5e+08
# Gen 297: Z=1.398e+02, ZC=8.076e+12, ZT=163, TotalTransport=2.5e+08
# Gen 298: Z=1.370e+02, ZC=8.396e+12, ZT=160, TotalTransport=2.5e+08
# Gen 299: Z=1.460e+02, ZC=8.154e+12, ZT=162, TotalTransport=2.5e+08
# Gen 300: Z=1.572e+02, ZC=8.402e+12, ZT=160, TotalTransport=2.5e+08
# Gen 301: Z=9.864e+01, ZC=8.147e+12, ZT=162, TotalTransport=2.5e+08
# Gen 302: Z=1.098e+02, ZC=8.116e+12, ZT=162, TotalTransport=2.5e+08
# Gen 303: Z=1.018e+02, ZC=8.138e+12, ZT=162, TotalTransport=2.5e+08
# Gen 304: Z=1.033e+02, ZC=8.315e+12, ZT=160, TotalTransport=2.5e+08
# Gen 305: Z=1.050e+02, ZC=8.394e+12, ZT=159, TotalTransport=2.6e+08
# Gen 306: Z=1.489e+02, ZC=8.308e+12, ZT=160, TotalTransport=2.5e+08
# Gen 307: Z=1.295e+02, ZC=8.282e+12, ZT=160, TotalTransport=2.5e+08
# Gen 308: Z=1.332e+02, ZC=8.189e+12, ZT=161, TotalTransport=2.5e+08
# Gen 309: Z=1.227e+02, ZC=8.432e+12, ZT=158, TotalTransport=2.6e+08
# Gen 310: Z=1.191e+02, ZC=8.120e+12, ZT=161, TotalTransport=2.5e+08
# Gen 311: Z=1.473e+02, ZC=8.432e+12, ZT=158, TotalTransport=2.6e+08
# Gen 312: Z=1.756e+02, ZC=8.228e+12, ZT=160, TotalTransport=2.5e+08
# Gen 313: Z=1.709e+02, ZC=8.292e+12, ZT=159, TotalTransport=2.6e+08
# Gen 314: Z=1.565e+02, ZC=8.239e+12, ZT=158, TotalTransport=2.5e+08
# Gen 315: Z=1.517e+02, ZC=8.239e+12, ZT=158, TotalTransport=2.5e+08
# Gen 316: Z=1.630e+02, ZC=8.239e+12, ZT=158, TotalTransport=2.5e+08
# Gen 317: Z=1.760e+02, ZC=8.239e+12, ZT=158, TotalTransport=2.5e+08
# Gen 318: Z=2.064e+02, ZC=8.317e+12, ZT=157, TotalTransport=2.6e+08
# Gen 319: Z=1.679e+02, ZC=8.424e+12, ZT=156, TotalTransport=2.6e+08
# Gen 320: Z=1.557e+02, ZC=8.399e+12, ZT=156, TotalTransport=2.6e+08
# Gen 321: Z=1.410e+02, ZC=8.357e+12, ZT=156, TotalTransport=2.6e+08
# Gen 322: Z=1.307e+02, ZC=8.241e+12, ZT=157, TotalTransport=2.5e+08
# Gen 323: Z=1.361e+02, ZC=8.275e+12, ZT=156, TotalTransport=2.6e+08
# Gen 324: Z=1.599e+02, ZC=8.399e+12, ZT=155, TotalTransport=2.6e+08
# Gen 325: Z=1.518e+02, ZC=8.354e+12, ZT=155, TotalTransport=2.6e+08
# Gen 326: Z=1.857e+02, ZC=8.352e+12, ZT=155, TotalTransport=2.6e+08
# Gen 327: Z=1.609e+02, ZC=8.352e+12, ZT=155, TotalTransport=2.6e+08
# Gen 328: Z=1.682e+02, ZC=8.351e+12, ZT=155, TotalTransport=2.6e+08
# Gen 329: Z=2.009e+02, ZC=8.415e+12, ZT=154, TotalTransport=2.6e+08
# Gen 330: Z=1.815e+02, ZC=8.418e+12, ZT=154, TotalTransport=2.6e+08
# Gen 331: Z=1.841e+02, ZC=8.322e+12, ZT=155, TotalTransport=2.6e+08
# Gen 332: Z=1.664e+02, ZC=8.434e+12, ZT=154, TotalTransport=2.6e+08
# Gen 333: Z=2.104e+02, ZC=8.397e+12, ZT=154, TotalTransport=2.6e+08
# Gen 334: Z=1.710e+02, ZC=8.459e+12, ZT=152, TotalTransport=2.6e+08
# Gen 335: Z=1.627e+02, ZC=8.420e+12, ZT=152, TotalTransport=2.6e+08
# Gen 336: Z=1.333e+02, ZC=8.400e+12, ZT=152, TotalTransport=2.6e+08
# Gen 337: Z=1.375e+02, ZC=8.420e+12, ZT=152, TotalTransport=2.6e+08
# Gen 338: Z=1.462e+02, ZC=8.414e+12, ZT=152, TotalTransport=2.6e+08
# Gen 339: Z=1.556e+02, ZC=8.420e+12, ZT=152, TotalTransport=2.6e+08
# Gen 340: Z=2.012e+02, ZC=8.518e+12, ZT=151, TotalTransport=2.6e+08
# Gen 341: Z=1.828e+02, ZC=8.431e+12, ZT=151, TotalTransport=2.6e+08
# Gen 342: Z=1.889e+02, ZC=8.430e+12, ZT=151, TotalTransport=2.6e+08
# Gen 343: Z=1.795e+02, ZC=8.479e+12, ZT=151, TotalTransport=2.6e+08
# Gen 344: Z=1.377e+02, ZC=8.474e+12, ZT=150, TotalTransport=2.6e+08
# Gen 345: Z=2.015e+02, ZC=8.474e+12, ZT=150, TotalTransport=2.6e+08
# Gen 346: Z=2.220e+02, ZC=8.474e+12, ZT=150, TotalTransport=2.6e+08
# Gen 347: Z=2.276e+02, ZC=8.474e+12, ZT=150, TotalTransport=2.6e+08
# Gen 348: Z=2.268e+02, ZC=8.373e+12, ZT=151, TotalTransport=2.6e+08
# Gen 349: Z=1.843e+02, ZC=8.602e+12, ZT=148, TotalTransport=2.6e+08
# Gen 350: Z=1.048e+02, ZC=8.606e+12, ZT=147, TotalTransport=2.7e+08
# Gen 351: Z=9.401e+01, ZC=8.606e+12, ZT=147, TotalTransport=2.7e+08
# Gen 352: Z=8.724e+01, ZC=8.567e+12, ZT=147, TotalTransport=2.6e+08
# Gen 353: Z=8.944e+01, ZC=8.567e+12, ZT=147, TotalTransport=2.6e+08
# Gen 354: Z=1.047e+02, ZC=8.453e+12, ZT=148, TotalTransport=2.6e+08
# Gen 355: Z=1.177e+02, ZC=8.455e+12, ZT=148, TotalTransport=2.6e+08
# Gen 356: Z=1.427e+02, ZC=8.557e+12, ZT=147, TotalTransport=2.6e+08
# Gen 357: Z=1.435e+02, ZC=8.494e+12, ZT=147, TotalTransport=2.6e+08
# Gen 358: Z=1.538e+02, ZC=8.588e+12, ZT=146, TotalTransport=2.7e+08
# Gen 359: Z=1.773e+02, ZC=8.533e+12, ZT=146, TotalTransport=2.7e+08
# Gen 360: Z=1.868e+02, ZC=8.533e+12, ZT=146, TotalTransport=2.7e+08
# Gen 361: Z=1.912e+02, ZC=8.532e+12, ZT=146, TotalTransport=2.7e+08
# Gen 362: Z=2.428e+02, ZC=8.531e+12, ZT=146, TotalTransport=2.6e+08
# Gen 363: Z=3.290e+02, ZC=8.716e+12, ZT=145, TotalTransport=2.7e+08
# Gen 364: Z=2.797e+02, ZC=8.528e+12, ZT=146, TotalTransport=2.7e+08
# Gen 365: Z=2.724e+02, ZC=8.661e+12, ZT=145, TotalTransport=2.7e+08
# Gen 366: Z=3.257e+02, ZC=8.514e+12, ZT=146, TotalTransport=2.6e+08
# Gen 367: Z=2.546e+02, ZC=8.513e+12, ZT=146, TotalTransport=2.7e+08
# Gen 368: Z=2.539e+02, ZC=8.513e+12, ZT=146, TotalTransport=2.7e+08
# Gen 369: Z=2.616e+02, ZC=8.646e+12, ZT=145, TotalTransport=2.7e+08
# Gen 370: Z=2.556e+02, ZC=8.653e+12, ZT=145, TotalTransport=2.7e+08
# Gen 371: Z=2.011e+02, ZC=8.631e+12, ZT=145, TotalTransport=2.7e+08
# Gen 372: Z=1.722e+02, ZC=8.570e+12, ZT=145, TotalTransport=2.7e+08
# Gen 373: Z=1.775e+02, ZC=8.544e+12, ZT=145, TotalTransport=2.7e+08
# Gen 374: Z=2.130e+02, ZC=8.570e+12, ZT=145, TotalTransport=2.7e+08
# Gen 375: Z=2.604e+02, ZC=8.679e+12, ZT=144, TotalTransport=2.7e+08
# Gen 376: Z=2.341e+02, ZC=8.554e+12, ZT=145, TotalTransport=2.7e+08
# Gen 377: Z=2.661e+02, ZC=8.676e+12, ZT=144, TotalTransport=2.7e+08
# Gen 378: Z=2.024e+02, ZC=8.664e+12, ZT=144, TotalTransport=2.7e+08
# Gen 379: Z=2.120e+02, ZC=8.645e+12, ZT=144, TotalTransport=2.7e+08
# Gen 380: Z=2.158e+02, ZC=8.585e+12, ZT=144, TotalTransport=2.7e+08
# Gen 381: Z=2.315e+02, ZC=8.608e+12, ZT=144, TotalTransport=2.7e+08
# Gen 382: Z=2.096e+02, ZC=8.610e+12, ZT=144, TotalTransport=2.7e+08
# Gen 383: Z=2.614e+02, ZC=8.798e+12, ZT=143, TotalTransport=2.7e+08
# Gen 384: Z=1.971e+02, ZC=8.763e+12, ZT=143, TotalTransport=2.7e+08
# Gen 385: Z=2.422e+02, ZC=8.680e+12, ZT=143, TotalTransport=2.7e+08
# Gen 386: Z=2.319e+02, ZC=8.597e+12, ZT=144, TotalTransport=2.7e+08
# Gen 387: Z=1.791e+02, ZC=8.597e+12, ZT=144, TotalTransport=2.7e+08
# Gen 388: Z=2.221e+02, ZC=8.596e+12, ZT=144, TotalTransport=2.7e+08
# Gen 389: Z=2.968e+02, ZC=8.693e+12, ZT=143, TotalTransport=2.7e+08
# Gen 390: Z=4.536e+02, ZC=8.739e+12, ZT=143, TotalTransport=2.7e+08
# Gen 391: Z=3.843e+02, ZC=8.738e+12, ZT=143, TotalTransport=2.7e+08
# Gen 392: Z=2.134e+02, ZC=8.595e+12, ZT=144, TotalTransport=2.7e+08
# Gen 393: Z=2.383e+02, ZC=8.719e+12, ZT=143, TotalTransport=2.7e+08
# Gen 394: Z=2.068e+02, ZC=8.712e+12, ZT=143, TotalTransport=2.7e+08
# Gen 395: Z=1.838e+02, ZC=8.712e+12, ZT=143, TotalTransport=2.7e+08
# Gen 396: Z=2.195e+02, ZC=8.635e+12, ZT=143, TotalTransport=2.7e+08
# Gen 397: Z=1.794e+02, ZC=8.635e+12, ZT=143, TotalTransport=2.7e+08
# Gen 398: Z=2.049e+02, ZC=8.633e+12, ZT=143, TotalTransport=2.7e+08
# Gen 399: Z=2.352e+02, ZC=8.633e+12, ZT=143, TotalTransport=2.7e+08
# Gen 400: Z=2.439e+02, ZC=8.633e+12, ZT=143, TotalTransport=2.7e+08
# Gen 401: Z=2.355e+02, ZC=8.634e+12, ZT=143, TotalTransport=2.7e+08
# Gen 402: Z=2.517e+02, ZC=8.631e+12, ZT=143, TotalTransport=2.7e+08
# Gen 403: Z=2.799e+02, ZC=8.634e+12, ZT=143, TotalTransport=2.7e+08
# Gen 404: Z=3.375e+02, ZC=8.814e+12, ZT=142, TotalTransport=2.7e+08
# Gen 405: Z=2.615e+02, ZC=8.748e+12, ZT=142, TotalTransport=2.7e+08
# Gen 406: Z=1.928e+02, ZC=8.748e+12, ZT=142, TotalTransport=2.7e+08
# Gen 407: Z=2.763e+02, ZC=8.712e+12, ZT=142, TotalTransport=2.7e+08
# Gen 408: Z=2.485e+02, ZC=8.783e+12, ZT=142, TotalTransport=2.7e+08
# Gen 409: Z=2.541e+02, ZC=8.783e+12, ZT=142, TotalTransport=2.7e+08
# Gen 410: Z=1.746e+02, ZC=8.783e+12, ZT=142, TotalTransport=2.7e+08
# Gen 411: Z=1.839e+02, ZC=8.926e+12, ZT=141, TotalTransport=2.7e+08
# Gen 412: Z=1.279e+02, ZC=8.851e+12, ZT=141, TotalTransport=2.7e+08
# Gen 413: Z=1.313e+02, ZC=8.657e+12, ZT=142, TotalTransport=2.7e+08
# Gen 414: Z=1.210e+02, ZC=8.639e+12, ZT=142, TotalTransport=2.7e+08
# Gen 415: Z=1.070e+02, ZC=8.718e+12, ZT=141, TotalTransport=2.7e+08
# Gen 416: Z=1.395e+02, ZC=8.720e+12, ZT=141, TotalTransport=2.7e+08
# Gen 417: Z=1.815e+02, ZC=8.719e+12, ZT=141, TotalTransport=2.7e+08
# Gen 418: Z=2.071e+02, ZC=8.717e+12, ZT=141, TotalTransport=2.7e+08
# Gen 419: Z=2.533e+02, ZC=8.716e+12, ZT=141, TotalTransport=2.7e+08
# Gen 420: Z=2.617e+02, ZC=8.868e+12, ZT=140, TotalTransport=2.8e+08
# Gen 421: Z=2.649e+02, ZC=8.868e+12, ZT=140, TotalTransport=2.8e+08
# Gen 422: Z=2.108e+02, ZC=8.714e+12, ZT=141, TotalTransport=2.7e+08
# Gen 423: Z=3.325e+02, ZC=8.852e+12, ZT=140, TotalTransport=2.7e+08
# Gen 424: Z=2.442e+02, ZC=8.852e+12, ZT=140, TotalTransport=2.7e+08
# Gen 425: Z=1.761e+02, ZC=8.851e+12, ZT=140, TotalTransport=2.7e+08
# Gen 426: Z=1.973e+02, ZC=8.851e+12, ZT=140, TotalTransport=2.7e+08
# Gen 427: Z=1.996e+02, ZC=8.851e+12, ZT=140, TotalTransport=2.7e+08
# Gen 428: Z=2.229e+02, ZC=8.954e+12, ZT=139, TotalTransport=2.8e+08
# Gen 429: Z=3.423e+02, ZC=8.954e+12, ZT=139, TotalTransport=2.8e+08
# Gen 430: Z=2.057e+02, ZC=9.016e+12, ZT=138, TotalTransport=2.8e+08
# Gen 431: Z=1.587e+02, ZC=9.016e+12, ZT=138, TotalTransport=2.8e+08
# Gen 432: Z=1.549e+02, ZC=9.016e+12, ZT=138, TotalTransport=2.8e+08
# Gen 433: Z=1.220e+02, ZC=8.998e+12, ZT=138, TotalTransport=2.8e+08
# Gen 434: Z=1.322e+02, ZC=8.997e+12, ZT=138, TotalTransport=2.8e+08
# Gen 435: Z=1.390e+02, ZC=8.856e+12, ZT=139, TotalTransport=2.8e+08
# Gen 436: Z=1.362e+02, ZC=8.856e+12, ZT=139, TotalTransport=2.8e+08
# Gen 437: Z=1.488e+02, ZC=8.856e+12, ZT=139, TotalTransport=2.8e+08
# Gen 438: Z=1.884e+02, ZC=8.855e+12, ZT=139, TotalTransport=2.8e+08
# Gen 439: Z=1.985e+02, ZC=8.990e+12, ZT=138, TotalTransport=2.8e+08
# Gen 440: Z=2.234e+02, ZC=8.965e+12, ZT=138, TotalTransport=2.8e+08
# Gen 441: Z=2.112e+02, ZC=8.970e+12, ZT=138, TotalTransport=2.8e+08
# Gen 442: Z=2.207e+02, ZC=8.971e+12, ZT=138, TotalTransport=2.8e+08
# Gen 443: Z=1.881e+02, ZC=8.971e+12, ZT=138, TotalTransport=2.8e+08
# Gen 444: Z=1.709e+02, ZC=8.950e+12, ZT=138, TotalTransport=2.8e+08
# Gen 445: Z=1.611e+02, ZC=8.948e+12, ZT=138, TotalTransport=2.8e+08
# Gen 446: Z=1.988e+02, ZC=8.841e+12, ZT=139, TotalTransport=2.8e+08
# Gen 447: Z=2.119e+02, ZC=8.914e+12, ZT=138, TotalTransport=2.8e+08
# Gen 448: Z=2.108e+02, ZC=8.915e+12, ZT=138, TotalTransport=2.8e+08
# Gen 449: Z=2.001e+02, ZC=8.912e+12, ZT=138, TotalTransport=2.8e+08
# Gen 450: Z=2.421e+02, ZC=8.912e+12, ZT=138, TotalTransport=2.8e+08
# Gen 451: Z=2.896e+02, ZC=8.912e+12, ZT=138, TotalTransport=2.8e+08
# Gen 452: Z=3.695e+02, ZC=9.028e+12, ZT=137, TotalTransport=2.8e+08
# Gen 453: Z=2.719e+02, ZC=9.028e+12, ZT=137, TotalTransport=2.8e+08
# Gen 454: Z=2.386e+02, ZC=9.028e+12, ZT=137, TotalTransport=2.8e+08
# Gen 455: Z=1.769e+02, ZC=8.912e+12, ZT=138, TotalTransport=2.8e+08
# Gen 456: Z=2.186e+02, ZC=8.922e+12, ZT=137, TotalTransport=2.8e+08
# Gen 457: Z=4.602e+02, ZC=8.919e+12, ZT=137, TotalTransport=2.8e+08
# Gen 458: Z=2.722e+02, ZC=8.919e+12, ZT=137, TotalTransport=2.8e+08
# Gen 459: Z=3.897e+02, ZC=8.919e+12, ZT=137, TotalTransport=2.8e+08
# Gen 460: Z=2.555e+02, ZC=8.919e+12, ZT=137, TotalTransport=2.8e+08
# Gen 461: Z=1.998e+02, ZC=8.916e+12, ZT=137, TotalTransport=2.8e+08
# Gen 462: Z=1.948e+02, ZC=8.916e+12, ZT=137, TotalTransport=2.8e+08
# Gen 463: Z=2.209e+02, ZC=8.994e+12, ZT=136, TotalTransport=2.8e+08
# Gen 464: Z=2.199e+02, ZC=8.882e+12, ZT=137, TotalTransport=2.8e+08
# Gen 465: Z=2.274e+02, ZC=8.881e+12, ZT=137, TotalTransport=2.8e+08
# Gen 466: Z=2.710e+02, ZC=8.960e+12, ZT=136, TotalTransport=2.8e+08
# Gen 467: Z=2.137e+02, ZC=8.960e+12, ZT=136, TotalTransport=2.8e+08
# Gen 468: Z=1.833e+02, ZC=8.892e+12, ZT=136, TotalTransport=2.8e+08
# Gen 469: Z=1.917e+02, ZC=8.891e+12, ZT=136, TotalTransport=2.8e+08
# Gen 470: Z=2.035e+02, ZC=8.885e+12, ZT=136, TotalTransport=2.8e+08
# Gen 471: Z=2.178e+02, ZC=8.891e+12, ZT=136, TotalTransport=2.8e+08
# Gen 472: Z=2.163e+02, ZC=8.995e+12, ZT=135, TotalTransport=2.8e+08
# Gen 473: Z=2.868e+02, ZC=8.963e+12, ZT=135, TotalTransport=2.8e+08
# Gen 474: Z=6.800e+07, ZC=8.872e+12, ZT=136, TotalTransport=2.8e+08
# Gen 475: Z=6.800e+07, ZC=8.871e+12, ZT=136, TotalTransport=2.8e+08
# Gen 476: Z=4.522e+02, ZC=8.871e+12, ZT=136, TotalTransport=2.8e+08
# Gen 477: Z=4.121e+02, ZC=9.036e+12, ZT=135, TotalTransport=2.8e+08
# Gen 478: Z=3.100e+02, ZC=8.998e+12, ZT=135, TotalTransport=2.8e+08
# Gen 479: Z=2.431e+02, ZC=9.035e+12, ZT=135, TotalTransport=2.8e+08
# Gen 480: Z=1.855e+02, ZC=8.932e+12, ZT=135, TotalTransport=2.8e+08
# Gen 481: Z=1.798e+02, ZC=8.932e+12, ZT=135, TotalTransport=2.8e+08
# Gen 482: Z=1.714e+02, ZC=8.932e+12, ZT=135, TotalTransport=2.8e+08
# Gen 483: Z=1.475e+02, ZC=8.925e+12, ZT=135, TotalTransport=2.8e+08
# Gen 484: Z=1.559e+02, ZC=8.925e+12, ZT=135, TotalTransport=2.8e+08
# Gen 485: Z=1.534e+02, ZC=9.000e+12, ZT=134, TotalTransport=2.8e+08
# Gen 486: Z=1.615e+02, ZC=8.984e+12, ZT=134, TotalTransport=2.8e+08
# Gen 487: Z=1.806e+02, ZC=8.974e+12, ZT=134, TotalTransport=2.8e+08
# Gen 488: Z=1.957e+02, ZC=8.960e+12, ZT=134, TotalTransport=2.8e+08
# Gen 489: Z=1.907e+02, ZC=8.960e+12, ZT=134, TotalTransport=2.8e+08
# Gen 490: Z=1.866e+02, ZC=8.947e+12, ZT=134, TotalTransport=2.8e+08
# Gen 491: Z=2.354e+02, ZC=8.960e+12, ZT=134, TotalTransport=2.8e+08
# Gen 492: Z=2.576e+02, ZC=8.960e+12, ZT=134, TotalTransport=2.8e+08
# Gen 493: Z=2.683e+02, ZC=8.959e+12, ZT=134, TotalTransport=2.8e+08
# Gen 494: Z=3.342e+02, ZC=8.959e+12, ZT=134, TotalTransport=2.8e+08
# Gen 495: Z=2.358e+02, ZC=8.959e+12, ZT=134, TotalTransport=2.8e+08
# Gen 496: Z=4.369e+02, ZC=8.959e+12, ZT=134, TotalTransport=2.8e+08
# Gen 497: Z=5.782e+02, ZC=8.959e+12, ZT=134, TotalTransport=2.8e+08
# Gen 498: Z=4.535e+02, ZC=8.959e+12, ZT=134, TotalTransport=2.8e+08
# Gen 499: Z=2.574e+02, ZC=8.959e+12, ZT=134, TotalTransport=2.8e+08
# 最终总运输量 = 280576930.85395473
# 火箭运输量 =  197573100
# 太空电梯运输量 =  83003830.85395473
