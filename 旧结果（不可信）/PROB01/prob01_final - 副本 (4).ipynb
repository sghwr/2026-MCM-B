# %%
from deap import base, creator, tools
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 全局参数

# %%
TMAX = 500         # 为演示缩短长度，实际可设1000
K = 10
P = 3

D_total = 1e8
Cap_rocket = 150
Cap_lift = 179000
L_max = 800

Cost_rocket = 500000
Cost_lift = 100000

# %% [markdown]
# 初始化DEAP

# %%
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()

# 火箭发射次数 (整数)
toolbox.register("attr_R", lambda: random.randint(0, L_max))
# 电梯运输量 (连续)
toolbox.register("attr_E", lambda: random.uniform(0, Cap_lift))

def init_individual():
    """保证初始化总运输量大约 D_total / TMAX"""
    ind = []
    avg_rocket_per_year = D_total / TMAX / 2 / Cap_rocket / K
    avg_lift_per_year = D_total / TMAX / 2 / P

    for _ in range(K*TMAX):
        val = max(1, int(random.gauss(avg_rocket_per_year, avg_rocket_per_year*0.5)))
        ind.append(min(val, L_max))

    for _ in range(P*TMAX):
        val = random.gauss(avg_lift_per_year, avg_lift_per_year*0.5)
        val = max(0, min(val, Cap_lift))
        ind.append(val)

    return creator.Individual(ind)

toolbox.register("individual", init_individual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %% [markdown]
# fitness分配

# %%
def assign_fitness(pop, w1=0.5, w2=0.5):
    ZC_list = []
    ZT_list = []

    for ind in pop:
        R = np.array(ind[:K*TMAX]).reshape(K, TMAX)
        E = np.array(ind[K*TMAX:]).reshape(P, TMAX)

        # 总成本
        ZC = Cost_rocket * np.sum(R) + Cost_lift * np.sum(E)

        # 总工期
        transported = 0
        ZT = TMAX
        for t in range(TMAX):
            R_t = np.sum(R[:, t]) * Cap_rocket
            E_t = np.sum(E[:, t])
            transported += R_t + E_t
            if transported >= D_total:
                ZT = t + 1
                break

        # 罚函数: 总运输量不足时增加 fitness
        #penalty = max(0, D_total - transported) * 1e-3  # 连续罚函数
        # 改进的罚函数：同时惩罚不足和超额
        penalty = 0
        if transported < D_total:
            # 不足：严重惩罚
            penalty += (D_total - transported) * 1e6
        else:
            # 超额：适度惩罚，避免严重浪费
            excess = transported - D_total
            # 超额惩罚：超过5%开始惩罚，惩罚递增
            if excess > D_total * 0.05:
                penalty += (excess - D_total * 0.05) * 1e3

                
        ind.ZC = ZC
        ind.ZT = ZT
        ind.penalty = penalty

        ZC_list.append(ZC)
        ZT_list.append(ZT)

    # 种群内标准化
    std_C = np.std(ZC_list) + 1e-6
    std_T = np.std(ZT_list) + 1e-6

    for ind in pop:
        fitness_val = w1 * ind.ZC / std_C + w2 * ind.ZT / std_T + ind.penalty
        ind.fitness.values = (fitness_val,)

# %% [markdown]
# 遗传算子

# %%
toolbox.register("mate", tools.cxTwoPoint)

def mutate_bound(ind, mu_R=0, sigma_R=100, mu_E=0, sigma_E=5e4, indpb=0.1):
    for i in range(len(ind)):
        if random.random() < indpb:
            if i < K*TMAX:
                ind[i] += int(round(random.gauss(mu_R, sigma_R)))
                ind[i] = max(0, min(L_max, ind[i]))
            else:
                ind[i] += random.gauss(mu_E, sigma_E)
                ind[i] = max(0, min(Cap_lift, ind[i]))
    return ind,

toolbox.register("mutate", mutate_bound)
toolbox.register("select", tools.selTournament, tournsize=3)

# %% [markdown]
# main函数入口

# %%
def main():
    pop = toolbox.population(n=50)
    NGEN = 800
    CXPB = 0.7
    MUTPB = 0.2

    assign_fitness(pop)

    for gen in range(NGEN):
        offspring = toolbox.select(pop, len(pop))
        offspring = list(map(toolbox.clone, offspring))

        # 交叉
        for c1, c2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < CXPB:
                toolbox.mate(c1, c2)
                del c1.fitness.values, c2.fitness.values

        # 变异
        for ind in offspring:
            if random.random() < MUTPB:
                toolbox.mutate(ind)
                del ind.fitness.values

        assign_fitness(offspring)
        pop[:] = offspring

        best = tools.selBest(pop, 1)[0]
        total_transported = np.sum(best[:K*TMAX])*Cap_rocket + np.sum(best[K*TMAX:])
        print(f"Gen {gen}: Z={best.fitness.values[0]:.3e}, "
              f"ZC={best.ZC:.3e}, ZT={best.ZT}, TotalTransport={total_transported:.1e}")

    return tools.selBest(pop, 1)[0]

# %% [markdown]
# 运行GA

# %%
best_ind = main()

R = np.array(best_ind[:K*TMAX]).reshape(K, TMAX)
E = np.array(best_ind[K*TMAX:]).reshape(P, TMAX)

ROCKET = pd.DataFrame(R)
ELEVATOR = pd.DataFrame(E)
ROCKET.to_excel((r"D:\USELESS\数据分析学习\数学建模学习\2026美赛\B\ROCKET1.xlsx"))
ELEVATOR.to_excel((r"D:\USELESS\数据分析学习\数学建模学习\2026美赛\B\ELEVATOR1.xlsx"))
print("最终总运输量 =", np.sum(R)*Cap_rocket + np.sum(E))
print('火箭运输量 = ', np.sum(R)*Cap_rocket)
print('太空电梯运输量 = ', np.sum(E))
# Out:
# Gen 0: Z=9.021e+01, ZC=5.307e+12, ZT=485, TotalTransport=1.0e+08
# Gen 1: Z=6.597e+01, ZC=5.310e+12, ZT=483, TotalTransport=1.0e+08
# Gen 2: Z=6.732e+01, ZC=5.172e+12, ZT=490, TotalTransport=1.0e+08
# Gen 3: Z=6.131e+01, ZC=5.347e+12, ZT=474, TotalTransport=1.1e+08
# Gen 4: Z=5.772e+01, ZC=5.280e+12, ZT=476, TotalTransport=1.1e+08
# Gen 5: Z=5.020e+01, ZC=5.167e+12, ZT=481, TotalTransport=1.0e+08
# Gen 6: Z=4.737e+01, ZC=5.420e+12, ZT=461, TotalTransport=1.1e+08
# Gen 7: Z=4.282e+01, ZC=5.252e+12, ZT=468, TotalTransport=1.1e+08
# Gen 8: Z=4.755e+01, ZC=5.305e+12, ZT=462, TotalTransport=1.1e+08
# Gen 9: Z=4.789e+01, ZC=5.351e+12, ZT=458, TotalTransport=1.1e+08
# Gen 10: Z=4.980e+01, ZC=5.200e+12, ZT=467, TotalTransport=1.1e+08
# Gen 11: Z=5.677e+01, ZC=5.400e+12, ZT=450, TotalTransport=1.1e+08
# Gen 12: Z=4.817e+01, ZC=5.265e+12, ZT=458, TotalTransport=1.1e+08
# Gen 13: Z=5.467e+01, ZC=5.480e+12, ZT=439, TotalTransport=1.1e+08
# Gen 14: Z=6.149e+01, ZC=5.364e+12, ZT=444, TotalTransport=1.1e+08
# Gen 15: Z=5.850e+01, ZC=5.364e+12, ZT=443, TotalTransport=1.1e+08
# Gen 16: Z=4.790e+01, ZC=5.364e+12, ZT=443, TotalTransport=1.1e+08
# Gen 17: Z=5.465e+01, ZC=5.569e+12, ZT=424, TotalTransport=1.2e+08
# Gen 18: Z=5.426e+01, ZC=5.485e+12, ZT=427, TotalTransport=1.2e+08
# Gen 19: Z=5.407e+01, ZC=5.507e+12, ZT=423, TotalTransport=1.2e+08
# Gen 20: Z=7.277e+01, ZC=5.330e+12, ZT=432, TotalTransport=1.2e+08
# Gen 21: Z=6.282e+01, ZC=5.330e+12, ZT=432, TotalTransport=1.2e+08
# Gen 22: Z=4.905e+01, ZC=5.563e+12, ZT=416, TotalTransport=1.2e+08
# Gen 23: Z=4.966e+01, ZC=5.466e+12, ZT=420, TotalTransport=1.2e+08
# Gen 24: Z=4.827e+01, ZC=5.558e+12, ZT=409, TotalTransport=1.2e+08
# Gen 25: Z=4.430e+01, ZC=5.461e+12, ZT=413, TotalTransport=1.2e+08
# Gen 26: Z=5.711e+01, ZC=5.507e+12, ZT=408, TotalTransport=1.2e+08
# Gen 27: Z=5.586e+01, ZC=5.628e+12, ZT=398, TotalTransport=1.2e+08
# Gen 28: Z=5.017e+01, ZC=5.748e+12, ZT=389, TotalTransport=1.3e+08
# Gen 29: Z=5.378e+01, ZC=5.748e+12, ZT=388, TotalTransport=1.3e+08
# Gen 30: Z=4.991e+01, ZC=5.592e+12, ZT=395, TotalTransport=1.3e+08
# Gen 31: Z=5.714e+01, ZC=5.595e+12, ZT=393, TotalTransport=1.3e+08
# Gen 32: Z=7.239e+01, ZC=5.662e+12, ZT=387, TotalTransport=1.3e+08
# Gen 33: Z=7.003e+01, ZC=5.679e+12, ZT=386, TotalTransport=1.3e+08
# Gen 34: Z=7.821e+01, ZC=5.556e+12, ZT=390, TotalTransport=1.3e+08
# Gen 35: Z=8.265e+01, ZC=5.745e+12, ZT=380, TotalTransport=1.3e+08
# Gen 36: Z=8.459e+01, ZC=5.670e+12, ZT=381, TotalTransport=1.3e+08
# Gen 37: Z=5.484e+01, ZC=5.757e+12, ZT=376, TotalTransport=1.3e+08
# Gen 38: Z=5.994e+01, ZC=5.633e+12, ZT=380, TotalTransport=1.3e+08
# Gen 39: Z=6.449e+01, ZC=5.603e+12, ZT=379, TotalTransport=1.3e+08
# Gen 40: Z=5.368e+01, ZC=5.604e+12, ZT=378, TotalTransport=1.3e+08
# Gen 41: Z=4.689e+01, ZC=6.024e+12, ZT=357, TotalTransport=1.4e+08
# Gen 42: Z=3.908e+01, ZC=5.615e+12, ZT=371, TotalTransport=1.3e+08
# Gen 43: Z=4.067e+01, ZC=5.615e+12, ZT=371, TotalTransport=1.3e+08
# Gen 44: Z=3.612e+01, ZC=5.885e+12, ZT=359, TotalTransport=1.4e+08
# Gen 45: Z=4.057e+01, ZC=5.893e+12, ZT=357, TotalTransport=1.4e+08
# Gen 46: Z=4.369e+01, ZC=5.857e+12, ZT=356, TotalTransport=1.4e+08
# Gen 47: Z=4.725e+01, ZC=5.804e+12, ZT=355, TotalTransport=1.4e+08
# Gen 48: Z=6.121e+01, ZC=5.731e+12, ZT=357, TotalTransport=1.4e+08
# Gen 49: Z=6.155e+01, ZC=5.951e+12, ZT=347, TotalTransport=1.4e+08
# Gen 50: Z=9.893e+01, ZC=5.812e+12, ZT=352, TotalTransport=1.4e+08
# Gen 51: Z=8.113e+01, ZC=5.761e+12, ZT=351, TotalTransport=1.4e+08
# Gen 52: Z=7.008e+01, ZC=5.761e+12, ZT=351, TotalTransport=1.4e+08
# Gen 53: Z=7.234e+01, ZC=5.912e+12, ZT=345, TotalTransport=1.4e+08
# Gen 54: Z=6.927e+01, ZC=5.854e+12, ZT=344, TotalTransport=1.4e+08
# Gen 55: Z=7.729e+01, ZC=5.992e+12, ZT=340, TotalTransport=1.4e+08
# Gen 56: Z=7.040e+01, ZC=5.917e+12, ZT=342, TotalTransport=1.4e+08
# Gen 57: Z=6.530e+01, ZC=5.903e+12, ZT=341, TotalTransport=1.4e+08
# Gen 58: Z=7.115e+01, ZC=6.134e+12, ZT=332, TotalTransport=1.5e+08
# Gen 59: Z=6.038e+01, ZC=5.851e+12, ZT=340, TotalTransport=1.4e+08
# Gen 60: Z=6.006e+01, ZC=6.274e+12, ZT=324, TotalTransport=1.5e+08
# Gen 61: Z=4.549e+01, ZC=6.197e+12, ZT=326, TotalTransport=1.5e+08
# Gen 62: Z=4.283e+01, ZC=5.978e+12, ZT=333, TotalTransport=1.5e+08
# Gen 63: Z=4.315e+01, ZC=6.038e+12, ZT=324, TotalTransport=1.5e+08
# Gen 64: Z=4.602e+01, ZC=5.847e+12, ZT=330, TotalTransport=1.5e+08
# Gen 65: Z=4.912e+01, ZC=5.847e+12, ZT=329, TotalTransport=1.5e+08
# Gen 66: Z=4.454e+01, ZC=6.231e+12, ZT=317, TotalTransport=1.5e+08
# Gen 67: Z=4.457e+01, ZC=6.009e+12, ZT=323, TotalTransport=1.5e+08
# Gen 68: Z=5.275e+01, ZC=6.200e+12, ZT=315, TotalTransport=1.5e+08
# Gen 69: Z=5.321e+01, ZC=6.025e+12, ZT=319, TotalTransport=1.5e+08
# Gen 70: Z=5.596e+01, ZC=6.028e+12, ZT=318, TotalTransport=1.5e+08
# Gen 71: Z=5.900e+01, ZC=6.226e+12, ZT=311, TotalTransport=1.5e+08
# Gen 72: Z=5.921e+01, ZC=6.016e+12, ZT=316, TotalTransport=1.5e+08
# Gen 73: Z=5.532e+01, ZC=6.419e+12, ZT=302, TotalTransport=1.6e+08
# Gen 74: Z=5.149e+01, ZC=6.212e+12, ZT=302, TotalTransport=1.6e+08
# Gen 75: Z=4.328e+01, ZC=6.212e+12, ZT=302, TotalTransport=1.6e+08
# Gen 76: Z=5.104e+01, ZC=6.236e+12, ZT=302, TotalTransport=1.6e+08
# Gen 77: Z=7.001e+01, ZC=6.232e+12, ZT=301, TotalTransport=1.6e+08
# Gen 78: Z=8.609e+01, ZC=6.261e+12, ZT=299, TotalTransport=1.6e+08
# Gen 79: Z=7.417e+01, ZC=6.418e+12, ZT=293, TotalTransport=1.6e+08
# Gen 80: Z=6.534e+01, ZC=6.364e+12, ZT=294, TotalTransport=1.6e+08
# Gen 81: Z=5.328e+01, ZC=6.169e+12, ZT=299, TotalTransport=1.6e+08
# Gen 82: Z=5.744e+01, ZC=6.580e+12, ZT=287, TotalTransport=1.6e+08
# Gen 83: Z=5.389e+01, ZC=6.439e+12, ZT=290, TotalTransport=1.6e+08
# Gen 84: Z=5.899e+01, ZC=6.238e+12, ZT=295, TotalTransport=1.6e+08
# Gen 85: Z=5.203e+01, ZC=6.190e+12, ZT=294, TotalTransport=1.6e+08
# Gen 86: Z=6.192e+01, ZC=6.190e+12, ZT=294, TotalTransport=1.6e+08
# Gen 87: Z=5.461e+01, ZC=6.409e+12, ZT=287, TotalTransport=1.6e+08
# Gen 88: Z=5.335e+01, ZC=6.409e+12, ZT=287, TotalTransport=1.6e+08
# Gen 89: Z=7.844e+01, ZC=6.311e+12, ZT=289, TotalTransport=1.6e+08
# Gen 90: Z=8.831e+01, ZC=6.361e+12, ZT=287, TotalTransport=1.6e+08
# Gen 91: Z=7.441e+01, ZC=6.465e+12, ZT=281, TotalTransport=1.7e+08
# Gen 92: Z=8.333e+01, ZC=6.415e+12, ZT=282, TotalTransport=1.6e+08
# Gen 93: Z=8.062e+01, ZC=6.573e+12, ZT=277, TotalTransport=1.7e+08
# Gen 94: Z=6.053e+01, ZC=6.582e+12, ZT=276, TotalTransport=1.7e+08
# Gen 95: Z=5.641e+01, ZC=6.546e+12, ZT=277, TotalTransport=1.7e+08
# Gen 96: Z=6.326e+01, ZC=6.546e+12, ZT=277, TotalTransport=1.7e+08
# Gen 97: Z=6.531e+01, ZC=6.362e+12, ZT=281, TotalTransport=1.7e+08
# Gen 98: Z=6.696e+01, ZC=6.568e+12, ZT=275, TotalTransport=1.7e+08
# Gen 99: Z=6.868e+01, ZC=6.406e+12, ZT=277, TotalTransport=1.7e+08
# Gen 100: Z=4.999e+01, ZC=6.409e+12, ZT=276, TotalTransport=1.7e+08
# Gen 101: Z=5.738e+01, ZC=6.355e+12, ZT=276, TotalTransport=1.7e+08
# Gen 102: Z=5.540e+01, ZC=6.868e+12, ZT=263, TotalTransport=1.8e+08
# Gen 103: Z=5.387e+01, ZC=6.868e+12, ZT=263, TotalTransport=1.8e+08
# Gen 104: Z=5.372e+01, ZC=6.761e+12, ZT=265, TotalTransport=1.7e+08
# Gen 105: Z=5.281e+01, ZC=6.498e+12, ZT=270, TotalTransport=1.7e+08
# Gen 106: Z=4.890e+01, ZC=6.778e+12, ZT=262, TotalTransport=1.8e+08
# Gen 107: Z=5.790e+01, ZC=6.847e+12, ZT=260, TotalTransport=1.8e+08
# Gen 108: Z=5.425e+01, ZC=6.848e+12, ZT=260, TotalTransport=1.8e+08
# Gen 109: Z=4.992e+01, ZC=6.779e+12, ZT=260, TotalTransport=1.8e+08
# Gen 110: Z=5.872e+01, ZC=6.830e+12, ZT=258, TotalTransport=1.8e+08
# Gen 111: Z=6.069e+01, ZC=6.941e+12, ZT=255, TotalTransport=1.8e+08
# Gen 112: Z=7.363e+01, ZC=6.918e+12, ZT=255, TotalTransport=1.8e+08
# Gen 113: Z=8.843e+01, ZC=6.876e+12, ZT=255, TotalTransport=1.8e+08
# Gen 114: Z=1.192e+02, ZC=6.878e+12, ZT=254, TotalTransport=1.8e+08
# Gen 115: Z=8.618e+01, ZC=6.994e+12, ZT=249, TotalTransport=1.8e+08
# Gen 116: Z=7.196e+01, ZC=6.936e+12, ZT=250, TotalTransport=1.8e+08
# Gen 117: Z=8.110e+01, ZC=6.950e+12, ZT=249, TotalTransport=1.8e+08
# Gen 118: Z=9.262e+01, ZC=6.876e+12, ZT=250, TotalTransport=1.8e+08
# Gen 119: Z=1.190e+02, ZC=6.874e+12, ZT=250, TotalTransport=1.8e+08
# Gen 120: Z=1.183e+02, ZC=6.887e+12, ZT=249, TotalTransport=1.8e+08
# Gen 121: Z=8.752e+01, ZC=6.941e+12, ZT=246, TotalTransport=1.8e+08
# Gen 122: Z=7.617e+01, ZC=7.083e+12, ZT=242, TotalTransport=1.9e+08
# Gen 123: Z=8.849e+01, ZC=6.945e+12, ZT=245, TotalTransport=1.8e+08
# Gen 124: Z=8.308e+01, ZC=6.943e+12, ZT=245, TotalTransport=1.8e+08
# Gen 125: Z=1.001e+02, ZC=6.943e+12, ZT=244, TotalTransport=1.8e+08
# Gen 126: Z=9.306e+01, ZC=7.139e+12, ZT=240, TotalTransport=1.9e+08
# Gen 127: Z=8.954e+01, ZC=7.242e+12, ZT=238, TotalTransport=1.9e+08
# Gen 128: Z=7.486e+01, ZC=7.222e+12, ZT=237, TotalTransport=1.9e+08
# Gen 129: Z=6.525e+01, ZC=7.220e+12, ZT=237, TotalTransport=1.9e+08
# Gen 130: Z=7.145e+01, ZC=7.240e+12, ZT=235, TotalTransport=1.9e+08
# Gen 131: Z=7.568e+01, ZC=7.159e+12, ZT=236, TotalTransport=1.9e+08
# Gen 132: Z=9.323e+01, ZC=7.113e+12, ZT=237, TotalTransport=1.9e+08
# Gen 133: Z=1.032e+02, ZC=7.208e+12, ZT=234, TotalTransport=1.9e+08
# Gen 134: Z=1.071e+02, ZC=7.198e+12, ZT=234, TotalTransport=1.9e+08
# Gen 135: Z=1.042e+02, ZC=7.362e+12, ZT=230, TotalTransport=1.9e+08
# Gen 136: Z=1.116e+02, ZC=7.191e+12, ZT=233, TotalTransport=1.9e+08
# Gen 137: Z=1.203e+02, ZC=7.302e+12, ZT=229, TotalTransport=1.9e+08
# Gen 138: Z=1.165e+02, ZC=7.181e+12, ZT=231, TotalTransport=1.9e+08
# Gen 139: Z=1.068e+02, ZC=7.181e+12, ZT=230, TotalTransport=1.9e+08
# Gen 140: Z=1.203e+02, ZC=7.181e+12, ZT=230, TotalTransport=1.9e+08
# Gen 141: Z=9.186e+01, ZC=7.347e+12, ZT=227, TotalTransport=2.0e+08
# Gen 142: Z=8.372e+01, ZC=7.376e+12, ZT=226, TotalTransport=2.0e+08
# Gen 143: Z=9.560e+01, ZC=7.329e+12, ZT=226, TotalTransport=2.0e+08
# Gen 144: Z=1.049e+02, ZC=7.329e+12, ZT=226, TotalTransport=2.0e+08
# Gen 145: Z=9.303e+01, ZC=7.226e+12, ZT=227, TotalTransport=2.0e+08
# Gen 146: Z=7.896e+01, ZC=7.461e+12, ZT=222, TotalTransport=2.0e+08
# Gen 147: Z=8.805e+01, ZC=7.443e+12, ZT=221, TotalTransport=2.0e+08
# Gen 148: Z=8.033e+01, ZC=7.442e+12, ZT=221, TotalTransport=2.0e+08
# Gen 149: Z=7.975e+01, ZC=7.442e+12, ZT=221, TotalTransport=2.0e+08
# Gen 150: Z=8.598e+01, ZC=7.571e+12, ZT=219, TotalTransport=2.0e+08
# Gen 151: Z=7.925e+01, ZC=7.316e+12, ZT=222, TotalTransport=2.0e+08
# Gen 152: Z=8.775e+01, ZC=7.595e+12, ZT=217, TotalTransport=2.0e+08
# Gen 153: Z=8.827e+01, ZC=7.392e+12, ZT=220, TotalTransport=2.0e+08
# Gen 154: Z=1.011e+02, ZC=7.455e+12, ZT=218, TotalTransport=2.0e+08
# Gen 155: Z=9.382e+01, ZC=7.397e+12, ZT=219, TotalTransport=2.0e+08
# Gen 156: Z=9.027e+01, ZC=7.338e+12, ZT=219, TotalTransport=2.0e+08
# Gen 157: Z=9.518e+01, ZC=7.367e+12, ZT=217, TotalTransport=2.0e+08
# Gen 158: Z=1.059e+02, ZC=7.367e+12, ZT=217, TotalTransport=2.0e+08
# Gen 159: Z=1.052e+02, ZC=7.367e+12, ZT=217, TotalTransport=2.0e+08
# Gen 160: Z=1.046e+02, ZC=7.652e+12, ZT=213, TotalTransport=2.1e+08
# Gen 161: Z=1.134e+02, ZC=7.420e+12, ZT=215, TotalTransport=2.0e+08
# Gen 162: Z=1.017e+02, ZC=7.863e+12, ZT=209, TotalTransport=2.1e+08
# Gen 163: Z=8.972e+01, ZC=7.439e+12, ZT=215, TotalTransport=2.0e+08
# Gen 164: Z=7.456e+01, ZC=7.418e+12, ZT=215, TotalTransport=2.0e+08
# Gen 165: Z=8.853e+01, ZC=7.420e+12, ZT=214, TotalTransport=2.0e+08
# Gen 166: Z=7.087e+01, ZC=7.645e+12, ZT=210, TotalTransport=2.1e+08
# Gen 167: Z=7.948e+01, ZC=7.371e+12, ZT=214, TotalTransport=2.0e+08
# Gen 168: Z=7.537e+01, ZC=7.548e+12, ZT=211, TotalTransport=2.1e+08
# Gen 169: Z=8.054e+01, ZC=7.435e+12, ZT=212, TotalTransport=2.1e+08
# Gen 170: Z=1.051e+02, ZC=7.503e+12, ZT=210, TotalTransport=2.1e+08
# Gen 171: Z=1.017e+02, ZC=7.665e+12, ZT=207, TotalTransport=2.1e+08
# Gen 172: Z=9.947e+01, ZC=7.472e+12, ZT=209, TotalTransport=2.1e+08
# Gen 173: Z=9.232e+01, ZC=7.487e+12, ZT=209, TotalTransport=2.1e+08
# Gen 174: Z=1.313e+02, ZC=7.526e+12, ZT=208, TotalTransport=2.1e+08
# Gen 175: Z=1.252e+02, ZC=7.717e+12, ZT=204, TotalTransport=2.1e+08
# Gen 176: Z=1.064e+02, ZC=7.692e+12, ZT=204, TotalTransport=2.1e+08
# Gen 177: Z=9.181e+01, ZC=7.634e+12, ZT=205, TotalTransport=2.1e+08
# Gen 178: Z=1.185e+02, ZC=7.668e+12, ZT=204, TotalTransport=2.1e+08
# Gen 179: Z=1.103e+02, ZC=7.741e+12, ZT=202, TotalTransport=2.1e+08
# Gen 180: Z=1.030e+02, ZC=7.741e+12, ZT=202, TotalTransport=2.1e+08
# Gen 181: Z=1.252e+02, ZC=7.741e+12, ZT=202, TotalTransport=2.1e+08
# Gen 182: Z=1.175e+02, ZC=7.673e+12, ZT=202, TotalTransport=2.1e+08
# Gen 183: Z=1.307e+02, ZC=7.673e+12, ZT=202, TotalTransport=2.1e+08
# Gen 184: Z=1.645e+02, ZC=7.673e+12, ZT=202, TotalTransport=2.1e+08
# Gen 185: Z=1.339e+02, ZC=7.849e+12, ZT=199, TotalTransport=2.2e+08
# Gen 186: Z=1.304e+02, ZC=7.748e+12, ZT=200, TotalTransport=2.2e+08
# Gen 187: Z=1.250e+02, ZC=7.746e+12, ZT=199, TotalTransport=2.2e+08
# Gen 188: Z=1.293e+02, ZC=7.825e+12, ZT=198, TotalTransport=2.2e+08
# Gen 189: Z=1.123e+02, ZC=7.765e+12, ZT=198, TotalTransport=2.2e+08
# Gen 190: Z=1.192e+02, ZC=7.765e+12, ZT=198, TotalTransport=2.2e+08
# Gen 191: Z=1.267e+02, ZC=7.763e+12, ZT=198, TotalTransport=2.2e+08
# Gen 192: Z=1.347e+02, ZC=7.894e+12, ZT=196, TotalTransport=2.2e+08
# Gen 193: Z=1.108e+02, ZC=7.931e+12, ZT=195, TotalTransport=2.2e+08
# Gen 194: Z=1.051e+02, ZC=7.896e+12, ZT=195, TotalTransport=2.2e+08
# Gen 195: Z=1.279e+02, ZC=7.851e+12, ZT=195, TotalTransport=2.2e+08
# Gen 196: Z=1.220e+02, ZC=7.776e+12, ZT=195, TotalTransport=2.2e+08
# Gen 197: Z=1.158e+02, ZC=7.878e+12, ZT=194, TotalTransport=2.2e+08
# Gen 198: Z=1.275e+02, ZC=7.851e+12, ZT=194, TotalTransport=2.2e+08
# Gen 199: Z=1.762e+02, ZC=7.921e+12, ZT=193, TotalTransport=2.2e+08
# Gen 200: Z=1.193e+02, ZC=8.037e+12, ZT=190, TotalTransport=2.2e+08
# Gen 201: Z=1.074e+02, ZC=8.037e+12, ZT=190, TotalTransport=2.2e+08
# Gen 202: Z=1.035e+02, ZC=7.844e+12, ZT=193, TotalTransport=2.2e+08
# Gen 203: Z=9.588e+01, ZC=7.823e+12, ZT=193, TotalTransport=2.2e+08
# Gen 204: Z=1.022e+02, ZC=8.047e+12, ZT=189, TotalTransport=2.3e+08
# Gen 205: Z=1.001e+02, ZC=7.878e+12, ZT=191, TotalTransport=2.2e+08
# Gen 206: Z=1.012e+02, ZC=7.863e+12, ZT=191, TotalTransport=2.2e+08
# Gen 207: Z=1.218e+02, ZC=7.914e+12, ZT=190, TotalTransport=2.2e+08
# Gen 208: Z=1.612e+02, ZC=7.902e+12, ZT=190, TotalTransport=2.3e+08
# Gen 209: Z=1.535e+02, ZC=7.998e+12, ZT=189, TotalTransport=2.3e+08
# Gen 210: Z=1.863e+02, ZC=7.963e+12, ZT=189, TotalTransport=2.3e+08
# Gen 211: Z=1.978e+02, ZC=7.963e+12, ZT=189, TotalTransport=2.3e+08
# Gen 212: Z=2.193e+02, ZC=7.919e+12, ZT=189, TotalTransport=2.3e+08
# Gen 213: Z=1.829e+02, ZC=8.073e+12, ZT=187, TotalTransport=2.3e+08
# Gen 214: Z=1.360e+02, ZC=8.072e+12, ZT=187, TotalTransport=2.3e+08
# Gen 215: Z=1.369e+02, ZC=7.998e+12, ZT=187, TotalTransport=2.3e+08
# Gen 216: Z=1.136e+02, ZC=7.998e+12, ZT=187, TotalTransport=2.3e+08
# Gen 217: Z=1.430e+02, ZC=8.070e+12, ZT=186, TotalTransport=2.3e+08
# Gen 218: Z=1.531e+02, ZC=7.919e+12, ZT=187, TotalTransport=2.3e+08
# Gen 219: Z=2.379e+02, ZC=7.919e+12, ZT=187, TotalTransport=2.3e+08
# Gen 220: Z=1.577e+02, ZC=7.987e+12, ZT=186, TotalTransport=2.3e+08
# Gen 221: Z=1.745e+02, ZC=7.987e+12, ZT=186, TotalTransport=2.3e+08
# Gen 222: Z=1.712e+02, ZC=8.163e+12, ZT=183, TotalTransport=2.3e+08
# Gen 223: Z=1.448e+02, ZC=8.163e+12, ZT=183, TotalTransport=2.3e+08
# Gen 224: Z=1.418e+02, ZC=7.981e+12, ZT=185, TotalTransport=2.3e+08
# Gen 225: Z=1.616e+02, ZC=7.996e+12, ZT=184, TotalTransport=2.3e+08
# Gen 226: Z=2.070e+02, ZC=8.101e+12, ZT=183, TotalTransport=2.3e+08
# Gen 227: Z=2.020e+02, ZC=8.099e+12, ZT=183, TotalTransport=2.3e+08
# Gen 228: Z=1.708e+02, ZC=7.993e+12, ZT=184, TotalTransport=2.3e+08
# Gen 229: Z=1.352e+02, ZC=7.996e+12, ZT=183, TotalTransport=2.3e+08
# Gen 230: Z=1.616e+02, ZC=8.112e+12, ZT=182, TotalTransport=2.3e+08
# Gen 231: Z=1.419e+02, ZC=8.085e+12, ZT=182, TotalTransport=2.3e+08
# Gen 232: Z=1.406e+02, ZC=8.143e+12, ZT=181, TotalTransport=2.3e+08
# Gen 233: Z=1.394e+02, ZC=8.100e+12, ZT=180, TotalTransport=2.3e+08
# Gen 234: Z=1.586e+02, ZC=8.234e+12, ZT=179, TotalTransport=2.3e+08
# Gen 235: Z=1.283e+02, ZC=8.063e+12, ZT=180, TotalTransport=2.3e+08
# Gen 236: Z=1.289e+02, ZC=8.025e+12, ZT=180, TotalTransport=2.3e+08
# Gen 237: Z=1.412e+02, ZC=8.015e+12, ZT=180, TotalTransport=2.3e+08
# Gen 238: Z=1.961e+02, ZC=8.001e+12, ZT=180, TotalTransport=2.3e+08
# Gen 239: Z=2.341e+02, ZC=7.976e+12, ZT=180, TotalTransport=2.3e+08
# Gen 240: Z=2.368e+02, ZC=8.073e+12, ZT=179, TotalTransport=2.3e+08
# Gen 241: Z=1.932e+02, ZC=8.179e+12, ZT=178, TotalTransport=2.4e+08
# Gen 242: Z=1.679e+02, ZC=8.179e+12, ZT=178, TotalTransport=2.4e+08
# Gen 243: Z=1.341e+02, ZC=8.142e+12, ZT=178, TotalTransport=2.3e+08
# Gen 244: Z=1.235e+02, ZC=8.056e+12, ZT=178, TotalTransport=2.3e+08
# Gen 245: Z=1.280e+02, ZC=8.056e+12, ZT=178, TotalTransport=2.3e+08
# Gen 246: Z=1.425e+02, ZC=8.172e+12, ZT=176, TotalTransport=2.4e+08
# Gen 247: Z=1.293e+02, ZC=8.171e+12, ZT=176, TotalTransport=2.4e+08
# Gen 248: Z=1.153e+02, ZC=8.052e+12, ZT=177, TotalTransport=2.4e+08
# Gen 249: Z=1.016e+02, ZC=8.052e+12, ZT=177, TotalTransport=2.4e+08
# Gen 250: Z=1.156e+02, ZC=8.181e+12, ZT=175, TotalTransport=2.4e+08
# Gen 251: Z=1.154e+02, ZC=8.181e+12, ZT=175, TotalTransport=2.4e+08
# Gen 252: Z=1.152e+02, ZC=8.342e+12, ZT=173, TotalTransport=2.4e+08
# Gen 253: Z=1.071e+02, ZC=8.001e+12, ZT=176, TotalTransport=2.4e+08
# Gen 254: Z=9.272e+01, ZC=8.223e+12, ZT=173, TotalTransport=2.4e+08
# Gen 255: Z=9.294e+01, ZC=8.223e+12, ZT=173, TotalTransport=2.4e+08
# Gen 256: Z=1.117e+02, ZC=8.223e+12, ZT=173, TotalTransport=2.4e+08
# Gen 257: Z=1.151e+02, ZC=8.247e+12, ZT=172, TotalTransport=2.4e+08
# Gen 258: Z=1.291e+02, ZC=8.239e+12, ZT=172, TotalTransport=2.4e+08
# Gen 259: Z=1.147e+02, ZC=8.191e+12, ZT=172, TotalTransport=2.4e+08
# Gen 260: Z=1.114e+02, ZC=8.239e+12, ZT=172, TotalTransport=2.4e+08
# Gen 261: Z=1.098e+02, ZC=8.311e+12, ZT=170, TotalTransport=2.4e+08
# Gen 262: Z=1.174e+02, ZC=8.188e+12, ZT=171, TotalTransport=2.4e+08
# Gen 263: Z=1.245e+02, ZC=8.181e+12, ZT=171, TotalTransport=2.4e+08
# Gen 264: Z=1.758e+02, ZC=8.236e+12, ZT=170, TotalTransport=2.4e+08
# Gen 265: Z=1.980e+02, ZC=8.294e+12, ZT=169, TotalTransport=2.4e+08
# Gen 266: Z=1.804e+02, ZC=8.145e+12, ZT=170, TotalTransport=2.4e+08
# Gen 267: Z=1.560e+02, ZC=8.225e+12, ZT=169, TotalTransport=2.4e+08
# Gen 268: Z=1.808e+02, ZC=8.221e+12, ZT=169, TotalTransport=2.4e+08
# Gen 269: Z=1.588e+02, ZC=8.217e+12, ZT=169, TotalTransport=2.4e+08
# Gen 270: Z=2.015e+02, ZC=8.189e+12, ZT=169, TotalTransport=2.4e+08
# Gen 271: Z=1.987e+02, ZC=8.240e+12, ZT=168, TotalTransport=2.4e+08
# Gen 272: Z=2.367e+02, ZC=8.239e+12, ZT=168, TotalTransport=2.4e+08
# Gen 273: Z=2.228e+02, ZC=8.239e+12, ZT=168, TotalTransport=2.4e+08
# Gen 274: Z=2.239e+02, ZC=8.239e+12, ZT=168, TotalTransport=2.4e+08
# Gen 275: Z=2.247e+02, ZC=8.225e+12, ZT=168, TotalTransport=2.4e+08
# Gen 276: Z=2.761e+02, ZC=8.323e+12, ZT=167, TotalTransport=2.5e+08
# Gen 277: Z=2.431e+02, ZC=8.372e+12, ZT=166, TotalTransport=2.5e+08
# Gen 278: Z=1.911e+02, ZC=8.372e+12, ZT=166, TotalTransport=2.5e+08
# Gen 279: Z=1.276e+02, ZC=8.357e+12, ZT=166, TotalTransport=2.5e+08
# Gen 280: Z=1.204e+02, ZC=8.237e+12, ZT=167, TotalTransport=2.4e+08
# Gen 281: Z=1.051e+02, ZC=8.376e+12, ZT=165, TotalTransport=2.5e+08
# Gen 282: Z=1.213e+02, ZC=8.372e+12, ZT=165, TotalTransport=2.5e+08
# Gen 283: Z=1.525e+02, ZC=8.355e+12, ZT=165, TotalTransport=2.5e+08
# Gen 284: Z=1.775e+02, ZC=8.372e+12, ZT=165, TotalTransport=2.5e+08
# Gen 285: Z=1.685e+02, ZC=8.240e+12, ZT=166, TotalTransport=2.5e+08
# Gen 286: Z=2.394e+02, ZC=8.355e+12, ZT=165, TotalTransport=2.5e+08
# Gen 287: Z=2.138e+02, ZC=8.368e+12, ZT=164, TotalTransport=2.5e+08
# Gen 288: Z=2.001e+02, ZC=8.433e+12, ZT=163, TotalTransport=2.5e+08
# Gen 289: Z=1.870e+02, ZC=8.433e+12, ZT=163, TotalTransport=2.5e+08
# Gen 290: Z=1.866e+02, ZC=8.433e+12, ZT=163, TotalTransport=2.5e+08
# Gen 291: Z=1.440e+02, ZC=8.388e+12, ZT=163, TotalTransport=2.5e+08
# Gen 292: Z=1.349e+02, ZC=8.388e+12, ZT=163, TotalTransport=2.5e+08
# Gen 293: Z=1.416e+02, ZC=8.374e+12, ZT=163, TotalTransport=2.5e+08
# Gen 294: Z=1.364e+02, ZC=8.495e+12, ZT=162, TotalTransport=2.5e+08
# Gen 295: Z=1.783e+02, ZC=8.355e+12, ZT=163, TotalTransport=2.5e+08
# Gen 296: Z=1.687e+02, ZC=8.467e+12, ZT=162, TotalTransport=2.5e+08
# Gen 297: Z=1.679e+02, ZC=8.428e+12, ZT=162, TotalTransport=2.5e+08
# Gen 298: Z=1.227e+02, ZC=8.534e+12, ZT=161, TotalTransport=2.5e+08
# Gen 299: Z=1.506e+02, ZC=8.419e+12, ZT=162, TotalTransport=2.5e+08
# Gen 300: Z=1.613e+02, ZC=8.478e+12, ZT=161, TotalTransport=2.5e+08
# Gen 301: Z=1.704e+02, ZC=8.478e+12, ZT=161, TotalTransport=2.5e+08
# Gen 302: Z=1.601e+02, ZC=8.459e+12, ZT=161, TotalTransport=2.5e+08
# Gen 303: Z=1.720e+02, ZC=8.473e+12, ZT=160, TotalTransport=2.5e+08
# Gen 304: Z=1.984e+02, ZC=8.473e+12, ZT=160, TotalTransport=2.5e+08
# Gen 305: Z=1.860e+02, ZC=8.473e+12, ZT=160, TotalTransport=2.5e+08
# Gen 306: Z=1.605e+02, ZC=8.473e+12, ZT=160, TotalTransport=2.5e+08
# Gen 307: Z=1.879e+02, ZC=8.494e+12, ZT=159, TotalTransport=2.5e+08
# Gen 308: Z=2.032e+02, ZC=8.494e+12, ZT=159, TotalTransport=2.5e+08
# Gen 309: Z=1.623e+02, ZC=8.494e+12, ZT=159, TotalTransport=2.5e+08
# Gen 310: Z=1.755e+02, ZC=8.494e+12, ZT=159, TotalTransport=2.5e+08
# Gen 311: Z=1.598e+02, ZC=8.494e+12, ZT=159, TotalTransport=2.5e+08
# Gen 312: Z=1.278e+02, ZC=8.479e+12, ZT=159, TotalTransport=2.5e+08
# Gen 313: Z=1.163e+02, ZC=8.494e+12, ZT=159, TotalTransport=2.5e+08
# Gen 314: Z=1.311e+02, ZC=8.494e+12, ZT=159, TotalTransport=2.5e+08
# Gen 315: Z=1.320e+02, ZC=8.768e+12, ZT=156, TotalTransport=2.6e+08
# Gen 316: Z=1.194e+02, ZC=8.512e+12, ZT=158, TotalTransport=2.5e+08
# Gen 317: Z=1.171e+02, ZC=8.635e+12, ZT=157, TotalTransport=2.6e+08
# Gen 318: Z=1.152e+02, ZC=8.600e+12, ZT=157, TotalTransport=2.6e+08
# Gen 319: Z=1.193e+02, ZC=8.527e+12, ZT=157, TotalTransport=2.6e+08
# Gen 320: Z=1.293e+02, ZC=8.599e+12, ZT=156, TotalTransport=2.6e+08
# Gen 321: Z=1.294e+02, ZC=8.597e+12, ZT=156, TotalTransport=2.6e+08
# Gen 322: Z=1.424e+02, ZC=8.597e+12, ZT=156, TotalTransport=2.6e+08
# Gen 323: Z=1.564e+02, ZC=8.700e+12, ZT=155, TotalTransport=2.6e+08
# Gen 324: Z=2.143e+02, ZC=8.530e+12, ZT=156, TotalTransport=2.6e+08
# Gen 325: Z=1.592e+02, ZC=8.613e+12, ZT=155, TotalTransport=2.6e+08
# Gen 326: Z=1.550e+02, ZC=8.601e+12, ZT=155, TotalTransport=2.6e+08
# Gen 327: Z=1.624e+02, ZC=8.612e+12, ZT=155, TotalTransport=2.6e+08
# Gen 328: Z=1.739e+02, ZC=8.599e+12, ZT=155, TotalTransport=2.6e+08
# Gen 329: Z=1.999e+02, ZC=8.700e+12, ZT=154, TotalTransport=2.6e+08
# Gen 330: Z=1.926e+02, ZC=8.636e+12, ZT=154, TotalTransport=2.6e+08
# Gen 331: Z=2.106e+02, ZC=8.623e+12, ZT=154, TotalTransport=2.6e+08
# Gen 332: Z=2.021e+02, ZC=8.604e+12, ZT=154, TotalTransport=2.6e+08
# Gen 333: Z=1.553e+02, ZC=8.879e+12, ZT=151, TotalTransport=2.6e+08
# Gen 334: Z=1.200e+02, ZC=8.626e+12, ZT=153, TotalTransport=2.6e+08
# Gen 335: Z=1.379e+02, ZC=8.715e+12, ZT=152, TotalTransport=2.6e+08
# Gen 336: Z=1.497e+02, ZC=8.715e+12, ZT=152, TotalTransport=2.6e+08
# Gen 337: Z=1.983e+02, ZC=8.598e+12, ZT=153, TotalTransport=2.6e+08
# Gen 338: Z=1.849e+02, ZC=8.667e+12, ZT=152, TotalTransport=2.6e+08
# Gen 339: Z=2.422e+02, ZC=8.667e+12, ZT=152, TotalTransport=2.6e+08
# Gen 340: Z=2.129e+02, ZC=8.661e+12, ZT=152, TotalTransport=2.6e+08
# Gen 341: Z=2.010e+02, ZC=8.646e+12, ZT=152, TotalTransport=2.6e+08
# Gen 342: Z=2.379e+02, ZC=8.640e+12, ZT=152, TotalTransport=2.6e+08
# Gen 343: Z=3.045e+02, ZC=8.612e+12, ZT=152, TotalTransport=2.6e+08
# Gen 344: Z=4.062e+02, ZC=8.640e+12, ZT=152, TotalTransport=2.6e+08
# Gen 345: Z=4.666e+02, ZC=8.635e+12, ZT=152, TotalTransport=2.6e+08
# Gen 346: Z=3.855e+02, ZC=8.777e+12, ZT=151, TotalTransport=2.6e+08
# Gen 347: Z=2.303e+02, ZC=8.720e+12, ZT=151, TotalTransport=2.6e+08
# Gen 348: Z=1.857e+02, ZC=8.827e+12, ZT=150, TotalTransport=2.6e+08
# Gen 349: Z=1.895e+02, ZC=8.715e+12, ZT=151, TotalTransport=2.6e+08
# Gen 350: Z=1.491e+02, ZC=8.785e+12, ZT=150, TotalTransport=2.6e+08
# Gen 351: Z=1.508e+02, ZC=8.753e+12, ZT=150, TotalTransport=2.6e+08
# Gen 352: Z=1.754e+02, ZC=8.753e+12, ZT=150, TotalTransport=2.6e+08
# Gen 353: Z=1.782e+02, ZC=8.752e+12, ZT=150, TotalTransport=2.6e+08
# Gen 354: Z=1.936e+02, ZC=8.844e+12, ZT=149, TotalTransport=2.6e+08
# Gen 355: Z=1.873e+02, ZC=8.844e+12, ZT=149, TotalTransport=2.6e+08
# Gen 356: Z=2.607e+02, ZC=8.746e+12, ZT=150, TotalTransport=2.6e+08
# Gen 357: Z=2.518e+02, ZC=8.735e+12, ZT=150, TotalTransport=2.6e+08
# Gen 358: Z=1.984e+02, ZC=8.987e+12, ZT=148, TotalTransport=2.6e+08
# Gen 359: Z=1.534e+02, ZC=9.000e+12, ZT=148, TotalTransport=2.6e+08
# Gen 360: Z=1.285e+02, ZC=8.844e+12, ZT=149, TotalTransport=2.6e+08
# Gen 361: Z=1.283e+02, ZC=8.844e+12, ZT=149, TotalTransport=2.6e+08
# Gen 362: Z=1.492e+02, ZC=8.962e+12, ZT=148, TotalTransport=2.6e+08
# Gen 363: Z=1.980e+02, ZC=8.954e+12, ZT=148, TotalTransport=2.6e+08
# Gen 364: Z=2.111e+02, ZC=8.920e+12, ZT=148, TotalTransport=2.6e+08
# Gen 365: Z=2.184e+02, ZC=8.920e+12, ZT=148, TotalTransport=2.6e+08
# Gen 366: Z=2.440e+02, ZC=8.920e+12, ZT=148, TotalTransport=2.6e+08
# Gen 367: Z=4.603e+02, ZC=8.910e+12, ZT=148, TotalTransport=2.6e+08
# Gen 368: Z=6.153e+02, ZC=8.908e+12, ZT=148, TotalTransport=2.6e+08
# Gen 369: Z=7.400e+07, ZC=8.908e+12, ZT=148, TotalTransport=2.6e+08
# Gen 370: Z=3.495e+02, ZC=9.056e+12, ZT=147, TotalTransport=2.7e+08
# Gen 371: Z=3.469e+02, ZC=9.056e+12, ZT=147, TotalTransport=2.7e+08
# Gen 372: Z=2.193e+02, ZC=9.056e+12, ZT=147, TotalTransport=2.7e+08
# Gen 373: Z=1.906e+02, ZC=8.896e+12, ZT=148, TotalTransport=2.6e+08
# Gen 374: Z=2.577e+02, ZC=9.055e+12, ZT=147, TotalTransport=2.6e+08
# Gen 375: Z=1.849e+02, ZC=9.212e+12, ZT=146, TotalTransport=2.7e+08
# Gen 376: Z=1.649e+02, ZC=8.896e+12, ZT=148, TotalTransport=2.6e+08
# Gen 377: Z=1.864e+02, ZC=9.112e+12, ZT=146, TotalTransport=2.7e+08
# Gen 378: Z=2.276e+02, ZC=9.112e+12, ZT=146, TotalTransport=2.7e+08
# Gen 379: Z=1.761e+02, ZC=9.112e+12, ZT=146, TotalTransport=2.7e+08
# Gen 380: Z=1.511e+02, ZC=9.074e+12, ZT=146, TotalTransport=2.7e+08
# Gen 381: Z=1.144e+02, ZC=9.074e+12, ZT=146, TotalTransport=2.7e+08
# Gen 382: Z=1.266e+02, ZC=9.053e+12, ZT=146, TotalTransport=2.7e+08
# Gen 383: Z=1.551e+02, ZC=9.056e+12, ZT=146, TotalTransport=2.7e+08
# Gen 384: Z=1.857e+02, ZC=9.090e+12, ZT=145, TotalTransport=2.7e+08
# Gen 385: Z=1.932e+02, ZC=9.101e+12, ZT=145, TotalTransport=2.7e+08
# Gen 386: Z=1.728e+02, ZC=9.067e+12, ZT=145, TotalTransport=2.7e+08
# Gen 387: Z=1.866e+02, ZC=9.239e+12, ZT=143, TotalTransport=2.7e+08
# Gen 388: Z=1.737e+02, ZC=9.067e+12, ZT=145, TotalTransport=2.7e+08
# Gen 389: Z=2.047e+02, ZC=9.072e+12, ZT=144, TotalTransport=2.7e+08
# Gen 390: Z=2.473e+02, ZC=9.093e+12, ZT=144, TotalTransport=2.7e+08
# Gen 391: Z=1.735e+02, ZC=9.130e+12, ZT=144, TotalTransport=2.7e+08
# Gen 392: Z=2.330e+02, ZC=9.129e+12, ZT=144, TotalTransport=2.7e+08
# Gen 393: Z=2.069e+02, ZC=9.130e+12, ZT=144, TotalTransport=2.7e+08
# Gen 394: Z=1.990e+02, ZC=9.074e+12, ZT=144, TotalTransport=2.7e+08
# Gen 395: Z=2.529e+02, ZC=9.030e+12, ZT=144, TotalTransport=2.7e+08
# Gen 396: Z=2.319e+02, ZC=9.030e+12, ZT=144, TotalTransport=2.7e+08
# Gen 397: Z=2.083e+02, ZC=9.030e+12, ZT=144, TotalTransport=2.7e+08
# Gen 398: Z=2.126e+02, ZC=9.139e+12, ZT=143, TotalTransport=2.7e+08
# Gen 399: Z=2.142e+02, ZC=9.117e+12, ZT=143, TotalTransport=2.7e+08
# Gen 400: Z=1.952e+02, ZC=9.084e+12, ZT=143, TotalTransport=2.7e+08
# Gen 401: Z=2.072e+02, ZC=9.101e+12, ZT=143, TotalTransport=2.7e+08
# Gen 402: Z=1.843e+02, ZC=9.101e+12, ZT=143, TotalTransport=2.7e+08
# Gen 403: Z=1.669e+02, ZC=9.099e+12, ZT=143, TotalTransport=2.7e+08
# Gen 404: Z=1.982e+02, ZC=9.072e+12, ZT=143, TotalTransport=2.7e+08
# Gen 405: Z=3.552e+02, ZC=9.071e+12, ZT=143, TotalTransport=2.7e+08
# Gen 406: Z=4.200e+02, ZC=9.071e+12, ZT=143, TotalTransport=2.7e+08
# Gen 407: Z=2.666e+02, ZC=9.147e+12, ZT=142, TotalTransport=2.7e+08
# Gen 408: Z=2.040e+02, ZC=9.147e+12, ZT=142, TotalTransport=2.7e+08
# Gen 409: Z=1.970e+02, ZC=9.147e+12, ZT=142, TotalTransport=2.7e+08
# Gen 410: Z=1.798e+02, ZC=9.147e+12, ZT=142, TotalTransport=2.7e+08
# Gen 411: Z=1.695e+02, ZC=9.124e+12, ZT=142, TotalTransport=2.7e+08
# Gen 412: Z=1.337e+02, ZC=9.122e+12, ZT=142, TotalTransport=2.7e+08
# Gen 413: Z=1.705e+02, ZC=9.122e+12, ZT=142, TotalTransport=2.7e+08
# Gen 414: Z=1.729e+02, ZC=9.103e+12, ZT=142, TotalTransport=2.7e+08
# Gen 415: Z=2.177e+02, ZC=9.188e+12, ZT=141, TotalTransport=2.7e+08
# Gen 416: Z=2.346e+02, ZC=9.122e+12, ZT=141, TotalTransport=2.7e+08
# Gen 417: Z=1.923e+02, ZC=9.122e+12, ZT=141, TotalTransport=2.7e+08
# Gen 418: Z=2.091e+02, ZC=9.114e+12, ZT=141, TotalTransport=2.7e+08
# Gen 419: Z=1.928e+02, ZC=9.114e+12, ZT=141, TotalTransport=2.7e+08
# Gen 420: Z=2.918e+02, ZC=9.114e+12, ZT=141, TotalTransport=2.7e+08
# Gen 421: Z=3.711e+02, ZC=9.113e+12, ZT=141, TotalTransport=2.7e+08
# Gen 422: Z=3.817e+02, ZC=9.107e+12, ZT=141, TotalTransport=2.7e+08
# Gen 423: Z=4.454e+02, ZC=9.108e+12, ZT=141, TotalTransport=2.7e+08
# Gen 424: Z=4.346e+02, ZC=9.315e+12, ZT=140, TotalTransport=2.7e+08
# Gen 425: Z=2.776e+02, ZC=9.106e+12, ZT=141, TotalTransport=2.7e+08
# Gen 426: Z=3.422e+02, ZC=9.106e+12, ZT=141, TotalTransport=2.7e+08
# Gen 427: Z=4.649e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 428: Z=4.596e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 429: Z=3.969e+02, ZC=9.105e+12, ZT=141, TotalTransport=2.7e+08
# Gen 430: Z=3.602e+02, ZC=9.105e+12, ZT=141, TotalTransport=2.7e+08
# Gen 431: Z=6.506e+02, ZC=9.105e+12, ZT=141, TotalTransport=2.7e+08
# Gen 432: Z=2.891e+02, ZC=9.105e+12, ZT=141, TotalTransport=2.7e+08
# Gen 433: Z=3.786e+02, ZC=9.105e+12, ZT=141, TotalTransport=2.7e+08
# Gen 434: Z=3.468e+02, ZC=9.105e+12, ZT=141, TotalTransport=2.7e+08
# Gen 435: Z=3.731e+02, ZC=9.105e+12, ZT=141, TotalTransport=2.7e+08
# Gen 436: Z=2.859e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 437: Z=4.561e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 438: Z=3.219e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 439: Z=4.413e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 440: Z=4.155e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 441: Z=3.842e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 442: Z=4.137e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 443: Z=4.680e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 444: Z=4.925e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 445: Z=4.401e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 446: Z=2.937e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 447: Z=3.010e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 448: Z=3.308e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 449: Z=7.050e+07, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 450: Z=5.009e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 451: Z=4.452e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 452: Z=3.424e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 453: Z=3.240e+02, ZC=9.076e+12, ZT=141, TotalTransport=2.7e+08
# Gen 454: Z=7.050e+07, ZC=9.071e+12, ZT=141, TotalTransport=2.7e+08
# Gen 455: Z=3.044e+02, ZC=9.070e+12, ZT=141, TotalTransport=2.7e+08
# Gen 456: Z=2.726e+02, ZC=9.283e+12, ZT=140, TotalTransport=2.7e+08
# Gen 457: Z=2.463e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 458: Z=3.400e+02, ZC=9.277e+12, ZT=140, TotalTransport=2.7e+08
# Gen 459: Z=3.638e+02, ZC=9.342e+12, ZT=140, TotalTransport=2.7e+08
# Gen 460: Z=2.103e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 461: Z=4.454e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 462: Z=3.301e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 463: Z=7.050e+07, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 464: Z=5.982e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 465: Z=3.745e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 466: Z=5.145e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 467: Z=2.939e+02, ZC=9.104e+12, ZT=141, TotalTransport=2.7e+08
# Gen 468: Z=4.757e+02, ZC=9.099e+12, ZT=141, TotalTransport=2.7e+08
# Gen 469: Z=3.165e+02, ZC=9.087e+12, ZT=141, TotalTransport=2.7e+08
# Gen 470: Z=3.747e+02, ZC=9.087e+12, ZT=141, TotalTransport=2.7e+08
# Gen 471: Z=3.782e+02, ZC=9.099e+12, ZT=141, TotalTransport=2.7e+08
# Gen 472: Z=7.050e+07, ZC=9.098e+12, ZT=141, TotalTransport=2.7e+08
# Gen 473: Z=6.195e+02, ZC=9.097e+12, ZT=141, TotalTransport=2.7e+08
# Gen 474: Z=4.384e+02, ZC=9.097e+12, ZT=141, TotalTransport=2.7e+08
# Gen 475: Z=5.844e+02, ZC=9.085e+12, ZT=141, TotalTransport=2.7e+08
# Gen 476: Z=5.867e+02, ZC=9.088e+12, ZT=141, TotalTransport=2.7e+08
# Gen 477: Z=3.447e+02, ZC=9.087e+12, ZT=141, TotalTransport=2.7e+08
# Gen 478: Z=3.948e+02, ZC=9.087e+12, ZT=141, TotalTransport=2.7e+08
# Gen 479: Z=4.588e+02, ZC=9.085e+12, ZT=141, TotalTransport=2.7e+08
# Gen 480: Z=6.194e+02, ZC=9.085e+12, ZT=141, TotalTransport=2.7e+08
# Gen 481: Z=3.806e+02, ZC=9.085e+12, ZT=141, TotalTransport=2.7e+08
# Gen 482: Z=3.115e+02, ZC=9.085e+12, ZT=141, TotalTransport=2.7e+08
# Gen 483: Z=3.073e+02, ZC=9.085e+12, ZT=141, TotalTransport=2.7e+08
# Gen 484: Z=5.921e+02, ZC=9.085e+12, ZT=141, TotalTransport=2.7e+08
# Gen 485: Z=3.970e+02, ZC=9.085e+12, ZT=141, TotalTransport=2.7e+08
# Gen 486: Z=4.515e+02, ZC=9.085e+12, ZT=141, TotalTransport=2.7e+08
# Gen 487: Z=4.621e+02, ZC=9.028e+12, ZT=141, TotalTransport=2.7e+08
# Gen 488: Z=2.899e+02, ZC=9.163e+12, ZT=140, TotalTransport=2.7e+08
# Gen 489: Z=2.822e+02, ZC=9.204e+12, ZT=140, TotalTransport=2.7e+08
# Gen 490: Z=3.569e+02, ZC=9.204e+12, ZT=140, TotalTransport=2.7e+08
# Gen 491: Z=3.083e+02, ZC=9.288e+12, ZT=140, TotalTransport=2.7e+08
# Gen 492: Z=3.209e+02, ZC=9.200e+12, ZT=140, TotalTransport=2.7e+08
# Gen 493: Z=5.793e+02, ZC=9.200e+12, ZT=140, TotalTransport=2.7e+08
# Gen 494: Z=3.098e+02, ZC=9.148e+12, ZT=140, TotalTransport=2.7e+08
# Gen 495: Z=1.936e+02, ZC=9.147e+12, ZT=140, TotalTransport=2.7e+08
# Gen 496: Z=2.672e+02, ZC=9.147e+12, ZT=140, TotalTransport=2.7e+08
# Gen 497: Z=2.745e+02, ZC=9.147e+12, ZT=140, TotalTransport=2.7e+08
# Gen 498: Z=2.176e+02, ZC=9.145e+12, ZT=140, TotalTransport=2.7e+08
# Gen 499: Z=1.728e+02, ZC=9.145e+12, ZT=140, TotalTransport=2.7e+08
# Gen 500: Z=1.990e+02, ZC=9.145e+12, ZT=140, TotalTransport=2.7e+08
# Gen 501: Z=1.937e+02, ZC=9.116e+12, ZT=140, TotalTransport=2.7e+08
# Gen 502: Z=1.787e+02, ZC=9.197e+12, ZT=139, TotalTransport=2.7e+08
# Gen 503: Z=2.153e+02, ZC=9.196e+12, ZT=139, TotalTransport=2.7e+08
# Gen 504: Z=1.656e+02, ZC=8.986e+12, ZT=141, TotalTransport=2.7e+08
# Gen 505: Z=1.287e+02, ZC=9.170e+12, ZT=139, TotalTransport=2.7e+08
# Gen 506: Z=1.212e+02, ZC=9.132e+12, ZT=139, TotalTransport=2.7e+08
# Gen 507: Z=1.045e+02, ZC=9.132e+12, ZT=139, TotalTransport=2.7e+08
# Gen 508: Z=1.386e+02, ZC=9.131e+12, ZT=139, TotalTransport=2.7e+08
# Gen 509: Z=1.664e+02, ZC=9.161e+12, ZT=138, TotalTransport=2.7e+08
# Gen 510: Z=1.433e+02, ZC=9.161e+12, ZT=138, TotalTransport=2.7e+08
# Gen 511: Z=2.350e+02, ZC=9.162e+12, ZT=138, TotalTransport=2.7e+08
# Gen 512: Z=1.890e+02, ZC=9.162e+12, ZT=138, TotalTransport=2.7e+08
# Gen 513: Z=1.823e+02, ZC=9.132e+12, ZT=138, TotalTransport=2.7e+08
# Gen 514: Z=2.140e+02, ZC=9.132e+12, ZT=138, TotalTransport=2.7e+08
# Gen 515: Z=1.951e+02, ZC=9.132e+12, ZT=138, TotalTransport=2.7e+08
# Gen 516: Z=2.174e+02, ZC=9.132e+12, ZT=138, TotalTransport=2.7e+08
# Gen 517: Z=2.303e+02, ZC=9.131e+12, ZT=138, TotalTransport=2.7e+08
# Gen 518: Z=2.756e+02, ZC=9.246e+12, ZT=137, TotalTransport=2.7e+08
# Gen 519: Z=3.879e+02, ZC=9.246e+12, ZT=137, TotalTransport=2.7e+08
# Gen 520: Z=3.512e+02, ZC=9.109e+12, ZT=138, TotalTransport=2.7e+08
# Gen 521: Z=3.210e+02, ZC=9.109e+12, ZT=138, TotalTransport=2.7e+08
# Gen 522: Z=4.526e+02, ZC=9.109e+12, ZT=138, TotalTransport=2.7e+08
# Gen 523: Z=3.804e+02, ZC=9.108e+12, ZT=138, TotalTransport=2.7e+08
# Gen 524: Z=4.708e+02, ZC=9.109e+12, ZT=138, TotalTransport=2.7e+08
# Gen 525: Z=3.714e+02, ZC=9.108e+12, ZT=138, TotalTransport=2.7e+08
# Gen 526: Z=4.442e+02, ZC=9.108e+12, ZT=138, TotalTransport=2.7e+08
# Gen 527: Z=3.138e+02, ZC=9.108e+12, ZT=138, TotalTransport=2.7e+08
# Gen 528: Z=2.776e+02, ZC=9.108e+12, ZT=138, TotalTransport=2.7e+08
# Gen 529: Z=2.693e+02, ZC=9.108e+12, ZT=138, TotalTransport=2.7e+08
# Gen 530: Z=3.459e+02, ZC=9.108e+12, ZT=138, TotalTransport=2.7e+08
# Gen 531: Z=3.238e+02, ZC=9.108e+12, ZT=138, TotalTransport=2.7e+08
# Gen 532: Z=3.457e+02, ZC=9.108e+12, ZT=138, TotalTransport=2.7e+08
# Gen 533: Z=5.790e+02, ZC=9.108e+12, ZT=138, TotalTransport=2.7e+08
# Gen 534: Z=3.088e+02, ZC=9.108e+12, ZT=138, TotalTransport=2.7e+08
# Gen 535: Z=3.361e+02, ZC=9.282e+12, ZT=137, TotalTransport=2.7e+08
# Gen 536: Z=3.072e+02, ZC=9.282e+12, ZT=137, TotalTransport=2.7e+08
# Gen 537: Z=3.203e+02, ZC=9.232e+12, ZT=137, TotalTransport=2.7e+08
# Gen 538: Z=2.631e+02, ZC=9.103e+12, ZT=138, TotalTransport=2.7e+08
# Gen 539: Z=3.054e+02, ZC=9.219e+12, ZT=137, TotalTransport=2.7e+08
# Gen 540: Z=3.363e+02, ZC=9.102e+12, ZT=138, TotalTransport=2.7e+08
# Gen 541: Z=2.240e+02, ZC=9.169e+12, ZT=137, TotalTransport=2.7e+08
# Gen 542: Z=2.271e+02, ZC=9.169e+12, ZT=137, TotalTransport=2.7e+08
# Gen 543: Z=2.218e+02, ZC=9.169e+12, ZT=137, TotalTransport=2.7e+08
# Gen 544: Z=2.207e+02, ZC=9.169e+12, ZT=137, TotalTransport=2.7e+08
# Gen 545: Z=2.225e+02, ZC=9.169e+12, ZT=137, TotalTransport=2.7e+08
# Gen 546: Z=1.834e+02, ZC=9.161e+12, ZT=137, TotalTransport=2.7e+08
# Gen 547: Z=1.987e+02, ZC=9.268e+12, ZT=136, TotalTransport=2.8e+08
# Gen 548: Z=1.995e+02, ZC=9.268e+12, ZT=136, TotalTransport=2.8e+08
# Gen 549: Z=1.897e+02, ZC=9.243e+12, ZT=136, TotalTransport=2.8e+08
# Gen 550: Z=2.322e+02, ZC=9.243e+12, ZT=136, TotalTransport=2.8e+08
# Gen 551: Z=3.049e+02, ZC=9.256e+12, ZT=136, TotalTransport=2.7e+08
# Gen 552: Z=2.008e+02, ZC=9.230e+12, ZT=136, TotalTransport=2.7e+08
# Gen 553: Z=1.836e+02, ZC=9.230e+12, ZT=136, TotalTransport=2.7e+08
# Gen 554: Z=1.999e+02, ZC=9.230e+12, ZT=136, TotalTransport=2.7e+08
# Gen 555: Z=1.897e+02, ZC=9.230e+12, ZT=136, TotalTransport=2.7e+08
# Gen 556: Z=1.912e+02, ZC=9.112e+12, ZT=137, TotalTransport=2.7e+08
# Gen 557: Z=1.738e+02, ZC=9.072e+12, ZT=137, TotalTransport=2.7e+08
# Gen 558: Z=1.853e+02, ZC=9.072e+12, ZT=137, TotalTransport=2.7e+08
# Gen 559: Z=1.814e+02, ZC=9.129e+12, ZT=136, TotalTransport=2.7e+08
# Gen 560: Z=1.682e+02, ZC=9.128e+12, ZT=136, TotalTransport=2.7e+08
# Gen 561: Z=1.454e+02, ZC=9.128e+12, ZT=136, TotalTransport=2.7e+08
# Gen 562: Z=1.602e+02, ZC=9.320e+12, ZT=135, TotalTransport=2.8e+08
# Gen 563: Z=1.989e+02, ZC=9.178e+12, ZT=136, TotalTransport=2.7e+08
# Gen 564: Z=2.466e+02, ZC=9.170e+12, ZT=136, TotalTransport=2.7e+08
# Gen 565: Z=3.035e+02, ZC=9.170e+12, ZT=136, TotalTransport=2.7e+08
# Gen 566: Z=5.040e+02, ZC=9.170e+12, ZT=136, TotalTransport=2.7e+08
# Gen 567: Z=3.595e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 568: Z=4.445e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 569: Z=4.301e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 570: Z=3.687e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 571: Z=2.513e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 572: Z=6.153e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 573: Z=4.389e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 574: Z=2.936e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 575: Z=3.214e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 576: Z=4.179e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 577: Z=4.617e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 578: Z=3.255e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 579: Z=3.879e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 580: Z=4.825e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 581: Z=3.125e+02, ZC=9.289e+12, ZT=135, TotalTransport=2.8e+08
# Gen 582: Z=3.279e+02, ZC=9.288e+12, ZT=135, TotalTransport=2.8e+08
# Gen 583: Z=4.747e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 584: Z=3.678e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 585: Z=2.693e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 586: Z=3.850e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 587: Z=2.807e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 588: Z=2.975e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 589: Z=3.747e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 590: Z=2.890e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 591: Z=3.883e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 592: Z=3.724e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 593: Z=2.903e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 594: Z=2.860e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 595: Z=3.584e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 596: Z=2.853e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 597: Z=3.132e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 598: Z=2.921e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 599: Z=3.177e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 600: Z=5.747e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 601: Z=3.839e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 602: Z=3.657e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 603: Z=3.280e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 604: Z=3.357e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 605: Z=3.540e+02, ZC=9.157e+12, ZT=136, TotalTransport=2.7e+08
# Gen 606: Z=2.965e+02, ZC=9.289e+12, ZT=135, TotalTransport=2.8e+08
# Gen 607: Z=3.443e+02, ZC=9.287e+12, ZT=135, TotalTransport=2.8e+08
# Gen 608: Z=2.145e+02, ZC=9.287e+12, ZT=135, TotalTransport=2.8e+08
# Gen 609: Z=2.181e+02, ZC=9.155e+12, ZT=136, TotalTransport=2.7e+08
# Gen 610: Z=3.047e+02, ZC=9.287e+12, ZT=135, TotalTransport=2.8e+08
# Gen 611: Z=2.375e+02, ZC=9.287e+12, ZT=135, TotalTransport=2.8e+08
# Gen 612: Z=2.065e+02, ZC=9.435e+12, ZT=134, TotalTransport=2.8e+08
# Gen 613: Z=2.610e+02, ZC=9.287e+12, ZT=135, TotalTransport=2.8e+08
# Gen 614: Z=2.383e+02, ZC=9.287e+12, ZT=135, TotalTransport=2.8e+08
# Gen 615: Z=1.856e+02, ZC=9.287e+12, ZT=135, TotalTransport=2.8e+08
# Gen 616: Z=1.964e+02, ZC=9.409e+12, ZT=134, TotalTransport=2.8e+08
# Gen 617: Z=2.371e+02, ZC=9.287e+12, ZT=135, TotalTransport=2.8e+08
# Gen 618: Z=2.130e+02, ZC=9.287e+12, ZT=135, TotalTransport=2.8e+08
# Gen 619: Z=1.962e+02, ZC=9.155e+12, ZT=136, TotalTransport=2.7e+08
# Gen 620: Z=3.351e+02, ZC=9.468e+12, ZT=135, TotalTransport=2.8e+08
# Gen 621: Z=2.681e+02, ZC=9.232e+12, ZT=135, TotalTransport=2.8e+08
# Gen 622: Z=1.563e+02, ZC=9.224e+12, ZT=135, TotalTransport=2.8e+08
# Gen 623: Z=2.043e+02, ZC=9.231e+12, ZT=135, TotalTransport=2.8e+08
# Gen 624: Z=2.290e+02, ZC=9.224e+12, ZT=135, TotalTransport=2.8e+08
# Gen 625: Z=2.182e+02, ZC=9.210e+12, ZT=135, TotalTransport=2.8e+08
# Gen 626: Z=2.116e+02, ZC=9.210e+12, ZT=135, TotalTransport=2.8e+08
# Gen 627: Z=2.712e+02, ZC=9.210e+12, ZT=135, TotalTransport=2.8e+08
# Gen 628: Z=2.662e+02, ZC=9.293e+12, ZT=134, TotalTransport=2.8e+08
# Gen 629: Z=3.342e+02, ZC=9.208e+12, ZT=135, TotalTransport=2.8e+08
# Gen 630: Z=3.891e+02, ZC=9.208e+12, ZT=135, TotalTransport=2.8e+08
# Gen 631: Z=4.309e+02, ZC=9.208e+12, ZT=135, TotalTransport=2.8e+08
# Gen 632: Z=3.352e+02, ZC=9.333e+12, ZT=134, TotalTransport=2.8e+08
# Gen 633: Z=2.851e+02, ZC=9.333e+12, ZT=134, TotalTransport=2.8e+08
# Gen 634: Z=3.171e+02, ZC=9.333e+12, ZT=134, TotalTransport=2.8e+08
# Gen 635: Z=2.071e+02, ZC=9.284e+12, ZT=134, TotalTransport=2.8e+08
# Gen 636: Z=2.209e+02, ZC=9.316e+12, ZT=134, TotalTransport=2.8e+08
# Gen 637: Z=2.048e+02, ZC=9.350e+12, ZT=133, TotalTransport=2.8e+08
# Gen 638: Z=1.876e+02, ZC=9.350e+12, ZT=133, TotalTransport=2.8e+08
# Gen 639: Z=1.522e+02, ZC=9.349e+12, ZT=133, TotalTransport=2.8e+08
# Gen 640: Z=1.338e+02, ZC=9.347e+12, ZT=133, TotalTransport=2.8e+08
# Gen 641: Z=1.254e+02, ZC=9.227e+12, ZT=134, TotalTransport=2.8e+08
# Gen 642: Z=1.326e+02, ZC=9.227e+12, ZT=134, TotalTransport=2.8e+08
# Gen 643: Z=1.815e+02, ZC=9.276e+12, ZT=133, TotalTransport=2.8e+08
# Gen 644: Z=1.849e+02, ZC=9.277e+12, ZT=133, TotalTransport=2.8e+08
# Gen 645: Z=1.826e+02, ZC=9.277e+12, ZT=133, TotalTransport=2.8e+08
# Gen 646: Z=1.787e+02, ZC=9.276e+12, ZT=133, TotalTransport=2.8e+08
# Gen 647: Z=2.976e+02, ZC=9.256e+12, ZT=133, TotalTransport=2.8e+08
# Gen 648: Z=2.722e+02, ZC=9.256e+12, ZT=133, TotalTransport=2.8e+08
# Gen 649: Z=2.779e+02, ZC=9.256e+12, ZT=133, TotalTransport=2.8e+08
# Gen 650: Z=2.453e+02, ZC=9.256e+12, ZT=133, TotalTransport=2.8e+08
# Gen 651: Z=3.327e+02, ZC=9.255e+12, ZT=133, TotalTransport=2.8e+08
# Gen 652: Z=2.658e+02, ZC=9.255e+12, ZT=133, TotalTransport=2.8e+08
# Gen 653: Z=2.469e+02, ZC=9.255e+12, ZT=133, TotalTransport=2.8e+08
# Gen 654: Z=2.733e+02, ZC=9.255e+12, ZT=133, TotalTransport=2.8e+08
# Gen 655: Z=2.719e+02, ZC=9.255e+12, ZT=133, TotalTransport=2.8e+08
# Gen 656: Z=2.490e+02, ZC=9.255e+12, ZT=133, TotalTransport=2.8e+08
# Gen 657: Z=3.518e+02, ZC=9.254e+12, ZT=133, TotalTransport=2.8e+08
# Gen 658: Z=2.867e+02, ZC=9.247e+12, ZT=133, TotalTransport=2.8e+08
# Gen 659: Z=2.642e+02, ZC=9.247e+12, ZT=133, TotalTransport=2.8e+08
# Gen 660: Z=3.377e+02, ZC=9.235e+12, ZT=133, TotalTransport=2.8e+08
# Gen 661: Z=3.194e+02, ZC=9.220e+12, ZT=133, TotalTransport=2.8e+08
# Gen 662: Z=3.445e+02, ZC=9.219e+12, ZT=133, TotalTransport=2.8e+08
# Gen 663: Z=3.062e+02, ZC=9.219e+12, ZT=133, TotalTransport=2.8e+08
# Gen 664: Z=6.650e+07, ZC=9.196e+12, ZT=133, TotalTransport=2.8e+08
# Gen 665: Z=6.650e+07, ZC=9.196e+12, ZT=133, TotalTransport=2.8e+08
# Gen 666: Z=3.737e+02, ZC=9.196e+12, ZT=133, TotalTransport=2.8e+08
# Gen 667: Z=3.137e+02, ZC=9.196e+12, ZT=133, TotalTransport=2.8e+08
# Gen 668: Z=3.174e+02, ZC=9.196e+12, ZT=133, TotalTransport=2.8e+08
# Gen 669: Z=3.263e+02, ZC=9.193e+12, ZT=133, TotalTransport=2.8e+08
# Gen 670: Z=3.249e+02, ZC=9.193e+12, ZT=133, TotalTransport=2.8e+08
# Gen 671: Z=3.448e+02, ZC=9.191e+12, ZT=133, TotalTransport=2.8e+08
# Gen 672: Z=3.907e+02, ZC=9.182e+12, ZT=133, TotalTransport=2.8e+08
# Gen 673: Z=2.764e+02, ZC=9.180e+12, ZT=133, TotalTransport=2.8e+08
# Gen 674: Z=3.065e+02, ZC=9.165e+12, ZT=133, TotalTransport=2.8e+08
# Gen 675: Z=3.411e+02, ZC=9.165e+12, ZT=133, TotalTransport=2.8e+08
# Gen 676: Z=3.027e+02, ZC=9.165e+12, ZT=133, TotalTransport=2.8e+08
# Gen 677: Z=3.424e+02, ZC=9.165e+12, ZT=133, TotalTransport=2.8e+08
# Gen 678: Z=2.754e+02, ZC=9.165e+12, ZT=133, TotalTransport=2.8e+08
# Gen 679: Z=2.417e+02, ZC=9.165e+12, ZT=133, TotalTransport=2.8e+08
# Gen 680: Z=2.394e+02, ZC=9.162e+12, ZT=133, TotalTransport=2.8e+08
# Gen 681: Z=2.592e+02, ZC=9.152e+12, ZT=133, TotalTransport=2.8e+08
# Gen 682: Z=3.365e+02, ZC=9.315e+12, ZT=132, TotalTransport=2.8e+08
# Gen 683: Z=4.122e+02, ZC=9.398e+12, ZT=132, TotalTransport=2.8e+08
# Gen 684: Z=3.380e+02, ZC=9.291e+12, ZT=132, TotalTransport=2.8e+08
# Gen 685: Z=3.732e+02, ZC=9.276e+12, ZT=132, TotalTransport=2.8e+08
# Gen 686: Z=2.621e+02, ZC=9.275e+12, ZT=132, TotalTransport=2.8e+08
# Gen 687: Z=2.063e+02, ZC=9.274e+12, ZT=132, TotalTransport=2.8e+08
# Gen 688: Z=2.299e+02, ZC=9.266e+12, ZT=132, TotalTransport=2.8e+08
# Gen 689: Z=1.926e+02, ZC=9.266e+12, ZT=132, TotalTransport=2.8e+08
# Gen 690: Z=1.934e+02, ZC=9.133e+12, ZT=133, TotalTransport=2.8e+08
# Gen 691: Z=1.998e+02, ZC=9.223e+12, ZT=132, TotalTransport=2.8e+08
# Gen 692: Z=1.853e+02, ZC=9.191e+12, ZT=132, TotalTransport=2.8e+08
# Gen 693: Z=1.919e+02, ZC=9.190e+12, ZT=132, TotalTransport=2.8e+08
# Gen 694: Z=1.886e+02, ZC=9.157e+12, ZT=132, TotalTransport=2.8e+08
# Gen 695: Z=2.075e+02, ZC=9.170e+12, ZT=132, TotalTransport=2.8e+08
# Gen 696: Z=2.516e+02, ZC=9.170e+12, ZT=132, TotalTransport=2.8e+08
# Gen 697: Z=5.625e+02, ZC=9.169e+12, ZT=132, TotalTransport=2.8e+08
# Gen 698: Z=3.159e+02, ZC=9.299e+12, ZT=131, TotalTransport=2.8e+08
# Gen 699: Z=2.472e+02, ZC=9.228e+12, ZT=131, TotalTransport=2.8e+08
# Gen 700: Z=1.804e+02, ZC=9.198e+12, ZT=131, TotalTransport=2.8e+08
# Gen 701: Z=1.833e+02, ZC=9.198e+12, ZT=131, TotalTransport=2.8e+08
# Gen 702: Z=1.765e+02, ZC=9.226e+12, ZT=131, TotalTransport=2.8e+08
# Gen 703: Z=1.860e+02, ZC=9.226e+12, ZT=131, TotalTransport=2.8e+08
# Gen 704: Z=1.871e+02, ZC=9.350e+12, ZT=130, TotalTransport=2.8e+08
# Gen 705: Z=1.858e+02, ZC=9.261e+12, ZT=130, TotalTransport=2.8e+08
# Gen 706: Z=1.952e+02, ZC=9.263e+12, ZT=130, TotalTransport=2.8e+08
# Gen 707: Z=2.215e+02, ZC=9.263e+12, ZT=130, TotalTransport=2.8e+08
# Gen 708: Z=1.717e+02, ZC=9.263e+12, ZT=130, TotalTransport=2.8e+08
# Gen 709: Z=2.134e+02, ZC=9.263e+12, ZT=130, TotalTransport=2.8e+08
# Gen 710: Z=1.959e+02, ZC=9.320e+12, ZT=130, TotalTransport=2.8e+08
# Gen 711: Z=1.657e+02, ZC=9.311e+12, ZT=130, TotalTransport=2.8e+08
# Gen 712: Z=2.309e+02, ZC=9.279e+12, ZT=130, TotalTransport=2.8e+08
# Gen 713: Z=2.506e+02, ZC=9.279e+12, ZT=130, TotalTransport=2.8e+08
# Gen 714: Z=2.502e+02, ZC=9.278e+12, ZT=130, TotalTransport=2.8e+08
# Gen 715: Z=2.471e+02, ZC=9.277e+12, ZT=130, TotalTransport=2.8e+08
# Gen 716: Z=2.295e+02, ZC=9.269e+12, ZT=130, TotalTransport=2.8e+08
# Gen 717: Z=2.630e+02, ZC=9.269e+12, ZT=130, TotalTransport=2.8e+08
# Gen 718: Z=3.588e+02, ZC=9.263e+12, ZT=130, TotalTransport=2.8e+08
# Gen 719: Z=3.817e+02, ZC=9.263e+12, ZT=130, TotalTransport=2.8e+08
# Gen 720: Z=6.633e+02, ZC=9.263e+12, ZT=130, TotalTransport=2.8e+08
# Gen 721: Z=2.431e+02, ZC=9.255e+12, ZT=130, TotalTransport=2.8e+08
# Gen 722: Z=3.174e+02, ZC=9.419e+12, ZT=129, TotalTransport=2.8e+08
# Gen 723: Z=2.796e+02, ZC=9.395e+12, ZT=129, TotalTransport=2.8e+08
# Gen 724: Z=2.198e+02, ZC=9.388e+12, ZT=129, TotalTransport=2.8e+08
# Gen 725: Z=1.803e+02, ZC=9.231e+12, ZT=130, TotalTransport=2.8e+08
# Gen 726: Z=1.608e+02, ZC=9.394e+12, ZT=129, TotalTransport=2.8e+08
# Gen 727: Z=1.885e+02, ZC=9.394e+12, ZT=129, TotalTransport=2.8e+08
# Gen 728: Z=1.820e+02, ZC=9.371e+12, ZT=129, TotalTransport=2.8e+08
# Gen 729: Z=1.657e+02, ZC=9.315e+12, ZT=129, TotalTransport=2.8e+08
# Gen 730: Z=1.816e+02, ZC=9.315e+12, ZT=129, TotalTransport=2.8e+08
# Gen 731: Z=1.936e+02, ZC=9.315e+12, ZT=129, TotalTransport=2.8e+08
# Gen 732: Z=2.051e+02, ZC=9.313e+12, ZT=129, TotalTransport=2.8e+08
# Gen 733: Z=3.350e+02, ZC=9.313e+12, ZT=129, TotalTransport=2.8e+08
# Gen 734: Z=3.158e+02, ZC=9.495e+12, ZT=128, TotalTransport=2.9e+08
# Gen 735: Z=2.779e+02, ZC=9.313e+12, ZT=129, TotalTransport=2.8e+08
# Gen 736: Z=4.380e+02, ZC=9.313e+12, ZT=129, TotalTransport=2.8e+08
# Gen 737: Z=3.979e+02, ZC=9.313e+12, ZT=129, TotalTransport=2.8e+08
# Gen 738: Z=4.367e+02, ZC=9.313e+12, ZT=129, TotalTransport=2.8e+08
# Gen 739: Z=2.772e+02, ZC=9.313e+12, ZT=129, TotalTransport=2.8e+08
# Gen 740: Z=2.773e+02, ZC=9.313e+12, ZT=129, TotalTransport=2.8e+08
# Gen 741: Z=3.109e+02, ZC=9.313e+12, ZT=129, TotalTransport=2.8e+08
# Gen 742: Z=3.039e+02, ZC=9.313e+12, ZT=129, TotalTransport=2.8e+08
# Gen 743: Z=4.357e+02, ZC=9.313e+12, ZT=129, TotalTransport=2.8e+08
# Gen 744: Z=2.633e+02, ZC=9.313e+12, ZT=129, TotalTransport=2.8e+08
# Gen 745: Z=3.067e+02, ZC=9.408e+12, ZT=128, TotalTransport=2.8e+08
# Gen 746: Z=3.016e+02, ZC=9.408e+12, ZT=128, TotalTransport=2.8e+08
# Gen 747: Z=4.013e+02, ZC=9.408e+12, ZT=128, TotalTransport=2.8e+08
# Gen 748: Z=2.628e+02, ZC=9.408e+12, ZT=128, TotalTransport=2.8e+08
# Gen 749: Z=2.240e+02, ZC=9.408e+12, ZT=128, TotalTransport=2.8e+08
# Gen 750: Z=2.121e+02, ZC=9.408e+12, ZT=128, TotalTransport=2.8e+08
# Gen 751: Z=2.087e+02, ZC=9.382e+12, ZT=128, TotalTransport=2.8e+08
# Gen 752: Z=1.913e+02, ZC=9.382e+12, ZT=128, TotalTransport=2.8e+08
# Gen 753: Z=2.112e+02, ZC=9.374e+12, ZT=128, TotalTransport=2.8e+08
# Gen 754: Z=2.061e+02, ZC=9.374e+12, ZT=128, TotalTransport=2.8e+08
# Gen 755: Z=2.398e+02, ZC=9.374e+12, ZT=128, TotalTransport=2.8e+08
# Gen 756: Z=2.675e+02, ZC=9.374e+12, ZT=128, TotalTransport=2.8e+08
# Gen 757: Z=2.526e+02, ZC=9.373e+12, ZT=128, TotalTransport=2.8e+08
# Gen 758: Z=3.057e+02, ZC=9.373e+12, ZT=128, TotalTransport=2.8e+08
# Gen 759: Z=2.834e+02, ZC=9.372e+12, ZT=128, TotalTransport=2.8e+08
# Gen 760: Z=3.817e+02, ZC=9.372e+12, ZT=128, TotalTransport=2.8e+08
# Gen 761: Z=4.169e+02, ZC=9.372e+12, ZT=128, TotalTransport=2.8e+08
# Gen 762: Z=3.127e+02, ZC=9.372e+12, ZT=128, TotalTransport=2.8e+08
# Gen 763: Z=2.353e+02, ZC=9.372e+12, ZT=128, TotalTransport=2.8e+08
# Gen 764: Z=2.966e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 765: Z=3.518e+02, ZC=9.372e+12, ZT=128, TotalTransport=2.8e+08
# Gen 766: Z=4.430e+02, ZC=9.372e+12, ZT=128, TotalTransport=2.8e+08
# Gen 767: Z=3.029e+02, ZC=9.372e+12, ZT=128, TotalTransport=2.8e+08
# Gen 768: Z=2.979e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 769: Z=4.340e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 770: Z=3.740e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 771: Z=4.799e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 772: Z=3.580e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 773: Z=3.900e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 774: Z=3.676e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 775: Z=2.800e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 776: Z=2.550e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 777: Z=3.411e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 778: Z=6.400e+07, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 779: Z=6.025e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 780: Z=3.127e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 781: Z=3.142e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 782: Z=3.743e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 783: Z=3.230e+02, ZC=9.371e+12, ZT=128, TotalTransport=2.8e+08
# Gen 784: Z=3.215e+02, ZC=9.335e+12, ZT=128, TotalTransport=2.8e+08
# Gen 785: Z=2.633e+02, ZC=9.330e+12, ZT=128, TotalTransport=2.8e+08
# Gen 786: Z=2.938e+02, ZC=9.330e+12, ZT=128, TotalTransport=2.8e+08
# Gen 787: Z=2.947e+02, ZC=9.325e+12, ZT=128, TotalTransport=2.8e+08
# Gen 788: Z=2.842e+02, ZC=9.324e+12, ZT=128, TotalTransport=2.8e+08
# Gen 789: Z=2.719e+02, ZC=9.324e+12, ZT=128, TotalTransport=2.8e+08
# Gen 790: Z=2.457e+02, ZC=9.319e+12, ZT=128, TotalTransport=2.8e+08
# Gen 791: Z=5.385e+02, ZC=9.319e+12, ZT=128, TotalTransport=2.8e+08
# Gen 792: Z=3.151e+02, ZC=9.311e+12, ZT=128, TotalTransport=2.8e+08
# Gen 793: Z=3.505e+02, ZC=9.311e+12, ZT=128, TotalTransport=2.8e+08
# Gen 794: Z=2.729e+02, ZC=9.311e+12, ZT=128, TotalTransport=2.8e+08
# Gen 795: Z=3.631e+02, ZC=9.308e+12, ZT=128, TotalTransport=2.8e+08
# Gen 796: Z=3.727e+02, ZC=9.305e+12, ZT=128, TotalTransport=2.8e+08
# Gen 797: Z=2.946e+02, ZC=9.301e+12, ZT=128, TotalTransport=2.8e+08
# Gen 798: Z=3.087e+02, ZC=9.301e+12, ZT=128, TotalTransport=2.8e+08
# Gen 799: Z=2.931e+02, ZC=9.299e+12, ZT=128, TotalTransport=2.8e+08
# 最终总运输量 = 283460785.91551137
# 火箭运输量 =  197036550
# 太空电梯运输量 =  86424235.9155114

# %%
K, TMAX = R.shape
P = E.shape[0]

# 计算每年总运输量
yearly_transport = np.array([R[:, t].sum()*Cap_rocket + E[:, t].sum() for t in range(TMAX)])

# 按年份运输量从大到小排序
sorted_idx = np.argsort(-yearly_transport)

# 初始化新的矩阵
R_new = np.zeros_like(R)
E_new = np.zeros_like(E)

transported = 0
ZT_new = 0

for t_new, t_old in enumerate(sorted_idx):
    # 尽量保持原有分配比例，但不超过上限
    R_year = np.minimum(R[:, t_old], L_max)
    E_year = np.minimum(E[:, t_old], Cap_lift)

    # 计算这一年的运输量
    transported += R_year.sum()*Cap_rocket + E_year.sum()
    
    # 如果运输量超过 D_total，则按比例缩减这一年的运输量
    if transported > D_total:
        excess = transported - D_total
        # 按比例缩减火箭和电梯
        total_year = R_year.sum()*Cap_rocket + E_year.sum()
        if total_year > 0:
            ratio = (total_year - excess) / total_year
            R_year = np.floor(R_year * ratio)  # 保留整数
            E_year = E_year * ratio
        transported = D_total
        ZT_new = t_new + 1
        R_new[:, t_new] = R_year
        E_new[:, t_new] = E_year
        break
    
    R_new[:, t_new] = R_year
    E_new[:, t_new] = E_year
    ZT_new = t_new + 1

print(f"压缩后最早完成 D_total 的年份 ZT_new = {ZT_new}")
print(f"压缩后总运输量 = {transported}")
print(f"火箭总运输量 = {R_new.sum()*Cap_rocket}")
print(f"电梯总运输量 = {E_new.sum()}")
# Out:
# 压缩后最早完成 D_total 的年份 ZT_new = 118
# 压缩后总运输量 = 100000000.0
# 火箭总运输量 = 62585550
# 电梯总运输量 = 37413582.31164177
